# %% [markdown]
# Audio Neural Style Transfer with Pytorch
# ============================
# This is an implementation of neural style transfer using the alogrithm developed in
# [A Neural Algorithm of Artistic Style](https://arxiv.org/abs/1508.06576) by Leon A. Gatys, Alexander S. Ecker and Matthias Bethge.
#
# However instead of learning style from images we use the spectrogram in place to carry out the procedure on audio.
#
# General implementation is based off the [Pytorch tutorial on Neural Transfer](http://pytorch.org/tutorials/advanced/neural_style_tutorial.html) by Alexis Jacq. Also inspired by [Audio texture synthesis](https://github.com/DmitryUlyanov/neural-style-audio-torch) by Dmitry Ulyanov.

# %%
# %matplotlib inline
from __future__ import print_function
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim
import numpy as np

import librosa
from IPython.display import Audio, display
from PIL import Image
import matplotlib.pyplot as plt
import scipy.stats as stats

import torchvision.transforms as transforms
import torchvision.models as models
from torch.nn.modules.module import _addindent

import copy
import os
import math

#for random feature projection
from scipy.stats import ortho_group


import soundfile as sf
from matplotlib.pyplot import figure

# %%
def log_scale(img):
    img = np.log1p(img)
    return img

def inv_log(img):
    img = np.exp(img) - 1.
    return img

# %% [markdown]
# <div style="background-color: honeydew">
# <h2> Session Parameters </h2>
# </div>

# %%
# True uses PGHI (Truncated Gaussian window, log mag, PGHI reconstruction)
# False uses Log Mag spectrum and Griffin Lim reconstruction
tifresi=False

#STYLE_FILENAME = "inputs/lemons.wav" #input filename
#STYLE_FILENAME = "inputs/gansounds/pops4secs.wav" #input filename
#STYLE_FILENAME = "inputs/gansounds/hubub.10secs.wav" #input filename

#STYLE_FILENAME = "inputs/fm.wav" #input filename
#STYLE_FILENAME = "inputs/peepers.wav" #input filename
#STYLE_FILENAME = "inputs/tokwotal.wav" #input filename
STYLE_FILENAME = "inputs/mcdermott/Tapping 1-2.b.wav" #input filename

# You can have your output length be anything! 
SYNTHETIC_LENGTH_FACTOR = 4 # duration of generated relative to target texture

#Go up to 20000 for high quality if you are on a GPU
num_steps=80 #00 #70

####################################################################################################
#Gram matrix dot product multiplies: RFMSTACK*(feature_size/RFMSALEFACTOR)^2
RANDOM_PROJECTION= "Gaussian" # "None", "Gaussian", "Sparse"   (n=None means no random projection at all)
RFMSCALEFACTOR=16   #RM project to size relative to feature dimension
RFMSTACK=32         # how many different RMs to stack
####################################################################################################

#MS Number of separate CNNs operating on input
numStreams=6
learning_Rate= 1 #0.1 #.1  # must be smaller for more streams (if numStream=1, then learning_Rate can be 1)

# %%
display(Audio(STYLE_FILENAME))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <div style="background-color: honeydew">
# <h2> FFT and CNN parameters  </h2>
# (probably don't need to change)
# </div>

# %%
# set filenames
outname = 'rftests' #output dir
runs = 1 # no. of separate outputs (to test consistency), 1 if only want single output

#librosa audio params
N_FFT = 512 
K_HOP = 128 

# architecture
"""use a custom convolutional network randomly initialized""" 
use01scale = False #set to true if want to scale img to [0,1] prior to training. Recommended if using VGG19
boundopt = False #whether to regularize the input within [lower,upper]. Recommended if using VGG19
whichChannel = "freq" #2d=2d conv, 1d options:freq=freq bins as channels, time= time bins as channels 
N_FILTERS = 512# 4096 #no. of filters in 1st conv layer
# hor_filter = 5 #width of conv filter, for 2d also the height of (square) kernel
possible_kernels = [2,4,8,16,64,128,256,512,1024,2048]
# possible_kernels = [2,4,8,16,32,64,128,256,512,1024,2048]
# possible_kernels = [5,5,5,5,5,5]
hor_filters = [0]*numStreams
for j in range(numStreams):
    hor_filters[j]=possible_kernels[j]

# %% [markdown]
# <div style="background-color: honeydew">
# <h4> TFResi params  </h4>
# (probably don't need to change)
# </div>

# %% [markdown]
# [Link to tfresi code.](https://github.com/andimarafioti/tifresi)

# %%
from tifresi.hparams import HParams
from tifresi.stft import GaussTruncTF

# from tifresi.transforms import log_spectrogram
# from tifresi.transforms import inv_log_spectrogram
#NOTE: Not using Marifioties 10 log_10 transform. Instead use natural log.
# This makes a HUGE difference !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
log_spectrogram=log_scale
inv_log_spectrogram=inv_log

stft_channels = HParams.stft_channels = N_FFT 
hop_size =  HParams.hop_size  = K_HOP
print(f'{hop_size=}')
HParams.sr=16000 

# empirically set: - too small, get low-res ringing; too high, get distortion
tfresiMagSpectScale=1 # Takes the [0,1] mag spectrogram and maps it to [0, tfresiMagSpectScale]

# For faster processin, a truncated window can be used instead
stft_system = GaussTruncTF(hop_size=hop_size, stft_channels=stft_channels)
# Out:
# hop_size=128

# %% [markdown]
# <div style="background-color: honeydew">
# <h4> Plumbing  </h4>
# </div>

# %%
use_cuda = torch.cuda.is_available() #use GPU if available
print('GPU available =',use_cuda)
dtype = torch.cuda.FloatTensor if use_cuda else torch.FloatTensor
# Out:
# GPU available = True

# %%
def read_audio_spectum(filename, tifresi=True):
    #x, fs = librosa.load(filename) #x=audiodata, fs=samplerate
    x, fs  = sf.read(filename)
    print(f'input file sample rate = {fs}')
    print(f'{len(x)=}')
    print(f'{hop_size=}')

#     x=x+np.random.normal(scale=.0001, size=N_SAMPLES)
    print(f'np.mod(len(x), stft_channels) = {np.mod(len(x), stft_channels)}')
    if tifresi :
        #x=np.append(x, np.zeros((hop_size-np.mod(len(x), hop_size))))
        x=np.append(x, np.zeros(stft_channels-np.mod(len(x), stft_channels)))
    print(f'{len(x)=}, {np.mod(len(x), hop_size)=}')
    print(f' number of hops is {len(x)//hop_size}')
    
    N_SAMPLES = len(x)
    if tifresi :
        print(f'In read audio, doing tifresi spectrogram')
#         R=tfresiMagSpectScale*stft_system.spectrogram(x)
        R=stft_system.spectrogram(x)
    else :
        print(f'In read audio, doing librosa spectrogram')
        R = np.abs(librosa.stft(x, n_fft=N_FFT, hop_length=K_HOP, win_length=N_FFT,  center=False))    
        
    print(f'R range is  [{np.amin(R)}, {np.amax(R)}')
    print(f'K_HOP - {K_HOP} and N_FFT is {N_FFT}')
    print(f'R shape is {R.shape}')
    return R, fs


def findMinMax(img):
    return int(math.floor(np.amin(img))),int(math.ceil(np.amax(img)))

def img_scale(img,datasetMin,datasetMax,scaleMin,scaleMax):
    """scales input numpy array from [datasetMin,datasetMax] -> [scaleMin,scaleMax]"""    
    shift = (scaleMax-scaleMin) / (datasetMax-datasetMin)
    scaled_values = shift * (img-datasetMin) + scaleMin
    print("img_scale: Using [{0},{1}] -> [{2},{3}] for scale conversion".format(datasetMin,datasetMax,scaleMin,scaleMax))
    return scaled_values

def img_invscale(img,datasetMin,datasetMax,scaleMin,scaleMax):
    """scales input numpy array from [scaleMin,scaleMax] -> [datasetMin,datasetMax]"""
    shift = (datasetMax-datasetMin) / (scaleMax-scaleMin)
    scaled_values = shift * (img-scaleMin) + datasetMin
    print("img_invscale: Using [{0},{1}] -> [{2},{3}] for inverse scale conversion".format(scaleMin,scaleMax,datasetMin,datasetMax))
    return scaled_values
    
#if 0
    # use below functions to use librosa db scale, normalized to [0,1]
    # note that this scaling does not work well for style transfer
    def db_scale(img,scale=80):
        img = librosa.amplitude_to_db(img)
        shift = float(np.amax(img))
        img = img - shift #put max at 0
        img = img/scale #scale from [-80,0] to [-1,0]
        img = img + 1. #shift to [0,1]
        img = np.maximum(img, 0) #clip anything below 0
        return img, shift

    def inv_db(img,shift,scale=80):
        img = img - 1. #shift from [0,1] to [-1,0]
        img = img * scale #[-1,0] -> [-80,0]
        img = img + shift
        img = librosa.db_to_amplitude(img)    
        return img

# %% [markdown]
# <div style="background-color: #AAFFAA">
# <h4> Prepare input and inspect.  </h4>
# </div>

# %%
R, fs = read_audio_spectum(STYLE_FILENAME, tifresi)
print(f"raw spectrogram R range before log and scaling: [{np.amin(R)},{np.amax(R)}] ")
# Out:
# input file sample rate = 16000
# len(x)=111428
# hop_size=128
# np.mod(len(x), stft_channels) = 324
# len(x)=111428, np.mod(len(x), hop_size)=68
#  number of hops is 870
# In read audio, doing librosa spectrogram
# R range is  [2.7971532049993745e-06, 8.463823396576199
# K_HOP - 128 and N_FFT is 512
# R shape is (257, 867)
# raw spectrogram R range before log and scaling: [2.7971532049993745e-06,8.463823396576199]

# %%
if tifresi :
    print('TIFResi: log_spectrogram')
    a_style = log_spectrogram(R)
    
else :
    print('HUZ: log_scase')
    a_style = log_scale(R)
    
print(f"    LOG    range before scaling: [{np.amin(a_style)},{np.amax(a_style)}]",)
print(f'shape of a_style is {a_style.shape}')
# Out:
# HUZ: log_scase
#     LOG    range before scaling: [2.7971492929736436e-06,2.247476465954237]
# shape of a_style is (257, 867)

# %%
if use01scale == True:
    a_min,a_max = findMinMax(a_style)
    a_style = img_scale(a_style,a_min,a_max,0,1)

# %%
"""we plot out the STFT magnitude range and the spectrogram do get a feel of the data"""
#plt.ion()
fig = plt.figure()
plt.title('Histogram of log Style Spectrogram vals')
ax = fig.add_subplot(111)
#n,b,_ = ax.hist(a_style.flatten(),bins='auto')
n,b,_ = ax.hist(a_style.flatten(),bins=100)
#ax.set_yticklabels([])
#ax.set_xticks([])
maxbin = np.argmax(n)
plt.show()
print("Max bin:",b[maxbin])

plt.figure(figsize=(10, 5))
plt.title('Style spectrogram')
plt.imshow(a_style, origin='lower')
print("Style spectrogram range after scaling:",np.amin(a_style),np.amax(a_style))
print("mean and std = ",np.mean(a_style),np.std(a_style))
temp_a_style=a_style # for reality check in next cell
# Out:
# Max bin: 2.7971492929736436e-06
# Style spectrogram range after scaling: 2.7971492929736436e-06 2.247476465954237
# mean and std =  0.06033450013220179 0.19112182260534913

# %%
if 0 : #RUN PGHI ON THE ORIGINAL INPUT DATA SPECTROGRAM  - ASSUMING TFRESI for the little experiment in this cell
    # now invert it, just like we will do with the GAN-generated images

    #SPECTOFFSET
    SPECTOFFSET=0 #.25

    lspect=a_style
    print(f' shape of lspect is {lspect.shape}')
    print(use01scale)
    
    #ASSUMING TIFRES
    print('TIFResi: inv_log_spectrogram')
    if use01scale == True:
#         foo = img_invscale(lspect,a_min,a_max,0,1)
        out_spec = inv_log_spectrogram(lspect+ SPECTOFFSET) 
#         print(f'   RESCALED: Min/Max of outputs:  {np.amin(out_spec)},{np.amax(out_spec)}') # check values make sense

    else:
        out_spec =inv_log_spectrogram(lspect+SPECTOFFSET) 
#         print(f'   inv_log_spectrogram: Min/Max of outputs:  {np.amin(out_spec)},{np.amax(out_spec)}') # check values make sense

    print(f' shape of out_spec is {out_spec.shape}')
#     bar = np.clip(out_spec, 0,None)
#     print(f' shape of bar is {bar.shape}')

#     print(f'Min/Max of spectrogram: {np.amin(bar)}, {np.amax(bar)}') # check values make sense
    x = stft_system.invert_spectrogram(out_spec) 

    display(Audio(x, rate=16000, autoplay=True))

# %%
N_SAMPLES = a_style.shape[1] #time bins
N_FREQ = a_style.shape[0] #freq bins

a_style = np.ascontiguousarray(a_style[None,None,:,:]) #[batch,channels,freq,samples]
if whichChannel == "2d":
    a_style = torch.from_numpy(a_style) #pytorch:[batch,channels(1),height(freq),width(samples)]
elif whichChannel == "freq":
    a_style = torch.from_numpy(a_style).permute(0,2,1,3) #pytorch:[batch,channels(freq),height(1),width(samples)]
elif whichChannel == "time":
    a_style = torch.from_numpy(a_style).permute(0,3,1,2) #pytorch:[batch,channels(samples),height(1),width(freq)]

style_img = Variable(a_style).type(dtype) #convert to pytorch variable
print("Using whichChannel ==",whichChannel," Input shape:",style_img.data.shape) #check shape is correct
# Out:
# Using whichChannel == freq  Input shape: torch.Size([1, 257, 1, 867])

# %%
def imshow(tensor, n_freqs, n_samples, channels=1, title=None, origin='lower'):
    """ transforms pytorch tensor to numpy array and plots it out """
    
    image = tensor.clone().cpu()  # we clone the tensor to not do changes on it
    if whichChannel == "2d":
        image = image
    if whichChannel == "freq":
        image = image.permute(0,2,1,3).contiguous() # get the dimensions in proper order
    elif whichChannel == "time":
        image = image.permute(0,2,3,1).contiguous() # get the dimensions in proper order
    image = image.view(n_freqs, n_samples)  # remove the fake batch dimension
    
    image = image.numpy() #convert pytorch tensor to numpy array
    print(image.shape) #check shape
    print("Output range:",np.amin(image),np.amax(image))
    print("mean and sigma:",np.mean(image),np.std(image))
    
    
    plt.imshow(image, origin=origin)
    if title is not None:
        plt.title(title)
    plt.pause(0.001) # pause a bit so that plots are updated
    return image #return numpy array

"Just to check we can get back the numpy array with the correct shape"
plt.figure(figsize=(10, 5))
plt.figure()
_=imshow(style_img.data, N_FREQ, N_SAMPLES, title='Style Spectrogram', origin='lower')

#plt.figure()
#imshow(content_img.data, title='Content Image')
# Out:
# (257, 867)
# Output range: 2.7971494e-06 2.2474766
# mean and sigma: 0.060334504 0.19112183

# %% [markdown]
# <div style="background-color: #FF4488">
# <h4> BeginNetwork   </h4>
# </div>

# %% [markdown]
# <div style="background-color: #AAFFAA">
# <h4> Create network   </h4>
# </div>

# %%
"Here we create the custom network"
import collections as c

if whichChannel == "2d":
    IN_CHANNELS = 1
elif whichChannel == "freq":
    IN_CHANNELS = N_FREQ
elif whichChannel == "time":
    IN_CHANNELS = N_SAMPLES
    

# custom weights initialization
def weights_init(m,hor_filter):
    std = np.sqrt(2) * np.sqrt(2.0 / ((N_FREQ + N_FILTERS) * hor_filter))
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
#         torch.nn.init.xavier_uniform_(m.weight)
#         m.bias.data.fill_(0.01)
        m.weight.data.normal_(0.0, std)

class style_net(nn.Module):
    """Here create the network you want to use by adding/removing layers in nn.Sequential"""
    def __init__(self,hor_filter):
        super(style_net, self).__init__()
#         self.hor_filter=hor_filter
        self.layers = nn.Sequential(c.OrderedDict([
                            ('conv1',nn.Conv2d(IN_CHANNELS,N_FILTERS,kernel_size=(1,hor_filter),bias=False)),
                            ('relu1',nn.ReLU())#,
#                             ('max1', nn.MaxPool2d(kernel_size=(1,2))),
            
#                             ('conv2',nn.Conv2d(N_FILTERS,N_FILTERS//2,kernel_size=(1,hor_filter),bias=False)),
#                             ('relu2',nn.ReLU()),
#                             ('max2', nn.MaxPool2d(kernel_size=(1,2))),
            
#                             ('conv3',nn.Conv2d(N_FILTERS//2,N_FILTERS//4,kernel_size=(1,hor_filter),bias=False)),
#                             ('relu3',nn.ReLU())
        ]))

                            #('relu2',nn.ReLU()),
                            #('max2', nn.MaxPool2d(kernel_size=(1,2))),


                            #('conv3',nn.Conv2d(N_FILTERS//2,N_FILTERS//2,kernel_size=(1,hor_filter),bias=False)),
                            #('relu3',nn.ReLU()),
                            #('max3', nn.MaxPool2d(kernel_size=(1,2))),

                            #('conv4',nn.Conv2d(N_FILTERS//2,N_FILTERS//4,kernel_size=(1,hor_filter),bias=False)),
                            #('relu4',nn.ReLU()),
                            #('max4', nn.MaxPool2d(kernel_size=(1,2))),


                            #('conv5',nn.Conv2d(N_FILTERS//4,N_FILTERS//4,kernel_size=(1,hor_filter),bias=False)),
                            #('relu5',nn.ReLU()),
                            #('max5', nn.MaxPool2d(kernel_size=(1,2))),


                            #('conv6',nn.Conv2d(N_FILTERS//4,N_FILTERS//8,kernel_size=(1,hor_filter),bias=False)),
                            #('relu6',nn.ReLU())]))

    def forward(self,input):
        out = self.layers(input)
        return out
    
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~    
cnnlist=[] 
#MS create a separate CNN for each stream
for j in range(numStreams) :
    cnn = style_net(hor_filters[j])
    cnn.apply(lambda x, f=hor_filters[j]: weights_init(x,f))
    for param in cnn.parameters():
        param.requires_grad = False
    print(list(cnn.layers))

    # move it to the GPU if possible:
    if use_cuda:
        cnn = cnn.cuda()
    
    cnnlist.append(cnn)

# Add the style/content loss 'layer' after the specified layer:
content_layers_default = [] #ignore for now
# style_layers_default = ['relu_1']
style_layers_default = ['relu_1']
# Out:
# [Conv2d(257, 512, kernel_size=(1, 2), stride=(1, 1), bias=False), ReLU()]
# [Conv2d(257, 512, kernel_size=(1, 4), stride=(1, 1), bias=False), ReLU()]
# [Conv2d(257, 512, kernel_size=(1, 8), stride=(1, 1), bias=False), ReLU()]
# [Conv2d(257, 512, kernel_size=(1, 16), stride=(1, 1), bias=False), ReLU()]
# [Conv2d(257, 512, kernel_size=(1, 64), stride=(1, 1), bias=False), ReLU()]
# [Conv2d(257, 512, kernel_size=(1, 128), stride=(1, 1), bias=False), ReLU()]

# %% [markdown]
# Content loss
# ~~~~~~~~~~~~
#
# The content loss is a function that takes as input the feature maps
# $F_{XL}$ at a layer $L$ in a network fed by $X$ and
# return the weigthed content distance $w_{CL}.D_C^L(X,C)$ between
# this image and the content image. Hence, the weight $w_{CL}$ and
# the target content $F_{CL}$ are parameters of the function. We
# implement this function as a torch module with a constructor that takes
# these parameters as input. The distance $\|F_{XL} - F_{YL}\|^2$ is
# the Mean Square Error between the two sets of feature maps, that can be
# computed using a criterion ``nn.MSELoss`` stated as a third parameter.
#
# We will add our content losses at each desired layer as additive modules
# of the neural network. That way, each time we will feed the network with
# an input image $X$, all the content losses will be computed at the
# desired layers and, thanks to autograd, all the gradients will be
# computed. For that, we just need to make the ``forward`` method of our
# module returning the input: the module becomes a ''transparent layer''
# of the neural network. The computed loss is saved as a parameter of the
# module.
#
# Finally, we define a fake ``backward`` method, that just call the
# backward method of ``nn.MSELoss`` in order to reconstruct the gradient.
# This method returns the computed loss: this will be useful when running
# the gradient descent in order to display the evolution of style and
# content losses.

# %%
class ContentLoss(nn.Module):
    """Since doing texture only we ignore this for now"""

    def __init__(self, target, weight): #weight here is the epsilon tuning (how much content vs style)
        super(ContentLoss, self).__init__()
        # we 'detach' the target content from the tree used
        self.target = target.detach() * weight
        # to dynamically compute the gradient: this is a stated value,
        # not a variable. Otherwise the forward method of the criterion
        # will throw an error.
        self.weight = weight
        self.criterion = nn.MSELoss()

    def forward(self, input):
        self.loss = self.criterion(input * self.weight, self.target)
        self.output = input
        return self.output

    def backward(self, retain_variables=True):
        self.loss.backward(retain_variables=retain_variables)
        return self.loss

# %% [markdown]
# .. Note::
#    **Important detail**: this module, although it is named ``ContentLoss``,
#    is not a true PyTorch Loss function. If you want to define your content
#    loss as a PyTorch Loss, you have to create a PyTorch autograd Function
#    and to recompute/implement the gradient by the hand in the ``backward``
#    method.
#
# Style loss
# ~~~~~~~~~~
#
# For the style loss, we need first to define a module that compute the
# gram produce $G_{XL}$ given the feature maps $F_{XL}$ of the
# neural network fed by $X$, at layer $L$. Let
# $\hat{F}_{XL}$ be the re-shaped version of $F_{XL}$ into a
# $K$\ x\ $N$ matrix, where $K$ is the number of feature
# maps at layer $L$ and $N$ the lenght of any vectorized
# feature map $F_{XL}^k$. The $k^{th}$ line of
# $\hat{F}_{XL}$ is $F_{XL}^k$. We let you check that
# $\hat{F}_{XL} \cdot \hat{F}_{XL}^T = G_{XL}$. Given that, it
# becomes easy to implement our module:

# %%
# create random feature projection matrix
RFM={}

# This is the "sparse" Achlioptas matrix
if RANDOM_PROJECTION=="Sparse" : 
    RFM[1024]=torch.from_numpy(np.random.choice(np.sqrt(3)*np.array([1., 0., -1.]), (1024,int(1024/RFMSCALEFACTOR)), p=[1./6.,2./3., 1./6.])).type(dtype)
    RFM[512]=torch.from_numpy(np.random.choice(np.sqrt(3)*np.array([1., 0., -1.]), (512,int(512/RFMSCALEFACTOR)), p=[1./6.,2./3., 1./6.])).type(dtype)
    RFM[256]=torch.from_numpy(np.random.choice(np.sqrt(3)*np.array([1., 0., -1.]), (256,int(256/RFMSCALEFACTOR)), p=[1./6.,2./3., 1./6.])).type(dtype)
    RFM[128]=torch.from_numpy(np.random.choice(np.sqrt(3)*np.array([1., 0., -1.]), (128,int(128/RFMSCALEFACTOR)), p=[1./6.,2./3., 1./6.])).type(dtype)

#Full orthonormal gaussian 
if RANDOM_PROJECTION=="Gaussian" : 
    RFM[1024]=(torch.from_numpy(ortho_group.rvs(1024)[:int(1024/RFMSCALEFACTOR)]).type(dtype)).unsqueeze(0)
    RFM[512]= (torch.from_numpy(ortho_group.rvs(512)[: int(512/RFMSCALEFACTOR)]).type(dtype)).unsqueeze(0)
    RFM[256]= (torch.from_numpy(ortho_group.rvs(256)[: int(256/RFMSCALEFACTOR)]).type(dtype)).unsqueeze(0)
    RFM[128]= (torch.from_numpy(ortho_group.rvs(128)[: int(128/RFMSCALEFACTOR)]).type(dtype)).unsqueeze(0)
    for rm in range(1, RFMSTACK) : 
        #RFM[1024]= torch.cat( (RFM[1024], (torch.from_numpy(ortho_group.rvs(1024)[:int(1024/RFMSCALEFACTOR)]).type(dtype)).unsqueeze(0)), dim=0)
        RFM[512]=torch.cat( (RFM[512],    (torch.from_numpy(ortho_group.rvs(512)[ :int(512/RFMSCALEFACTOR)]).type(dtype)).unsqueeze(0)), dim=0)
        #RFM[256]=torch.cat( (RFM[256],    (torch.from_numpy(ortho_group.rvs(256)[ :int(256/RFMSCALEFACTOR)]).type(dtype)).unsqueeze(0)), dim=0)
        #RFM[128]=torch.cat( (RFM[128],    (torch.from_numpy(ortho_group.rvs(128)[ :int(128/RFMSCALEFACTOR)]).type(dtype)).unsqueeze(0)), dim=0)

# %%
class GramMatrix(nn.Module):

    def forward(self, input):
        a, b, c, d = input.size() #a=batch size(=1)
                                  #b=number of feature maps
                                  #(c,d)=dimensions of a feat. map (N=c*d) -> for 1D conv c=1
        #features = input.view(a * b, c * d)  # resise F_XL into \hat F_XL
        features = input.view(b, a * c * d)  # resise F_XL into \hat F_XL
        
       # features2=torch.matmul(RFM[:b//2,:b], features)
        if RANDOM_PROJECTION=="None":
            features2=features.unsqueeze(0)
        else :
            features2=torch.matmul(RFM[b], features)
        #print(f"In GramMatrix, shape of features = {np.shape(features2)}")

        #G = torch.matmul(features2, features2.t())  # compute the gram product #normalizing? - length of the features
        G = torch.matmul(features2, torch.transpose(features2, 1,2))  # compute the gram product #normalizing? - length of the features
        #print(f"In GramMatrix, shape of grammatrix = {np.shape(G)}")
        # we 'normalize' the values of the gram matrix
        # by dividing by the number of element in each feature maps.
        return G.div(a * c * d)

# %%
class GramMatrix_justfoolinaround_notused(nn.Module):
#class GramMatrix(nn.Module):
    def forward(self, input, recurse=2):
        if recurse==0 :
            return input
        
        a, b, c, d = input.size() #a=batch size(=1)
                                  #b=number of feature maps
                                  #(c,d)=dimensions of a feat. map (N=c*d) -> for 1D conv c=1
        #features = input.view(a * b, c * d)  # resise F_XL into \hat F_XL
        features = input.view(b, a * c * d)  # resise F_XL into \hat F_XL
        
        ##print(f"Grammatrix.forward: {input.size() =}")
        
       # features2=torch.matmul(RFM[:b//2,:b], features)
        if RANDOM_PROJECTION=="None":
            features2=features.unsqueeze(0)
        else :
            features2=torch.matmul(RFM[b], features)
        #print(f"In GramMatrix, shape of features = {np.shape(features2)}")

        #G = torch.matmul(features2, features2.t())  # compute the gram product #normalizing? - length of the features
        G = torch.matmul(features2, torch.transpose(features2, 1,2))  # compute the gram product #normalizing? - length of the features
        #print(f"In GramMatrix, shape of grammatrix = {np.shape(G)}")
        # we 'normalize' the values of the gram matrix
        # by dividing by the number of element in each feature maps.
        ##print(f"Grammatrix.forward: {G.div(a * c * d).size() =}")
        aa, bb, cc = G.size()
        return self.forward(G.div(a * c * d).reshape(1,bb*cc,1,aa), recurse=recurse-1)

# %% [markdown]
# The longer is the feature maps dimension $N$, the bigger are the
# values of the gram matrix. Therefore, if we don't normalize by $N$,
# the loss computed at the first layers (before pooling layers) will have
# much more importance during the gradient descent. We dont want that,
# since the most interesting style features are in the deepest layers!
#
# Then, the style loss module is implemented exactly the same way than the
# content loss module, but we have to add the ``gramMatrix`` as a
# parameter:

# %%
#foofoo
class StyleLoss(nn.Module):

    def __init__(self, target, weight, layer): #weight here is the alpha tuning (how much content vs style)
        super(StyleLoss, self).__init__()
        self.target = target.detach() * weight
        self.weight = weight
        self.gram = GramMatrix()
        self.criterion = nn.MSELoss(size_average=False)
        #print(f'Creating StyleLoss module - this one for layer {layer} with target shape {target.shape}' )


    def forward(self, input):
        #print(f' StyleLoss.forward with input of shape {input.shape}')
        self.output = input.clone()
        self.G = self.gram(input)
        self.G.mul_(self.weight)
        self.loss = self.criterion(self.G, self.target) #/sum(sum(self.target**2)) #target=gram mat for style img, G=gram mat for current input ie. noise
        return self.output

    def backward(self, retain_variables=True):
        self.loss.backward(retain_graph=True)
        return self.loss

# %%
class OptReg(nn.Module):
    """soft bound the optimization between [lower,upper] by regularization"""
    
    def __init__(self, upper, lower, weight=1): #weight here is the alpha tuning (how much content vs style)
        super(OptReg, self).__init__()
        self.upper = Variable(torch.cuda.FloatTensor([upper]))
        self.lower = Variable(torch.cuda.FloatTensor([lower]))
        self.weight = weight

    def forward(self, input):
        #self.output = input.clone()
        self.zeros = Variable(torch.zeros(input.size()).type(dtype))
                              
        self.over = torch.max(input-self.upper,self.zeros)
        self.under = torch.max(self.lower-input,self.zeros)
        self.total= self.over + self.under
        self.l2total = self.weight * self.total.norm(2)
        #print(f'OptReg l2total = {self.l2total}')
        return self.l2total

# %% [raw]
# a = Variable(torch.cuda.FloatTensor([[2,0,2],[1,0,1]]))
# b = Variable(torch.cuda.FloatTensor([[5,0,5],[-1,0,-1]]))
# c = Variable(torch.cuda.FloatTensor([1]))
# d = c-a
# print(d)
# e = torch.max(d,b)
# f = e+e
# print(f)
# g = f.norm(2)
# print(g)
#
# def optbound_regularizer_old(img,upper,lower):
#     """soft bound the optimization between [lower,upper] by regularization"""
#     #print(torch.max(img),torch.min(img))
#     imgn = Variable(img)
#     over = torch.max(imgn.data-upper,torch.zeros(img.size()).type(dtype))
#     #print("over",over)
#     under = torch.max(lower-imgn.data,torch.zeros(img.size()).type(dtype))
#     #print("under",under)
#     out = over + under
#     #print("out",out)
#     out = out.norm(2)
#     #print("norm",out)
#     #l2_reg = torch.cuda.FloatTensor([out])
#     l2_reg = Variable(torch.cuda.FloatTensor([out]), requires_grad=True)
#
#     return l2_reg
#
# def optbound_regularizer(img,upper,lower,reg_weight):
#     """soft bound the optimization between [lower,upper] by regularization"""
#     #print(torch.max(img),torch.min(img))
#     zero_var = Variable(torch.zeros(img.size()).type(dtype))
#     over = Variable(torch.max(img-upper,torch.zeros(img.size()).type(dtype)), requires_grad=True)
#     crit_over = nn.MSELoss(size_average=False)
#     over_loss = crit_over(over,zero_var)
#     #print("over",over)
#     under = Variable(torch.max(lower-img,torch.zeros(img.size()).type(dtype)), requires_grad=True)
#     crit_under = nn.MSELoss(size_average=False)
#     under_loss = crit_under(under,zero_var)
#     #print("under",under)
#     out = over_loss + under_loss
#     #print("out",out)
#     #out = out.norm(2)
#     #print("norm",out)
#     #l2_reg = torch.cuda.FloatTensor([out])
#     #l2_reg = Variable(torch.cuda.FloatTensor([out]), requires_grad=True)
#     out = reg_weight * out
#     #optbound = out.backward(retain_graph=True)
#
#     return out #optbound

# %% [markdown]
# Load the neural network
# ~~~~~~~~~~~~~~~~~~~~~~~
#
# Now, we have to import a pre-trained neural network. As in the paper, we
# are going to use a pretrained VGG network with 19 layers (VGG19).
#
# PyTorch's implementation of VGG is a module divided in two child
# ``Sequential`` modules: ``features`` (containing convolution and pooling
# layers) and ``classifier`` (containing fully connected layers). We are
# just interested by ``features``:

# %% [markdown]
# A ``Sequential`` module contains an ordered list of child modules. For
# instance, ``vgg19.features`` contains a sequence (Conv2d, ReLU,
# Maxpool2d, Conv2d, ReLU...) aligned in the right order of depth. As we
# said in *Content loss* section, we wand to add our style and content
# loss modules as additive 'transparent' layers in our network, at desired
# depths. For that, we construct a new ``Sequential`` module, in wich we
# are going to add modules from ``vgg19`` and our loss modules in the
# right order:

# %%
#rebuild network with the layers we want
def get_style_model_and_losses(cnn, style_img, content_img=None,
                               style_weight=1, content_weight=0,
                               content_layers=content_layers_default,
                               style_layers=style_layers_default, style_img2=None):
    cnn = copy.deepcopy(cnn)

    # just in order to have an iterable access to or list of content/syle losses
    content_losses = []
    style_losses = []
    
    model = nn.Sequential()
    layer_list = list(cnn.layers)
    
    gram = GramMatrix()  # we need a gram module in order to compute style targets

    # move these modules to the GPU if possible:
    if use_cuda:
        model = model.cuda()
        gram = gram.cuda()

    #here we rebuild the network adding the in content and style loss "layers"   
    i = 1  
    for layer in layer_list:
        
        if isinstance(layer, nn.Conv2d): #if layer in vgg19 belong to class nn.Conv2d
            name = "conv_" + str(i)
            model.add_module(name, layer) #add that layer to our sequential model
            
            if content_img != None:
                if name in content_layers: #at the right depth add the content loss "layer"
                    # add content loss:
                    target = model(content_img).clone()
                    content_loss = ContentLoss(target, content_weight)
                    model.add_module("content_loss_" + str(i), content_loss)
                    content_losses.append(content_loss)

            if name in style_layers: #at the right depth add the content loss "layer"
                # add style loss:
                target_feature = model(style_img).clone()
                target_feature_gram = gram(target_feature)
                style_loss = StyleLoss(target_feature_gram, style_weight, name)
                model.add_module("style_loss_" + str(i), style_loss)
                style_losses.append(style_loss)

        if isinstance(layer, nn.ReLU): #do the same for ReLUs
            name = "relu_" + str(i)
            model.add_module(name, layer)
            
            if content_img != None:
                if name in content_layers:
                    # add content loss:
                    target = model(content_img).clone()
                    content_loss = ContentLoss(target, content_weight)
                    model.add_module("content_loss_" + str(i), content_loss)
                    content_losses.append(content_loss)

            if name in style_layers:
                # add style loss:
                target_feature = model(style_img).clone()
                target_feature_gram = gram(target_feature)
                style_loss = StyleLoss(target_feature_gram, style_weight, name)
                model.add_module("style_loss_" + str(i), style_loss)
                style_losses.append(style_loss) 
                
            i += 1

        if isinstance(layer, nn.MaxPool2d): #do the same for maxpool
            name = "pool_" + str(i)
            model.add_module(name, layer)
            
            if name in style_layers:
                # add style loss:
                target_feature = model(style_img).clone()
                target_feature_gram = gram(target_feature)
                style_loss = StyleLoss(target_feature_gram, style_weight, name)
                model.add_module("style_loss_" + str(i), style_loss)
                style_losses.append(style_loss)
            
            #avgpool = nn.AvgPool2d(kernel_size=(1,2),
            #                stride=layer.stride, padding = layer.padding)
            #model.add_module(name, avgpool)  # *** can also replace certain layers if we want eg. maxpool -> avgpool


    #for param in model.parameters():
    #    param.requires_grad = False
    return model, style_losses, content_losses

# %% [markdown]
# .. Note::
#    In the paper they recommend to change max pooling layers into
#    average pooling. With AlexNet, that is a small network compared to VGG19
#    used in the paper, we are not going to see any difference of quality in
#    the result. However, you can use these lines instead if you want to do
#    this substitution:
#
#    ::
#
#        # avgpool = nn.AvgPool2d(kernel_size=layer.kernel_size,
#        #                         stride=layer.stride, padding = layer.padding)
#        # model.add_module(name,avgpool)

# %% [markdown]
# Input image
# ~~~~~~~~~~~
#
# Again, in order to simplify the code, we take an image of the same
# dimensions than content and style images. This image can be a white
# noise, or it can also be a copy of the content-image.

# %% [markdown]
# <div style="background-color: #AAFFAA">
# <h4> Prepare noise as input  </h4>
# </div>

# %%
"""image to input in generative network"""
#input_img = content_img.clone()

# if you want to use a white noise instead uncomment the below line:
#input_img = Variable(torch.randn(content_img.data.size())).type(dtype)

def in_img(n_freqs, nsamples):
    """initialize (runs) number of unique random noise input images"""  
    input_imgs = []
    #rand_tensor = torch.randn(1,n_freqs,1,nsamples)*1e-3
#     lower,upper,mu,sigma = 1e-3,1,.5,1e-1
#     lower,upper,mu,sigma = -50,0,-45,7
    lower,upper,mu,sigma = 1e-9,0.7,0.001,0.01

    dist = stats.truncnorm((lower-mu)/sigma,(upper-mu)/sigma,loc=mu,scale=sigma)
    
    i = 0
    while i < runs:
         #[batch,channels,h,w]
        if whichChannel == "2d":
            samples = dist.rvs([1,1,n_freqs,nsamples])
            input_imgs.append(Variable(torch.from_numpy(samples)).type(dtype))
            #input_imgs.append(Variable(torch.rand(1,1,n_freqs,nsamples)*1e-3).type(dtype))
            #input_imgs.append(Variable(torch.randn(1,1,n_freqs,nsamples)*1e-3).type(dtype))
        if whichChannel == "freq":
            #samples = dist.rvs([1,n_freqs,1,nsamples])
            #input_imgs.append(Variable(torch.from_numpy(samples)).type(dtype))
            #input_imgs.append(Variable(torch.rand(1,n_freqs,1,nsamples)*1e-3).type(dtype))
            input_imgs.append(Variable(mu+torch.randn(1,n_freqs,1,nsamples)*1e-2).type(dtype))
        elif whichChannel == "time":
            samples = dist.rvs([1,nsamples,1,n_freqs])
            input_imgs.append(Variable(torch.from_numpy(samples)).type(dtype))
            #input_imgs.append(Variable(torch.rand(1,nsamples,1,n_freqs)*1e-3).type(dtype))
            #input_imgs.append(Variable(torch.randn(1,nsamples,1,n_freqs)*1e-3).type(dtype))
        i +=1
    return input_imgs

input_imgs = in_img(N_FREQ, int(N_SAMPLES*SYNTHETIC_LENGTH_FACTOR))

# add the original input image to the figure:
plt.figure()
_=imshow(input_imgs[0].data, N_FREQ, int(N_SAMPLES*SYNTHETIC_LENGTH_FACTOR), title='Input Image')
# Out:
# (257, 3468)
# Output range: -0.043772202 0.052576803
# mean and sigma: 0.0010031897 0.010002029

# %% [markdown]
# Gradient descent
# ~~~~~~~~~~~~~~~~
#
# As Leon Gatys, the author of the algorithm, suggested
# `here <https://discuss.pytorch.org/t/pytorch-tutorial-for-neural-transfert-of-artistic-style/336/20?u=alexis-jacq>`__,
# we will use L-BFGS algorithm to run our gradient descent. Unlike
# training a network, we want to train the input image in order to
# minimise the content/style losses. We would like to simply create a
# PyTorch  L-BFGS optimizer, passing our image as the variable to optimize.
# But ``optim.LBFGS`` takes as first argument a list of PyTorch
# ``Variable`` that require gradient. Our input image is a ``Variable``
# but is not a leaf of the tree that requires computation of gradients. In
# order to show that this variable requires a gradient, a possibility is
# to construct a ``Parameter`` object from the input image. Then, we just
# give a list containing this ``Parameter`` to the optimizer's
# constructor:

# %%
def get_input_param_optimizer(input_img):
    # this line to show that input is a parameter that requires a gradient
    input_param = nn.Parameter(input_img.data)
    optimizer = optim.LBFGS([input_param])
    return input_param, optimizer

# %% [markdown]
# **Last step**: the loop of gradient descent. At each step, we must feed
# the network with the updated input in order to compute the new losses,
# we must run the ``backward`` methods of each loss to dynamically compute
# their gradients and perform the step of gradient descent. The optimizer
# requires as argument a "closure": a function that reevaluates the model
# and returns the loss.

# %%
def run_style_transfer(cnnlist, style_img, input_img, content_img=None, num_steps=num_steps,
                       style_weight=1, content_weight=0, reg_weight=0.01): 
    """Run the style transfer"""
    
    #MS - one model, loss accumulator, and optimizer per stream 
    modelMS=[None for j in range(numStreams)]
    style_lossesMS=[None for j in range(numStreams)] 
    content_lossesMS=[None for j in range(numStreams)]
#     optimizerMS=[None for j in range(numStreams)]

    #MS one input_param for all streams, each operating on the same data. 
    input_param = nn.Parameter(input_img.data)
    
    
    prev = input_param.data
    
    # first create the separate cnn models and losses
    for j in range(numStreams) :
        print('Building the style transfer model..')
        modelMS[j], style_lossesMS[j], content_lossesMS[j] = get_style_model_and_losses(cnnlist[j],
            style_img, content_img, style_weight, content_weight)
        #input_paramMS[j], optimizerMS[j] = get_input_param_optimizer(input_img)
        
        #input_param is the same variable passed to each separate CNN
        #MS Changed learning rate to prevent instabilities with lr=1.
#         optimizerMS[j] = optim.LBFGS([input_param], lr=learning_Rate)

        print("Input range:",torch.max(input_param.data),torch.min(input_param.data))   
        print(modelMS[j])
        print('Optimizing..')
    optimizerMS = optim.LBFGS([input_param],lr=learning_Rate)
        
    
    print(f'Created {j} MS models')
    # print(f' input_param[0] is input_param[1] ? ...... {input_paramMS[0] is input_paramMS[1]}')    # FALSE!    
    

    run = [0]
    
    if boundopt == True:
        bound = OptReg(1,0.005, reg_weight)
    

    plt.figure()
    while run[0] <= num_steps:

        run[0] += 1
        print("Current Run Number = ",run[0])
        
        #MS create the closure, and then run the optimizer for each stream in sequence
        # (the update from each stream becomes the input for the next, I think!)
        print("numStreams = ",numStreams)
        def closure():
            optimizerMS.zero_grad()
            style_score = 0
            content_score = 0
            for j in range(numStreams) :
        
            
                # correct the values of updated input image
                #if use01scale == True:
                    #input_param.data.clamp_(0, 1)

                #print("Current stream Number in closure() = ",j)
#                 optimizerMS.zero_grad()
                modelMS[j](input_param)
                

                if boundopt == True:
                    bound.zero_grad()
                    reg = bound(input_param)
                    if not torch.equal(reg.data,torch.cuda.FloatTensor([0])):
                        reg.backward()

                for sl in style_lossesMS[j]:
                    style_score += sl.backward() #call backward method to grab the loss
                #print("stylescore for run", run[0], " stream ",j ," is ",style_score)

                #for cl in content_losses:
                #    content_score += cl.backward()

                if boundopt == True:
                    total_loss = style_score + reg  #+ content_score
                else:
                    total_loss = style_score

                #run[0] += 1

                if run[0] % 10 == 0:
                    #print("reg", reg)
                    #print(torch.max(input_param.data),torch.min(input_param.data))

                    print(f"run: {run}, model[{j}]")
                    print('Style Loss : {:4f}'.format(
                        #style_score.data[0]))
                        style_score.data))
                    plt.plot(run[0],style_score.data.cpu(),'bo')
                    if boundopt == True:
                        print('Bound Loss : {:4f}'.format(
                           #reg.data[0]))
                            reg.data))
#                     print(torch.max(input_param.data),torch.min(input_param.data))
#                     print('Total Loss : {:4f}'.format(
#                         # total_loss.data[0]))
#                         total_loss.data))
#                     plt.figure()
#                     plt.imshow(input_param.data.detach().cpu().numpy().squeeze(),origin='lower')
#                     plt.title("For step %d input_param.data is "%run[0])
#                     plt.show()

            return total_loss/numStreams   #return value for closer()

            # The update to an image happens in here:
        optimizerMS.step(closure)  #optimizer.step will call closure with its closure vars; #executes 20 iterations in this one line
                
          
        # END MS loop
        
        
        
    # a last correction...
    #if use01scale == True:
        #input_param.data.clamp_(0, 1)
    plt.show()
    return input_param.data   # Can return any of the MS input_params - they all refer to the same object

# %% [markdown]
# <div style="background-color: #AAFFAA">
# <h4> Finally, run the algorithm  </h4>
# </div>

# %%
outputs = []
i = 0
while i < runs:
    
    output = run_style_transfer(cnnlist, style_img, input_imgs[i])


    plt.figure().set_size_inches(20, 20)
    out = imshow(output, N_FREQ, int(N_SAMPLES*SYNTHETIC_LENGTH_FACTOR),title='Output Image')
    outputs.append(out)
    i += 1

# sphinx_gallery_thumbnail_number = 4
#figure(figsize=(8, 6), dpi=80)
plt.show()
# Out:
# Building the style transfer model..
# Input range: tensor(0.0526, device='cuda:0') tensor(-0.0438, device='cuda:0')
# Sequential(
#   (conv_1): Conv2d(257, 512, kernel_size=(1, 2), stride=(1, 1), bias=False)
#   (relu_1): ReLU()
#   (style_loss_1): StyleLoss(
#     (gram): GramMatrix()
#     (criterion): MSELoss()
#   )
# )
# Optimizing..
# Building the style transfer model..
# Input range: tensor(0.0526, device='cuda:0') tensor(-0.0438, device='cuda:0')
# Sequential(
#   (conv_1): Conv2d(257, 512, kernel_size=(1, 4), stride=(1, 1), bias=False)
#   (relu_1): ReLU()
#   (style_loss_1): StyleLoss(
#     (gram): GramMatrix()
#     (criterion): MSELoss()
#   )
# )
# Optimizing..
# Building the style transfer model..
# Input range: tensor(0.0526, device='cuda:0') tensor(-0.0438, device='cuda:0')
# Sequential(
#   (conv_1): Conv2d(257, 512, kernel_size=(1, 8), stride=(1, 1), bias=False)
#   (relu_1): ReLU()
#   (style_loss_1): StyleLoss(
#     (gram): GramMatrix()
#     (criterion): MSELoss()
#   )
# )
# Optimizing..
# Building the style transfer model..
# Input range: tensor(0.0526, device='cuda:0') tensor(-0.0438, device='cuda:0')
# Sequential(
#   (conv_1): Conv2d(257, 512, kernel_size=(1, 16), stride=(1, 1), bias=False)
#   (relu_1): ReLU()
#   (style_loss_1): StyleLoss(
#     (gram): GramMatrix()
#     (criterion): MSELoss()
#   )
# )
# Optimizing..
# Building the style transfer model..
# Input range: tensor(0.0526, device='cuda:0') tensor(-0.0438, device='cuda:0')
# Sequential(
#   (conv_1): Conv2d(257, 512, kernel_size=(1, 64), stride=(1, 1), bias=False)
#   (relu_1): ReLU()
#   (style_loss_1): StyleLoss(
#     (gram): GramMatrix()
#     (criterion): MSELoss()
#   )
# )
# Optimizing..
# Building the style transfer model..
# Input range: tensor(0.0526, device='cuda:0') tensor(-0.0438, device='cuda:0')
# Sequential(
#   (conv_1): Conv2d(257, 512, kernel_size=(1, 128), stride=(1, 1), bias=False)
#   (relu_1): ReLU()
#   (style_loss_1): StyleLoss(
#     (gram): GramMatrix()
#     (criterion): MSELoss()
#   )
# )
# Optimizing..
# Created 5 MS models
# Current Run Number =  1
# numStreams =  6
# Current Run Number =  2
# numStreams =  6
# Current Run Number =  3
# numStreams =  6
# Current Run Number =  4
# numStreams =  6
# Current Run Number =  5
# numStreams =  6
# Current Run Number =  6
# numStreams =  6
# Current Run Number =  7
# numStreams =  6
# Current Run Number =  8
# numStreams =  6
# Current Run Number =  9
# numStreams =  6
# Current Run Number =  10
# numStreams =  6
# run: [10], model[0]
# Style Loss : 14.236298
# run: [10], model[1]
# Style Loss : 25.868946
# run: [10], model[2]
# Style Loss : 33.654156
# run: [10], model[3]
# Style Loss : 39.096870
# run: [10], model[4]
# Style Loss : 44.855659
# run: [10], model[5]
# Style Loss : 50.574303
# run: [10], model[0]
# Style Loss : 14.232994
# run: [10], model[1]
# Style Loss : 25.862234
# run: [10], model[2]
# Style Loss : 33.645119
# run: [10], model[3]
# Style Loss : 39.086357
# run: [10], model[4]
# Style Loss : 44.843239
# run: [10], model[5]
# Style Loss : 50.559959
# run: [10], model[0]
# Style Loss : 14.229632
# run: [10], model[1]
# Style Loss : 25.855404
# run: [10], model[2]
# Style Loss : 33.635918
# run: [10], model[3]
# Style Loss : 39.075657
# run: [10], model[4]
# Style Loss : 44.830601
# run: [10], model[5]
# Style Loss : 50.545364
# run: [10], model[0]
# Style Loss : 14.226213
# run: [10], model[1]
# Style Loss : 25.848450
# run: [10], model[2]
# Style Loss : 33.626556
# run: [10], model[3]
# Style Loss : 39.064770
# run: [10], model[4]
# Style Loss : 44.817741
# run: [10], model[5]
# Style Loss : 50.530518
# run: [10], model[0]
# Style Loss : 14.222734
# run: [10], model[1]
# Style Loss : 25.841377
# run: [10], model[2]
# Style Loss : 33.617039
# run: [10], model[3]
# Style Loss : 39.053703
# run: [10], model[4]
# Style Loss : 44.804676
# run: [10], model[5]
# Style Loss : 50.515434
# run: [10], model[0]
# Style Loss : 14.219195
# run: [10], model[1]
# Style Loss : 25.834179
# run: [10], model[2]
# Style Loss : 33.607353
# run: [10], model[3]
# Style Loss : 39.042446
# run: [10], model[4]
# Style Loss : 44.791382
# run: [10], model[5]
# Style Loss : 50.500088
# run: [10], model[0]
# Style Loss : 14.215594
# run: [10], model[1]
# Style Loss : 25.826853
# run: [10], model[2]
# Style Loss : 33.597492
# run: [10], model[3]
# Style Loss : 39.030987
# run: [10], model[4]
# Style Loss : 44.777859
# run: [10], model[5]
# Style Loss : 50.484478
# run: [10], model[0]
# Style Loss : 14.211930
# run: [10], model[1]
# Style Loss : 25.819397
# run: [10], model[2]
# Style Loss : 33.587463
# run: [10], model[3]
# Style Loss : 39.019333
# run: [10], model[4]
# Style Loss : 44.764103
# run: [10], model[5]
# Style Loss : 50.468605
# run: [10], model[0]
# Style Loss : 14.208204
# run: [10], model[1]
# Style Loss : 25.811813
# run: [10], model[2]
# Style Loss : 33.577263
# run: [10], model[3]
# Style Loss : 39.007484
# run: [10], model[4]
# Style Loss : 44.750122
# run: [10], model[5]
# Style Loss : 50.452469
# run: [10], model[0]
# Style Loss : 14.204412
# run: [10], model[1]
# Style Loss : 25.804092
# run: [10], model[2]
# Style Loss : 33.566879
# run: [10], model[3]
# Style Loss : 38.995422
# run: [10], model[4]
# Style Loss : 44.735893
# run: [10], model[5]
# Style Loss : 50.436050
# run: [10], model[0]
# Style Loss : 14.200554
# run: [10], model[1]
# Style Loss : 25.796234
# run: [10], model[2]
# Style Loss : 33.556313
# run: [10], model[3]
# Style Loss : 38.983150
# run: [10], model[4]
# Style Loss : 44.721420
# run: [10], model[5]
# Style Loss : 50.419353
# run: [10], model[0]
# Style Loss : 14.196630
# run: [10], model[1]
# Style Loss : 25.788240
# run: [10], model[2]
# Style Loss : 33.545570
# run: [10], model[3]
# Style Loss : 38.970676
# run: [10], model[4]
# Style Loss : 44.706707
# run: [10], model[5]
# Style Loss : 50.402382
# run: [10], model[0]
# Style Loss : 14.192636
# run: [10], model[1]
# Style Loss : 25.780104
# run: [10], model[2]
# Style Loss : 33.534634
# run: [10], model[3]
# Style Loss : 38.957981
# run: [10], model[4]
# Style Loss : 44.691734
# run: [10], model[5]
# Style Loss : 50.385113
# run: [10], model[0]
# Style Loss : 14.188574
# run: [10], model[1]
# Style Loss : 25.771822
# run: [10], model[2]
# Style Loss : 33.523506
# run: [10], model[3]
# Style Loss : 38.945065
# run: [10], model[4]
# Style Loss : 44.676510
# run: [10], model[5]
# Style Loss : 50.367554
# run: [10], model[0]
# Style Loss : 14.184439
# run: [10], model[1]
# Style Loss : 25.763393
# run: [10], model[2]
# Style Loss : 33.512180
# run: [10], model[3]
# Style Loss : 38.931923
# run: [10], model[4]
# Style Loss : 44.661018
# run: [10], model[5]
# Style Loss : 50.349689
# run: [10], model[0]
# Style Loss : 14.180233
# run: [10], model[1]
# Style Loss : 25.754818
# run: [10], model[2]
# Style Loss : 33.500664
# run: [10], model[3]
# Style Loss : 38.918560
# run: [10], model[4]
# Style Loss : 44.645271
# run: [10], model[5]
# Style Loss : 50.331535
# run: [10], model[0]
# Style Loss : 14.175954
# run: [10], model[1]
# Style Loss : 25.746086
# run: [10], model[2]
# Style Loss : 33.488937
# run: [10], model[3]
# Style Loss : 38.904957
# run: [10], model[4]
# Style Loss : 44.629242
# run: [10], model[5]
# Style Loss : 50.313053
# run: [10], model[0]
# Style Loss : 14.171598
# run: [10], model[1]
# Style Loss : 25.737202
# run: [10], model[2]
# Style Loss : 33.477009
# run: [10], model[3]
# Style Loss : 38.891125
# run: [10], model[4]
# Style Loss : 44.612946
# run: [10], model[5]
# Style Loss : 50.294270
# run: [10], model[0]
# Style Loss : 14.167169
# run: [10], model[1]
# Style Loss : 25.728161
# run: [10], model[2]
# Style Loss : 33.464870
# run: [10], model[3]
# Style Loss : 38.877048
# run: [10], model[4]
# Style Loss : 44.596367
# run: [10], model[5]
# Style Loss : 50.275162
# run: [10], model[0]
# Style Loss : 14.162660
# run: [10], model[1]
# Style Loss : 25.718960
# run: [10], model[2]
# Style Loss : 33.452522
# run: [10], model[3]
# Style Loss : 38.862732
# run: [10], model[4]
# Style Loss : 44.579502
# run: [10], model[5]
# Style Loss : 50.255722
# Current Run Number =  11
# numStreams =  6
# Current Run Number =  12
# numStreams =  6
# Current Run Number =  13
# numStreams =  6
# Current Run Number =  14
# numStreams =  6
# Current Run Number =  15
# numStreams =  6
# Current Run Number =  16
# numStreams =  6
# Current Run Number =  17
# numStreams =  6
# Current Run Number =  18
# numStreams =  6
# Current Run Number =  19
# numStreams =  6
# Current Run Number =  20
# numStreams =  6
# run: [20], model[0]
# Style Loss : 9.962111
# run: [20], model[1]
# Style Loss : 17.212765
# run: [20], model[2]
# Style Loss : 22.337229
# run: [20], model[3]
# Style Loss : 26.196716
# run: [20], model[4]
# Style Loss : 30.036064
# run: [20], model[5]
# Style Loss : 33.800701
# run: [20], model[0]
# Style Loss : 9.962124
# run: [20], model[1]
# Style Loss : 17.212799
# run: [20], model[2]
# Style Loss : 22.337275
# run: [20], model[3]
# Style Loss : 26.196766
# run: [20], model[4]
# Style Loss : 30.036121
# run: [20], model[5]
# Style Loss : 33.800766
# run: [20], model[0]
# Style Loss : 9.962060
# run: [20], model[1]
# Style Loss : 17.212692
# run: [20], model[2]
# Style Loss : 22.337139
# run: [20], model[3]
# Style Loss : 26.196613
# run: [20], model[4]
# Style Loss : 30.035950
# run: [20], model[5]
# Style Loss : 33.800575
# run: [20], model[0]
# Style Loss : 9.961958
# run: [20], model[1]
# Style Loss : 17.212509
# run: [20], model[2]
# Style Loss : 22.336908
# run: [20], model[3]
# Style Loss : 26.196354
# run: [20], model[4]
# Style Loss : 30.035658
# run: [20], model[5]
# Style Loss : 33.800247
# run: [20], model[0]
# Style Loss : 9.961853
# run: [20], model[1]
# Style Loss : 17.212318
# run: [20], model[2]
# Style Loss : 22.336664
# run: [20], model[3]
# Style Loss : 26.196075
# run: [20], model[4]
# Style Loss : 30.035347
# run: [20], model[5]
# Style Loss : 33.799900
# run: [20], model[0]
# Style Loss : 9.961758
# run: [20], model[1]
# Style Loss : 17.212143
# run: [20], model[2]
# Style Loss : 22.336439
# run: [20], model[3]
# Style Loss : 26.195822
# run: [20], model[4]
# Style Loss : 30.035059
# run: [20], model[5]
# Style Loss : 33.799580
# run: [20], model[0]
# Style Loss : 9.961659
# run: [20], model[1]
# Style Loss : 17.211964
# run: [20], model[2]
# Style Loss : 22.336210
# run: [20], model[3]
# Style Loss : 26.195562
# run: [20], model[4]
# Style Loss : 30.034765
# run: [20], model[5]
# Style Loss : 33.799248
# run: [20], model[0]
# Style Loss : 9.961557
# run: [20], model[1]
# Style Loss : 17.211782
# run: [20], model[2]
# Style Loss : 22.335981
# run: [20], model[3]
# Style Loss : 26.195301
# run: [20], model[4]
# Style Loss : 30.034472
# run: [20], model[5]
# Style Loss : 33.798920
# run: [20], model[0]
# Style Loss : 9.961456
# run: [20], model[1]
# Style Loss : 17.211594
# run: [20], model[2]
# Style Loss : 22.335739
# run: [20], model[3]
# Style Loss : 26.195028
# run: [20], model[4]
# Style Loss : 30.034166
# run: [20], model[5]
# Style Loss : 33.798580
# run: [20], model[0]
# Style Loss : 9.961356
# run: [20], model[1]
# Style Loss : 17.211414
# run: [20], model[2]
# Style Loss : 22.335516
# run: [20], model[3]
# Style Loss : 26.194775
# run: [20], model[4]
# Style Loss : 30.033880
# run: [20], model[5]
# Style Loss : 33.798264
# run: [20], model[0]
# Style Loss : 9.961252
# run: [20], model[1]
# Style Loss : 17.211233
# run: [20], model[2]
# Style Loss : 22.335281
# run: [20], model[3]
# Style Loss : 26.194510
# run: [20], model[4]
# Style Loss : 30.033583
# run: [20], model[5]
# Style Loss : 33.797932
# run: [20], model[0]
# Style Loss : 9.961151
# run: [20], model[1]
# Style Loss : 17.211056
# run: [20], model[2]
# Style Loss : 22.335056
# run: [20], model[3]
# Style Loss : 26.194256
# run: [20], model[4]
# Style Loss : 30.033298
# run: [20], model[5]
# Style Loss : 33.797611
# run: [20], model[0]
# Style Loss : 9.961054
# run: [20], model[1]
# Style Loss : 17.210873
# run: [20], model[2]
# Style Loss : 22.334824
# run: [20], model[3]
# Style Loss : 26.193989
# run: [20], model[4]
# Style Loss : 30.032997
# run: [20], model[5]
# Style Loss : 33.797279
# run: [20], model[0]
# Style Loss : 9.960948
# run: [20], model[1]
# Style Loss : 17.210690
# run: [20], model[2]
# Style Loss : 22.334595
# run: [20], model[3]
# Style Loss : 26.193729
# run: [20], model[4]
# Style Loss : 30.032705
# run: [20], model[5]
# Style Loss : 33.796951
# run: [20], model[0]
# Style Loss : 9.960853
# run: [20], model[1]
# Style Loss : 17.210510
# run: [20], model[2]
# Style Loss : 22.334362
# run: [20], model[3]
# Style Loss : 26.193466
# run: [20], model[4]
# Style Loss : 30.032410
# run: [20], model[5]
# Style Loss : 33.796619
# run: [20], model[0]
# Style Loss : 9.960747
# run: [20], model[1]
# Style Loss : 17.210327
# run: [20], model[2]
# Style Loss : 22.334129
# run: [20], model[3]
# Style Loss : 26.193203
# run: [20], model[4]
# Style Loss : 30.032114
# run: [20], model[5]
# Style Loss : 33.796291
# run: [20], model[0]
# Style Loss : 9.960648
# run: [20], model[1]
# Style Loss : 17.210140
# run: [20], model[2]
# Style Loss : 22.333893
# run: [20], model[3]
# Style Loss : 26.192936
# run: [20], model[4]
# Style Loss : 30.031813
# run: [20], model[5]
# Style Loss : 33.795952
# run: [20], model[0]
# Style Loss : 9.960546
# run: [20], model[1]
# Style Loss : 17.209961
# run: [20], model[2]
# Style Loss : 22.333664
# run: [20], model[3]
# Style Loss : 26.192677
# run: [20], model[4]
# Style Loss : 30.031523
# run: [20], model[5]
# Style Loss : 33.795631
# run: [20], model[0]
# Style Loss : 9.960444
# run: [20], model[1]
# Style Loss : 17.209776
# run: [20], model[2]
# Style Loss : 22.333431
# run: [20], model[3]
# Style Loss : 26.192413
# run: [20], model[4]
# Style Loss : 30.031225
# run: [20], model[5]
# Style Loss : 33.795296
# run: [20], model[0]
# Style Loss : 9.960342
# run: [20], model[1]
# Style Loss : 17.209591
# run: [20], model[2]
# Style Loss : 22.333197
# run: [20], model[3]
# Style Loss : 26.192148
# run: [20], model[4]
# Style Loss : 30.030926
# run: [20], model[5]
# Style Loss : 33.794964
# Current Run Number =  21
# numStreams =  6
# Current Run Number =  22
# numStreams =  6
# Current Run Number =  23
# numStreams =  6
# Current Run Number =  24
# numStreams =  6
# Current Run Number =  25
# numStreams =  6
# Current Run Number =  26
# numStreams =  6
# Current Run Number =  27
# numStreams =  6
# Current Run Number =  28
# numStreams =  6
# Current Run Number =  29
# numStreams =  6
# Current Run Number =  30
# numStreams =  6
# run: [30], model[0]
# Style Loss : 0.002675
# run: [30], model[1]
# Style Loss : 0.004873
# run: [30], model[2]
# Style Loss : 0.006478
# run: [30], model[3]
# Style Loss : 0.007729
# run: [30], model[4]
# Style Loss : 0.009289
# run: [30], model[5]
# Style Loss : 0.011768
# run: [30], model[0]
# Style Loss : 0.002617
# run: [30], model[1]
# Style Loss : 0.004755
# run: [30], model[2]
# Style Loss : 0.006316
# run: [30], model[3]
# Style Loss : 0.007534
# run: [30], model[4]
# Style Loss : 0.009062
# run: [30], model[5]
# Style Loss : 0.011493
# run: [30], model[0]
# Style Loss : 0.002575
# run: [30], model[1]
# Style Loss : 0.004687
# run: [30], model[2]
# Style Loss : 0.006224
# run: [30], model[3]
# Style Loss : 0.007413
# run: [30], model[4]
# Style Loss : 0.008883
# run: [30], model[5]
# Style Loss : 0.011213
# run: [30], model[0]
# Style Loss : 0.002504
# run: [30], model[1]
# Style Loss : 0.004547
# run: [30], model[2]
# Style Loss : 0.006042
# run: [30], model[3]
# Style Loss : 0.007195
# run: [30], model[4]
# Style Loss : 0.008642
# run: [30], model[5]
# Style Loss : 0.010949
# run: [30], model[0]
# Style Loss : 0.002450
# run: [30], model[1]
# Style Loss : 0.004448
# run: [30], model[2]
# Style Loss : 0.005909
# run: [30], model[3]
# Style Loss : 0.007037
# run: [30], model[4]
# Style Loss : 0.008438
# run: [30], model[5]
# Style Loss : 0.010675
# run: [30], model[0]
# Style Loss : 0.002387
# run: [30], model[1]
# Style Loss : 0.004340
# run: [30], model[2]
# Style Loss : 0.005763
# run: [30], model[3]
# Style Loss : 0.006864
# run: [30], model[4]
# Style Loss : 0.008205
# run: [30], model[5]
# Style Loss : 0.010351
# run: [30], model[0]
# Style Loss : 0.002348
# run: [30], model[1]
# Style Loss : 0.004262
# run: [30], model[2]
# Style Loss : 0.005666
# run: [30], model[3]
# Style Loss : 0.006746
# run: [30], model[4]
# Style Loss : 0.008053
# run: [30], model[5]
# Style Loss : 0.010152
# run: [30], model[0]
# Style Loss : 0.002275
# run: [30], model[1]
# Style Loss : 0.004132
# run: [30], model[2]
# Style Loss : 0.005496
# run: [30], model[3]
# Style Loss : 0.006543
# run: [30], model[4]
# Style Loss : 0.007807
# run: [30], model[5]
# Style Loss : 0.009845
# run: [30], model[0]
# Style Loss : 0.002252
# run: [30], model[1]
# Style Loss : 0.004087
# run: [30], model[2]
# Style Loss : 0.005451
# run: [30], model[3]
# Style Loss : 0.006486
# run: [30], model[4]
# Style Loss : 0.007701
# run: [30], model[5]
# Style Loss : 0.009643
# run: [30], model[0]
# Style Loss : 0.002160
# run: [30], model[1]
# Style Loss : 0.003921
# run: [30], model[2]
# Style Loss : 0.005219
# run: [30], model[3]
# Style Loss : 0.006215
# run: [30], model[4]
# Style Loss : 0.007416
# run: [30], model[5]
# Style Loss : 0.009353
# run: [30], model[0]
# Style Loss : 0.002142
# run: [30], model[1]
# Style Loss : 0.003884
# run: [30], model[2]
# Style Loss : 0.005159
# run: [30], model[3]
# Style Loss : 0.006134
# run: [30], model[4]
# Style Loss : 0.007306
# run: [30], model[5]
# Style Loss : 0.009207
# run: [30], model[0]
# Style Loss : 0.002095
# run: [30], model[1]
# Style Loss : 0.003794
# run: [30], model[2]
# Style Loss : 0.005035
# run: [30], model[3]
# Style Loss : 0.005983
# run: [30], model[4]
# Style Loss : 0.007130
# run: [30], model[5]
# Style Loss : 0.008999
# run: [30], model[0]
# Style Loss : 0.002060
# run: [30], model[1]
# Style Loss : 0.003745
# run: [30], model[2]
# Style Loss : 0.004978
# run: [30], model[3]
# Style Loss : 0.005918
# run: [30], model[4]
# Style Loss : 0.007020
# run: [30], model[5]
# Style Loss : 0.008810
# run: [30], model[0]
# Style Loss : 0.002002
# run: [30], model[1]
# Style Loss : 0.003635
# run: [30], model[2]
# Style Loss : 0.004834
# run: [30], model[3]
# Style Loss : 0.005751
# run: [30], model[4]
# Style Loss : 0.006834
# run: [30], model[5]
# Style Loss : 0.008600
# run: [30], model[0]
# Style Loss : 0.001950
# run: [30], model[1]
# Style Loss : 0.003539
# run: [30], model[2]
# Style Loss : 0.004702
# run: [30], model[3]
# Style Loss : 0.005590
# run: [30], model[4]
# Style Loss : 0.006650
# run: [30], model[5]
# Style Loss : 0.008378
# run: [30], model[0]
# Style Loss : 0.001911
# run: [30], model[1]
# Style Loss : 0.003468
# run: [30], model[2]
# Style Loss : 0.004609
# run: [30], model[3]
# Style Loss : 0.005478
# run: [30], model[4]
# Style Loss : 0.006510
# run: [30], model[5]
# Style Loss : 0.008195
# run: [30], model[0]
# Style Loss : 0.001861
# run: [30], model[1]
# Style Loss : 0.003377
# run: [30], model[2]
# Style Loss : 0.004490
# run: [30], model[3]
# Style Loss : 0.005343
# run: [30], model[4]
# Style Loss : 0.006346
# run: [30], model[5]
# Style Loss : 0.007975
# run: [30], model[0]
# Style Loss : 0.001818
# run: [30], model[1]
# Style Loss : 0.003304
# run: [30], model[2]
# Style Loss : 0.004391
# run: [30], model[3]
# Style Loss : 0.005224
# run: [30], model[4]
# Style Loss : 0.006203
# run: [30], model[5]
# Style Loss : 0.007801
# run: [30], model[0]
# Style Loss : 0.001791
# run: [30], model[1]
# Style Loss : 0.003255
# run: [30], model[2]
# Style Loss : 0.004321
# run: [30], model[3]
# Style Loss : 0.005135
# run: [30], model[4]
# Style Loss : 0.006085
# run: [30], model[5]
# Style Loss : 0.007642
# run: [30], model[0]
# Style Loss : 0.001753
# run: [30], model[1]
# Style Loss : 0.003180
# run: [30], model[2]
# Style Loss : 0.004218
# run: [30], model[3]
# Style Loss : 0.005011
# run: [30], model[4]
# Style Loss : 0.005941
# run: [30], model[5]
# Style Loss : 0.007470
# Current Run Number =  31
# numStreams =  6
# Current Run Number =  32
# numStreams =  6
# Current Run Number =  33
# numStreams =  6
# Current Run Number =  34
# numStreams =  6
# Current Run Number =  35
# numStreams =  6
# Current Run Number =  36
# numStreams =  6
# Current Run Number =  37
# numStreams =  6
# Current Run Number =  38
# numStreams =  6
# Current Run Number =  39
# numStreams =  6
# Current Run Number =  40
# numStreams =  6
# run: [40], model[0]
# Style Loss : 0.000308
# run: [40], model[1]
# Style Loss : 0.000549
# run: [40], model[2]
# Style Loss : 0.000716
# run: [40], model[3]
# Style Loss : 0.000828
# run: [40], model[4]
# Style Loss : 0.000926
# run: [40], model[5]
# Style Loss : 0.001090
# run: [40], model[0]
# Style Loss : 0.000307
# run: [40], model[1]
# Style Loss : 0.000547
# run: [40], model[2]
# Style Loss : 0.000714
# run: [40], model[3]
# Style Loss : 0.000826
# run: [40], model[4]
# Style Loss : 0.000923
# run: [40], model[5]
# Style Loss : 0.001085
# run: [40], model[0]
# Style Loss : 0.000306
# run: [40], model[1]
# Style Loss : 0.000545
# run: [40], model[2]
# Style Loss : 0.000711
# run: [40], model[3]
# Style Loss : 0.000821
# run: [40], model[4]
# Style Loss : 0.000918
# run: [40], model[5]
# Style Loss : 0.001079
# run: [40], model[0]
# Style Loss : 0.000304
# run: [40], model[1]
# Style Loss : 0.000542
# run: [40], model[2]
# Style Loss : 0.000707
# run: [40], model[3]
# Style Loss : 0.000817
# run: [40], model[4]
# Style Loss : 0.000913
# run: [40], model[5]
# Style Loss : 0.001073
# run: [40], model[0]
# Style Loss : 0.000303
# run: [40], model[1]
# Style Loss : 0.000539
# run: [40], model[2]
# Style Loss : 0.000703
# run: [40], model[3]
# Style Loss : 0.000813
# run: [40], model[4]
# Style Loss : 0.000908
# run: [40], model[5]
# Style Loss : 0.001067
# run: [40], model[0]
# Style Loss : 0.000301
# run: [40], model[1]
# Style Loss : 0.000536
# run: [40], model[2]
# Style Loss : 0.000700
# run: [40], model[3]
# Style Loss : 0.000808
# run: [40], model[4]
# Style Loss : 0.000903
# run: [40], model[5]
# Style Loss : 0.001061
# run: [40], model[0]
# Style Loss : 0.000299
# run: [40], model[1]
# Style Loss : 0.000533
# run: [40], model[2]
# Style Loss : 0.000695
# run: [40], model[3]
# Style Loss : 0.000804
# run: [40], model[4]
# Style Loss : 0.000898
# run: [40], model[5]
# Style Loss : 0.001054
# run: [40], model[0]
# Style Loss : 0.000298
# run: [40], model[1]
# Style Loss : 0.000531
# run: [40], model[2]
# Style Loss : 0.000692
# run: [40], model[3]
# Style Loss : 0.000799
# run: [40], model[4]
# Style Loss : 0.000893
# run: [40], model[5]
# Style Loss : 0.001048
# run: [40], model[0]
# Style Loss : 0.000296
# run: [40], model[1]
# Style Loss : 0.000528
# run: [40], model[2]
# Style Loss : 0.000689
# run: [40], model[3]
# Style Loss : 0.000796
# run: [40], model[4]
# Style Loss : 0.000888
# run: [40], model[5]
# Style Loss : 0.001043
# run: [40], model[0]
# Style Loss : 0.000295
# run: [40], model[1]
# Style Loss : 0.000526
# run: [40], model[2]
# Style Loss : 0.000685
# run: [40], model[3]
# Style Loss : 0.000792
# run: [40], model[4]
# Style Loss : 0.000884
# run: [40], model[5]
# Style Loss : 0.001037
# run: [40], model[0]
# Style Loss : 0.000294
# run: [40], model[1]
# Style Loss : 0.000523
# run: [40], model[2]
# Style Loss : 0.000682
# run: [40], model[3]
# Style Loss : 0.000788
# run: [40], model[4]
# Style Loss : 0.000879
# run: [40], model[5]
# Style Loss : 0.001031
# run: [40], model[0]
# Style Loss : 0.000292
# run: [40], model[1]
# Style Loss : 0.000520
# run: [40], model[2]
# Style Loss : 0.000678
# run: [40], model[3]
# Style Loss : 0.000783
# run: [40], model[4]
# Style Loss : 0.000874
# run: [40], model[5]
# Style Loss : 0.001025
# run: [40], model[0]
# Style Loss : 0.000290
# run: [40], model[1]
# Style Loss : 0.000517
# run: [40], model[2]
# Style Loss : 0.000674
# run: [40], model[3]
# Style Loss : 0.000778
# run: [40], model[4]
# Style Loss : 0.000869
# run: [40], model[5]
# Style Loss : 0.001019
# run: [40], model[0]
# Style Loss : 0.000289
# run: [40], model[1]
# Style Loss : 0.000515
# run: [40], model[2]
# Style Loss : 0.000671
# run: [40], model[3]
# Style Loss : 0.000775
# run: [40], model[4]
# Style Loss : 0.000865
# run: [40], model[5]
# Style Loss : 0.001014
# run: [40], model[0]
# Style Loss : 0.000287
# run: [40], model[1]
# Style Loss : 0.000512
# run: [40], model[2]
# Style Loss : 0.000667
# run: [40], model[3]
# Style Loss : 0.000770
# run: [40], model[4]
# Style Loss : 0.000860
# run: [40], model[5]
# Style Loss : 0.001008
# run: [40], model[0]
# Style Loss : 0.000286
# run: [40], model[1]
# Style Loss : 0.000510
# run: [40], model[2]
# Style Loss : 0.000665
# run: [40], model[3]
# Style Loss : 0.000767
# run: [40], model[4]
# Style Loss : 0.000856
# run: [40], model[5]
# Style Loss : 0.001003
# run: [40], model[0]
# Style Loss : 0.000285
# run: [40], model[1]
# Style Loss : 0.000508
# run: [40], model[2]
# Style Loss : 0.000662
# run: [40], model[3]
# Style Loss : 0.000763
# run: [40], model[4]
# Style Loss : 0.000852
# run: [40], model[5]
# Style Loss : 0.000999
# run: [40], model[0]
# Style Loss : 0.000284
# run: [40], model[1]
# Style Loss : 0.000506
# run: [40], model[2]
# Style Loss : 0.000659
# run: [40], model[3]
# Style Loss : 0.000760
# run: [40], model[4]
# Style Loss : 0.000848
# run: [40], model[5]
# Style Loss : 0.000993
# run: [40], model[0]
# Style Loss : 0.000282
# run: [40], model[1]
# Style Loss : 0.000503
# run: [40], model[2]
# Style Loss : 0.000655
# run: [40], model[3]
# Style Loss : 0.000756
# run: [40], model[4]
# Style Loss : 0.000843
# run: [40], model[5]
# Style Loss : 0.000988
# run: [40], model[0]
# Style Loss : 0.000281
# run: [40], model[1]
# Style Loss : 0.000501
# run: [40], model[2]
# Style Loss : 0.000652
# run: [40], model[3]
# Style Loss : 0.000753
# run: [40], model[4]
# Style Loss : 0.000839
# run: [40], model[5]
# Style Loss : 0.000983
# Current Run Number =  41
# numStreams =  6
# Current Run Number =  42
# numStreams =  6
# Current Run Number =  43
# numStreams =  6
# Current Run Number =  44
# numStreams =  6
# Current Run Number =  45
# numStreams =  6
# Current Run Number =  46
# numStreams =  6
# Current Run Number =  47
# numStreams =  6
# Current Run Number =  48
# numStreams =  6
# Current Run Number =  49
# numStreams =  6
# Current Run Number =  50
# numStreams =  6
# run: [50], model[0]
# Style Loss : 0.000157
# run: [50], model[1]
# Style Loss : 0.000276
# run: [50], model[2]
# Style Loss : 0.000356
# run: [50], model[3]
# Style Loss : 0.000405
# run: [50], model[4]
# Style Loss : 0.000444
# run: [50], model[5]
# Style Loss : 0.000507
# run: [50], model[0]
# Style Loss : 0.000157
# run: [50], model[1]
# Style Loss : 0.000276
# run: [50], model[2]
# Style Loss : 0.000355
# run: [50], model[3]
# Style Loss : 0.000405
# run: [50], model[4]
# Style Loss : 0.000443
# run: [50], model[5]
# Style Loss : 0.000506
# run: [50], model[0]
# Style Loss : 0.000157
# run: [50], model[1]
# Style Loss : 0.000275
# run: [50], model[2]
# Style Loss : 0.000354
# run: [50], model[3]
# Style Loss : 0.000403
# run: [50], model[4]
# Style Loss : 0.000442
# run: [50], model[5]
# Style Loss : 0.000505
# run: [50], model[0]
# Style Loss : 0.000156
# run: [50], model[1]
# Style Loss : 0.000275
# run: [50], model[2]
# Style Loss : 0.000354
# run: [50], model[3]
# Style Loss : 0.000403
# run: [50], model[4]
# Style Loss : 0.000441
# run: [50], model[5]
# Style Loss : 0.000504
# run: [50], model[0]
# Style Loss : 0.000156
# run: [50], model[1]
# Style Loss : 0.000274
# run: [50], model[2]
# Style Loss : 0.000353
# run: [50], model[3]
# Style Loss : 0.000402
# run: [50], model[4]
# Style Loss : 0.000440
# run: [50], model[5]
# Style Loss : 0.000502
# run: [50], model[0]
# Style Loss : 0.000156
# run: [50], model[1]
# Style Loss : 0.000273
# run: [50], model[2]
# Style Loss : 0.000352
# run: [50], model[3]
# Style Loss : 0.000401
# run: [50], model[4]
# Style Loss : 0.000439
# run: [50], model[5]
# Style Loss : 0.000501
# run: [50], model[0]
# Style Loss : 0.000155
# run: [50], model[1]
# Style Loss : 0.000273
# run: [50], model[2]
# Style Loss : 0.000351
# run: [50], model[3]
# Style Loss : 0.000400
# run: [50], model[4]
# Style Loss : 0.000438
# run: [50], model[5]
# Style Loss : 0.000500
# run: [50], model[0]
# Style Loss : 0.000155
# run: [50], model[1]
# Style Loss : 0.000272
# run: [50], model[2]
# Style Loss : 0.000350
# run: [50], model[3]
# Style Loss : 0.000399
# run: [50], model[4]
# Style Loss : 0.000437
# run: [50], model[5]
# Style Loss : 0.000499
# run: [50], model[0]
# Style Loss : 0.000155
# run: [50], model[1]
# Style Loss : 0.000271
# run: [50], model[2]
# Style Loss : 0.000349
# run: [50], model[3]
# Style Loss : 0.000398
# run: [50], model[4]
# Style Loss : 0.000436
# run: [50], model[5]
# Style Loss : 0.000497
# run: [50], model[0]
# Style Loss : 0.000154
# run: [50], model[1]
# Style Loss : 0.000271
# run: [50], model[2]
# Style Loss : 0.000349
# run: [50], model[3]
# Style Loss : 0.000397
# run: [50], model[4]
# Style Loss : 0.000435
# run: [50], model[5]
# Style Loss : 0.000496
# run: [50], model[0]
# Style Loss : 0.000154
# run: [50], model[1]
# Style Loss : 0.000270
# run: [50], model[2]
# Style Loss : 0.000348
# run: [50], model[3]
# Style Loss : 0.000396
# run: [50], model[4]
# Style Loss : 0.000434
# run: [50], model[5]
# Style Loss : 0.000495
# run: [50], model[0]
# Style Loss : 0.000154
# run: [50], model[1]
# Style Loss : 0.000270
# run: [50], model[2]
# Style Loss : 0.000347
# run: [50], model[3]
# Style Loss : 0.000395
# run: [50], model[4]
# Style Loss : 0.000433
# run: [50], model[5]
# Style Loss : 0.000494
# run: [50], model[0]
# Style Loss : 0.000153
# run: [50], model[1]
# Style Loss : 0.000269
# run: [50], model[2]
# Style Loss : 0.000346
# run: [50], model[3]
# Style Loss : 0.000395
# run: [50], model[4]
# Style Loss : 0.000432
# run: [50], model[5]
# Style Loss : 0.000492
# run: [50], model[0]
# Style Loss : 0.000153
# run: [50], model[1]
# Style Loss : 0.000268
# run: [50], model[2]
# Style Loss : 0.000345
# run: [50], model[3]
# Style Loss : 0.000393
# run: [50], model[4]
# Style Loss : 0.000431
# run: [50], model[5]
# Style Loss : 0.000491
# run: [50], model[0]
# Style Loss : 0.000152
# run: [50], model[1]
# Style Loss : 0.000268
# run: [50], model[2]
# Style Loss : 0.000345
# run: [50], model[3]
# Style Loss : 0.000393
# run: [50], model[4]
# Style Loss : 0.000430
# run: [50], model[5]
# Style Loss : 0.000490
# run: [50], model[0]
# Style Loss : 0.000152
# run: [50], model[1]
# Style Loss : 0.000267
# run: [50], model[2]
# Style Loss : 0.000344
# run: [50], model[3]
# Style Loss : 0.000392
# run: [50], model[4]
# Style Loss : 0.000429
# run: [50], model[5]
# Style Loss : 0.000489
# run: [50], model[0]
# Style Loss : 0.000152
# run: [50], model[1]
# Style Loss : 0.000266
# run: [50], model[2]
# Style Loss : 0.000343
# run: [50], model[3]
# Style Loss : 0.000391
# run: [50], model[4]
# Style Loss : 0.000427
# run: [50], model[5]
# Style Loss : 0.000487
# run: [50], model[0]
# Style Loss : 0.000151
# run: [50], model[1]
# Style Loss : 0.000266
# run: [50], model[2]
# Style Loss : 0.000342
# run: [50], model[3]
# Style Loss : 0.000390
# run: [50], model[4]
# Style Loss : 0.000426
# run: [50], model[5]
# Style Loss : 0.000486
# run: [50], model[0]
# Style Loss : 0.000151
# run: [50], model[1]
# Style Loss : 0.000265
# run: [50], model[2]
# Style Loss : 0.000341
# run: [50], model[3]
# Style Loss : 0.000389
# run: [50], model[4]
# Style Loss : 0.000425
# run: [50], model[5]
# Style Loss : 0.000485
# run: [50], model[0]
# Style Loss : 0.000151
# run: [50], model[1]
# Style Loss : 0.000265
# run: [50], model[2]
# Style Loss : 0.000340
# run: [50], model[3]
# Style Loss : 0.000388
# run: [50], model[4]
# Style Loss : 0.000424
# run: [50], model[5]
# Style Loss : 0.000484
# Current Run Number =  51
# numStreams =  6
# Current Run Number =  52
# numStreams =  6
# Current Run Number =  53
# numStreams =  6
# Current Run Number =  54
# numStreams =  6
# Current Run Number =  55
# numStreams =  6
# Current Run Number =  56
# numStreams =  6
# Current Run Number =  57
# numStreams =  6
# Current Run Number =  58
# numStreams =  6
# Current Run Number =  59
# numStreams =  6
# Current Run Number =  60
# numStreams =  6
# run: [60], model[0]
# Style Loss : 0.000112
# run: [60], model[1]
# Style Loss : 0.000195
# run: [60], model[2]
# Style Loss : 0.000250
# run: [60], model[3]
# Style Loss : 0.000283
# run: [60], model[4]
# Style Loss : 0.000307
# run: [60], model[5]
# Style Loss : 0.000345
# run: [60], model[0]
# Style Loss : 0.000112
# run: [60], model[1]
# Style Loss : 0.000195
# run: [60], model[2]
# Style Loss : 0.000249
# run: [60], model[3]
# Style Loss : 0.000282
# run: [60], model[4]
# Style Loss : 0.000306
# run: [60], model[5]
# Style Loss : 0.000345
# run: [60], model[0]
# Style Loss : 0.000112
# run: [60], model[1]
# Style Loss : 0.000195
# run: [60], model[2]
# Style Loss : 0.000249
# run: [60], model[3]
# Style Loss : 0.000282
# run: [60], model[4]
# Style Loss : 0.000306
# run: [60], model[5]
# Style Loss : 0.000344
# run: [60], model[0]
# Style Loss : 0.000112
# run: [60], model[1]
# Style Loss : 0.000194
# run: [60], model[2]
# Style Loss : 0.000249
# run: [60], model[3]
# Style Loss : 0.000281
# run: [60], model[4]
# Style Loss : 0.000305
# run: [60], model[5]
# Style Loss : 0.000344
# run: [60], model[0]
# Style Loss : 0.000112
# run: [60], model[1]
# Style Loss : 0.000194
# run: [60], model[2]
# Style Loss : 0.000248
# run: [60], model[3]
# Style Loss : 0.000281
# run: [60], model[4]
# Style Loss : 0.000305
# run: [60], model[5]
# Style Loss : 0.000343
# run: [60], model[0]
# Style Loss : 0.000111
# run: [60], model[1]
# Style Loss : 0.000194
# run: [60], model[2]
# Style Loss : 0.000248
# run: [60], model[3]
# Style Loss : 0.000281
# run: [60], model[4]
# Style Loss : 0.000305
# run: [60], model[5]
# Style Loss : 0.000343
# run: [60], model[0]
# Style Loss : 0.000111
# run: [60], model[1]
# Style Loss : 0.000194
# run: [60], model[2]
# Style Loss : 0.000248
# run: [60], model[3]
# Style Loss : 0.000281
# run: [60], model[4]
# Style Loss : 0.000304
# run: [60], model[5]
# Style Loss : 0.000342
# run: [60], model[0]
# Style Loss : 0.000111
# run: [60], model[1]
# Style Loss : 0.000194
# run: [60], model[2]
# Style Loss : 0.000248
# run: [60], model[3]
# Style Loss : 0.000280
# run: [60], model[4]
# Style Loss : 0.000304
# run: [60], model[5]
# Style Loss : 0.000342
# run: [60], model[0]
# Style Loss : 0.000111
# run: [60], model[1]
# Style Loss : 0.000193
# run: [60], model[2]
# Style Loss : 0.000247
# run: [60], model[3]
# Style Loss : 0.000280
# run: [60], model[4]
# Style Loss : 0.000304
# run: [60], model[5]
# Style Loss : 0.000341
# run: [60], model[0]
# Style Loss : 0.000111
# run: [60], model[1]
# Style Loss : 0.000193
# run: [60], model[2]
# Style Loss : 0.000247
# run: [60], model[3]
# Style Loss : 0.000279
# run: [60], model[4]
# Style Loss : 0.000303
# run: [60], model[5]
# Style Loss : 0.000341
# run: [60], model[0]
# Style Loss : 0.000111
# run: [60], model[1]
# Style Loss : 0.000193
# run: [60], model[2]
# Style Loss : 0.000247
# run: [60], model[3]
# Style Loss : 0.000279
# run: [60], model[4]
# Style Loss : 0.000303
# run: [60], model[5]
# Style Loss : 0.000340
# run: [60], model[0]
# Style Loss : 0.000111
# run: [60], model[1]
# Style Loss : 0.000193
# run: [60], model[2]
# Style Loss : 0.000246
# run: [60], model[3]
# Style Loss : 0.000278
# run: [60], model[4]
# Style Loss : 0.000302
# run: [60], model[5]
# Style Loss : 0.000340
# run: [60], model[0]
# Style Loss : 0.000110
# run: [60], model[1]
# Style Loss : 0.000192
# run: [60], model[2]
# Style Loss : 0.000246
# run: [60], model[3]
# Style Loss : 0.000278
# run: [60], model[4]
# Style Loss : 0.000302
# run: [60], model[5]
# Style Loss : 0.000340
# run: [60], model[0]
# Style Loss : 0.000110
# run: [60], model[1]
# Style Loss : 0.000192
# run: [60], model[2]
# Style Loss : 0.000245
# run: [60], model[3]
# Style Loss : 0.000278
# run: [60], model[4]
# Style Loss : 0.000301
# run: [60], model[5]
# Style Loss : 0.000339
# run: [60], model[0]
# Style Loss : 0.000110
# run: [60], model[1]
# Style Loss : 0.000192
# run: [60], model[2]
# Style Loss : 0.000245
# run: [60], model[3]
# Style Loss : 0.000277
# run: [60], model[4]
# Style Loss : 0.000301
# run: [60], model[5]
# Style Loss : 0.000338
# run: [60], model[0]
# Style Loss : 0.000110
# run: [60], model[1]
# Style Loss : 0.000192
# run: [60], model[2]
# Style Loss : 0.000245
# run: [60], model[3]
# Style Loss : 0.000277
# run: [60], model[4]
# Style Loss : 0.000301
# run: [60], model[5]
# Style Loss : 0.000338
# run: [60], model[0]
# Style Loss : 0.000110
# run: [60], model[1]
# Style Loss : 0.000191
# run: [60], model[2]
# Style Loss : 0.000245
# run: [60], model[3]
# Style Loss : 0.000277
# run: [60], model[4]
# Style Loss : 0.000300
# run: [60], model[5]
# Style Loss : 0.000338
# run: [60], model[0]
# Style Loss : 0.000110
# run: [60], model[1]
# Style Loss : 0.000191
# run: [60], model[2]
# Style Loss : 0.000244
# run: [60], model[3]
# Style Loss : 0.000276
# run: [60], model[4]
# Style Loss : 0.000300
# run: [60], model[5]
# Style Loss : 0.000337
# run: [60], model[0]
# Style Loss : 0.000110
# run: [60], model[1]
# Style Loss : 0.000191
# run: [60], model[2]
# Style Loss : 0.000244
# run: [60], model[3]
# Style Loss : 0.000276
# run: [60], model[4]
# Style Loss : 0.000299
# run: [60], model[5]
# Style Loss : 0.000337
# run: [60], model[0]
# Style Loss : 0.000110
# run: [60], model[1]
# Style Loss : 0.000191
# run: [60], model[2]
# Style Loss : 0.000244
# run: [60], model[3]
# Style Loss : 0.000276
# run: [60], model[4]
# Style Loss : 0.000299
# run: [60], model[5]
# Style Loss : 0.000336
# Current Run Number =  61
# numStreams =  6
# Current Run Number =  62
# numStreams =  6
# Current Run Number =  63
# numStreams =  6
# Current Run Number =  64
# numStreams =  6
# Current Run Number =  65
# numStreams =  6
# Current Run Number =  66
# numStreams =  6
# Current Run Number =  67
# numStreams =  6
# Current Run Number =  68
# numStreams =  6
# Current Run Number =  69
# numStreams =  6
# Current Run Number =  70
# numStreams =  6
# run: [70], model[0]
# Style Loss : 0.000092
# run: [70], model[1]
# Style Loss : 0.000159
# run: [70], model[2]
# Style Loss : 0.000202
# run: [70], model[3]
# Style Loss : 0.000227
# run: [70], model[4]
# Style Loss : 0.000245
# run: [70], model[5]
# Style Loss : 0.000274
# run: [70], model[0]
# Style Loss : 0.000092
# run: [70], model[1]
# Style Loss : 0.000158
# run: [70], model[2]
# Style Loss : 0.000202
# run: [70], model[3]
# Style Loss : 0.000227
# run: [70], model[4]
# Style Loss : 0.000245
# run: [70], model[5]
# Style Loss : 0.000273
# run: [70], model[0]
# Style Loss : 0.000091
# run: [70], model[1]
# Style Loss : 0.000158
# run: [70], model[2]
# Style Loss : 0.000201
# run: [70], model[3]
# Style Loss : 0.000227
# run: [70], model[4]
# Style Loss : 0.000245
# run: [70], model[5]
# Style Loss : 0.000273
# run: [70], model[0]
# Style Loss : 0.000091
# run: [70], model[1]
# Style Loss : 0.000158
# run: [70], model[2]
# Style Loss : 0.000201
# run: [70], model[3]
# Style Loss : 0.000227
# run: [70], model[4]
# Style Loss : 0.000244
# run: [70], model[5]
# Style Loss : 0.000273
# run: [70], model[0]
# Style Loss : 0.000091
# run: [70], model[1]
# Style Loss : 0.000158
# run: [70], model[2]
# Style Loss : 0.000201
# run: [70], model[3]
# Style Loss : 0.000226
# run: [70], model[4]
# Style Loss : 0.000244
# run: [70], model[5]
# Style Loss : 0.000273
# run: [70], model[0]
# Style Loss : 0.000091
# run: [70], model[1]
# Style Loss : 0.000158
# run: [70], model[2]
# Style Loss : 0.000201
# run: [70], model[3]
# Style Loss : 0.000226
# run: [70], model[4]
# Style Loss : 0.000244
# run: [70], model[5]
# Style Loss : 0.000272
# run: [70], model[0]
# Style Loss : 0.000091
# run: [70], model[1]
# Style Loss : 0.000158
# run: [70], model[2]
# Style Loss : 0.000201
# run: [70], model[3]
# Style Loss : 0.000226
# run: [70], model[4]
# Style Loss : 0.000244
# run: [70], model[5]
# Style Loss : 0.000272
# run: [70], model[0]
# Style Loss : 0.000091
# run: [70], model[1]
# Style Loss : 0.000158
# run: [70], model[2]
# Style Loss : 0.000200
# run: [70], model[3]
# Style Loss : 0.000226
# run: [70], model[4]
# Style Loss : 0.000244
# run: [70], model[5]
# Style Loss : 0.000272
# run: [70], model[0]
# Style Loss : 0.000091
# run: [70], model[1]
# Style Loss : 0.000157
# run: [70], model[2]
# Style Loss : 0.000200
# run: [70], model[3]
# Style Loss : 0.000225
# run: [70], model[4]
# Style Loss : 0.000243
# run: [70], model[5]
# Style Loss : 0.000272
# run: [70], model[0]
# Style Loss : 0.000091
# run: [70], model[1]
# Style Loss : 0.000157
# run: [70], model[2]
# Style Loss : 0.000200
# run: [70], model[3]
# Style Loss : 0.000225
# run: [70], model[4]
# Style Loss : 0.000243
# run: [70], model[5]
# Style Loss : 0.000271
# run: [70], model[0]
# Style Loss : 0.000091
# run: [70], model[1]
# Style Loss : 0.000157
# run: [70], model[2]
# Style Loss : 0.000200
# run: [70], model[3]
# Style Loss : 0.000225
# run: [70], model[4]
# Style Loss : 0.000243
# run: [70], model[5]
# Style Loss : 0.000271
# run: [70], model[0]
# Style Loss : 0.000091
# run: [70], model[1]
# Style Loss : 0.000157
# run: [70], model[2]
# Style Loss : 0.000200
# run: [70], model[3]
# Style Loss : 0.000225
# run: [70], model[4]
# Style Loss : 0.000243
# run: [70], model[5]
# Style Loss : 0.000271
# run: [70], model[0]
# Style Loss : 0.000091
# run: [70], model[1]
# Style Loss : 0.000157
# run: [70], model[2]
# Style Loss : 0.000200
# run: [70], model[3]
# Style Loss : 0.000225
# run: [70], model[4]
# Style Loss : 0.000242
# run: [70], model[5]
# Style Loss : 0.000271
# run: [70], model[0]
# Style Loss : 0.000091
# run: [70], model[1]
# Style Loss : 0.000157
# run: [70], model[2]
# Style Loss : 0.000199
# run: [70], model[3]
# Style Loss : 0.000224
# run: [70], model[4]
# Style Loss : 0.000242
# run: [70], model[5]
# Style Loss : 0.000270
# run: [70], model[0]
# Style Loss : 0.000091
# run: [70], model[1]
# Style Loss : 0.000157
# run: [70], model[2]
# Style Loss : 0.000199
# run: [70], model[3]
# Style Loss : 0.000224
# run: [70], model[4]
# Style Loss : 0.000242
# run: [70], model[5]
# Style Loss : 0.000270
# run: [70], model[0]
# Style Loss : 0.000091
# run: [70], model[1]
# Style Loss : 0.000157
# run: [70], model[2]
# Style Loss : 0.000199
# run: [70], model[3]
# Style Loss : 0.000224
# run: [70], model[4]
# Style Loss : 0.000242
# run: [70], model[5]
# Style Loss : 0.000270
# run: [70], model[0]
# Style Loss : 0.000090
# run: [70], model[1]
# Style Loss : 0.000156
# run: [70], model[2]
# Style Loss : 0.000199
# run: [70], model[3]
# Style Loss : 0.000224
# run: [70], model[4]
# Style Loss : 0.000242
# run: [70], model[5]
# Style Loss : 0.000270
# run: [70], model[0]
# Style Loss : 0.000090
# run: [70], model[1]
# Style Loss : 0.000156
# run: [70], model[2]
# Style Loss : 0.000199
# run: [70], model[3]
# Style Loss : 0.000224
# run: [70], model[4]
# Style Loss : 0.000241
# run: [70], model[5]
# Style Loss : 0.000269
# run: [70], model[0]
# Style Loss : 0.000090
# run: [70], model[1]
# Style Loss : 0.000156
# run: [70], model[2]
# Style Loss : 0.000198
# run: [70], model[3]
# Style Loss : 0.000224
# run: [70], model[4]
# Style Loss : 0.000241
# run: [70], model[5]
# Style Loss : 0.000269
# run: [70], model[0]
# Style Loss : 0.000090
# run: [70], model[1]
# Style Loss : 0.000156
# run: [70], model[2]
# Style Loss : 0.000198
# run: [70], model[3]
# Style Loss : 0.000223
# run: [70], model[4]
# Style Loss : 0.000241
# run: [70], model[5]
# Style Loss : 0.000269
# Current Run Number =  71
# numStreams =  6
# Current Run Number =  72
# numStreams =  6
# Current Run Number =  73
# numStreams =  6
# Current Run Number =  74
# numStreams =  6
# Current Run Number =  75
# numStreams =  6
# Current Run Number =  76
# numStreams =  6
# Current Run Number =  77
# numStreams =  6
# Current Run Number =  78
# numStreams =  6
# Current Run Number =  79
# numStreams =  6
# Current Run Number =  80
# numStreams =  6
# run: [80], model[0]
# Style Loss : 0.000079
# run: [80], model[1]
# Style Loss : 0.000136
# run: [80], model[2]
# Style Loss : 0.000173
# run: [80], model[3]
# Style Loss : 0.000194
# run: [80], model[4]
# Style Loss : 0.000209
# run: [80], model[5]
# Style Loss : 0.000232
# run: [80], model[0]
# Style Loss : 0.000079
# run: [80], model[1]
# Style Loss : 0.000136
# run: [80], model[2]
# Style Loss : 0.000173
# run: [80], model[3]
# Style Loss : 0.000194
# run: [80], model[4]
# Style Loss : 0.000208
# run: [80], model[5]
# Style Loss : 0.000231
# run: [80], model[0]
# Style Loss : 0.000079
# run: [80], model[1]
# Style Loss : 0.000136
# run: [80], model[2]
# Style Loss : 0.000173
# run: [80], model[3]
# Style Loss : 0.000194
# run: [80], model[4]
# Style Loss : 0.000208
# run: [80], model[5]
# Style Loss : 0.000231
# run: [80], model[0]
# Style Loss : 0.000079
# run: [80], model[1]
# Style Loss : 0.000136
# run: [80], model[2]
# Style Loss : 0.000172
# run: [80], model[3]
# Style Loss : 0.000194
# run: [80], model[4]
# Style Loss : 0.000208
# run: [80], model[5]
# Style Loss : 0.000231
# run: [80], model[0]
# Style Loss : 0.000079
# run: [80], model[1]
# Style Loss : 0.000136
# run: [80], model[2]
# Style Loss : 0.000172
# run: [80], model[3]
# Style Loss : 0.000193
# run: [80], model[4]
# Style Loss : 0.000208
# run: [80], model[5]
# Style Loss : 0.000231
# run: [80], model[0]
# Style Loss : 0.000079
# run: [80], model[1]
# Style Loss : 0.000136
# run: [80], model[2]
# Style Loss : 0.000172
# run: [80], model[3]
# Style Loss : 0.000193
# run: [80], model[4]
# Style Loss : 0.000208
# run: [80], model[5]
# Style Loss : 0.000231
# run: [80], model[0]
# Style Loss : 0.000079
# run: [80], model[1]
# Style Loss : 0.000136
# run: [80], model[2]
# Style Loss : 0.000172
# run: [80], model[3]
# Style Loss : 0.000193
# run: [80], model[4]
# Style Loss : 0.000208
# run: [80], model[5]
# Style Loss : 0.000231
# run: [80], model[0]
# Style Loss : 0.000079
# run: [80], model[1]
# Style Loss : 0.000136
# run: [80], model[2]
# Style Loss : 0.000172
# run: [80], model[3]
# Style Loss : 0.000193
# run: [80], model[4]
# Style Loss : 0.000208
# run: [80], model[5]
# Style Loss : 0.000230
# run: [80], model[0]
# Style Loss : 0.000079
# run: [80], model[1]
# Style Loss : 0.000136
# run: [80], model[2]
# Style Loss : 0.000172
# run: [80], model[3]
# Style Loss : 0.000193
# run: [80], model[4]
# Style Loss : 0.000207
# run: [80], model[5]
# Style Loss : 0.000230
# run: [80], model[0]
# Style Loss : 0.000079
# run: [80], model[1]
# Style Loss : 0.000135
# run: [80], model[2]
# Style Loss : 0.000172
# run: [80], model[3]
# Style Loss : 0.000193
# run: [80], model[4]
# Style Loss : 0.000207
# run: [80], model[5]
# Style Loss : 0.000230
# run: [80], model[0]
# Style Loss : 0.000079
# run: [80], model[1]
# Style Loss : 0.000135
# run: [80], model[2]
# Style Loss : 0.000172
# run: [80], model[3]
# Style Loss : 0.000193
# run: [80], model[4]
# Style Loss : 0.000207
# run: [80], model[5]
# Style Loss : 0.000230
# run: [80], model[0]
# Style Loss : 0.000078
# run: [80], model[1]
# Style Loss : 0.000135
# run: [80], model[2]
# Style Loss : 0.000171
# run: [80], model[3]
# Style Loss : 0.000193
# run: [80], model[4]
# Style Loss : 0.000207
# run: [80], model[5]
# Style Loss : 0.000230
# run: [80], model[0]
# Style Loss : 0.000078
# run: [80], model[1]
# Style Loss : 0.000135
# run: [80], model[2]
# Style Loss : 0.000171
# run: [80], model[3]
# Style Loss : 0.000192
# run: [80], model[4]
# Style Loss : 0.000207
# run: [80], model[5]
# Style Loss : 0.000230
# run: [80], model[0]
# Style Loss : 0.000078
# run: [80], model[1]
# Style Loss : 0.000135
# run: [80], model[2]
# Style Loss : 0.000171
# run: [80], model[3]
# Style Loss : 0.000192
# run: [80], model[4]
# Style Loss : 0.000207
# run: [80], model[5]
# Style Loss : 0.000229
# run: [80], model[0]
# Style Loss : 0.000078
# run: [80], model[1]
# Style Loss : 0.000135
# run: [80], model[2]
# Style Loss : 0.000171
# run: [80], model[3]
# Style Loss : 0.000192
# run: [80], model[4]
# Style Loss : 0.000207
# run: [80], model[5]
# Style Loss : 0.000229
# run: [80], model[0]
# Style Loss : 0.000078
# run: [80], model[1]
# Style Loss : 0.000135
# run: [80], model[2]
# Style Loss : 0.000171
# run: [80], model[3]
# Style Loss : 0.000192
# run: [80], model[4]
# Style Loss : 0.000206
# run: [80], model[5]
# Style Loss : 0.000229
# run: [80], model[0]
# Style Loss : 0.000078
# run: [80], model[1]
# Style Loss : 0.000135
# run: [80], model[2]
# Style Loss : 0.000171
# run: [80], model[3]
# Style Loss : 0.000192
# run: [80], model[4]
# Style Loss : 0.000206
# run: [80], model[5]
# Style Loss : 0.000229
# run: [80], model[0]
# Style Loss : 0.000078
# run: [80], model[1]
# Style Loss : 0.000135
# run: [80], model[2]
# Style Loss : 0.000171
# run: [80], model[3]
# Style Loss : 0.000192
# run: [80], model[4]
# Style Loss : 0.000206
# run: [80], model[5]
# Style Loss : 0.000229
# run: [80], model[0]
# Style Loss : 0.000078
# run: [80], model[1]
# Style Loss : 0.000135
# run: [80], model[2]
# Style Loss : 0.000171
# run: [80], model[3]
# Style Loss : 0.000192
# run: [80], model[4]
# Style Loss : 0.000206
# run: [80], model[5]
# Style Loss : 0.000229
# run: [80], model[0]
# Style Loss : 0.000078
# run: [80], model[1]
# Style Loss : 0.000135
# run: [80], model[2]
# Style Loss : 0.000171
# run: [80], model[3]
# Style Loss : 0.000192
# run: [80], model[4]
# Style Loss : 0.000206
# run: [80], model[5]
# Style Loss : 0.000228
# Current Run Number =  81
# numStreams =  6
# (257, 3468)
# Output range: -1.4590987 3.6139398
# mean and sigma: 0.058026463 0.1931208

# %%
#SPECTOFFSET
SPECTOFFSET=0

##out_spec = inv_scale(out,shf)
for j in range(len(outputs)):
    print(f'Min/Max of outputs:  {np.amin(outputs[j])},{np.amax(outputs[j])}') # check values make sense
    fig = plt.figure()
    plt.title('Style spectrogram')
    ax = fig.add_subplot(111)
    n,b,_ = ax.hist(outputs[j].flatten(),bins='auto')
    plt.show()

if tifresi :
    #### Shift log spec to use max range before thresholding for tfresi inversion
    #outputs=[x+1-np.amax(x) for x in outputs]
    print('TIFResi: inv_log_spectrogram')
    if use01scale == True:
        foo = [img_invscale(x,a_min,a_max,0,1) for x in outputs]
        
        out_spec = [inv_log_spectrogram(x+SPECTOFFSET) for x in foo]

        for j in range(len(outputs)):
            print(f'   RESCALED: Min/Max of outputs:  {np.amin(foo[j])},{np.amax(foo[j])}') # check values make sense

    else:
        out_spec = [inv_log_spectrogram(x+SPECTOFFSET) for x in outputs] 

        #out_spec = [inv_log(x+SPECTOFFSET) for x in outputs]
        for j in range(len(outputs)):
            print(f'   inv_log_spectrogram: Min/Max of outputs:  {np.amin(out_spec[j])},{np.amax(out_spec[j])}') # check values make sense

else : 
    print('HUZ: inv_log')
    if use01scale == True:
        out_spec = [inv_log(img_invscale(x,a_min,a_max,0,1)) for x in outputs]
    else:
        out_spec = [inv_log(x) for x in outputs]

    for j in range(len(out_spec)):
        print(f'Min/Max of out_spec: {np.amin(out_spec[j])}, {np.amax(out_spec[j])}') # check values make sense
# Out:
# Min/Max of outputs:  -1.4590986967086792,3.6139397621154785
# HUZ: inv_log
# Min/Max of out_spec: -0.7675542831420898, 36.111976623535156

# %%
# Griffin & Lim algo for phase reconstruction (not used for tifresi)

print(f'out_spec lene is {len(out_spec)}')
for index,value in enumerate(out_spec):
    print(f'shape of value is {value.shape}')
    
    if tifresi :
        print(f'TIFResi invert mag to audio')
        print("shape of mag = ",np.shape(value))
        S = value
        bar=S#-np.amin(S)+.0001
#         bar = np.abs(bar)
        #bar=bar/np.amax(bar)
        bar = np.clip(bar, 0,None)
        print(f'Min/Max of spectrogram: {np.amin(bar)}, {np.amax(bar)}') # check values make sense
        x = stft_system.invert_spectrogram(bar) 
    else :
        print(f'Huz invert mag to audio')
        p = 2 * np.pi * np.random.random_sample(value.shape) - np.pi #start with some phase
        #Griffin Lim
        for i in range(50):
            S = value * np.exp(1j*p) #use magnitude a given by spectrogram and some random phase
            x = librosa.istft(S,hop_length=K_HOP, win_length=N_FFT, center=False) #do the inverse transform
            p = np.angle(librosa.stft(x, n_fft=N_FFT, hop_length=K_HOP, win_length=N_FFT, center=False)) #use this new phase value

    try:
        os.makedirs("outputs/" + outname)
    except FileExistsError:
        # directory already exists
        pass

    OUTPUT_FILENAME="outputs/" + outname + '/' + outname + '_' + str(index) + '.wav'
    #librosa.output.write_wav("outputs/" + outname + '/' + outname + '_' + str(index) + '.wav', x, fs)
    sf.write(OUTPUT_FILENAME, x, fs)
    print(f'Spectrogram values range over [{np.amin(value)},{np.amax(value)} ]')
    #figure(figsize=(8, 6), dpi=80)
    plt.figure().set_size_inches(20, 4)
    plt.title('Result')
    plt.imshow(value,  origin='lower', cmap=plt.cm.get_cmap('Oranges'))
    plt.colorbar();
    plt.clim(-0, .3);  #prevent extreme values from making spectrum practicvally invisible [where are those huge values????]
    
    OUTPUT_FILENAME="outputs/" + outname + '/' + outname + '_' + str(index) + '.png'
    plt.savefig(OUTPUT_FILENAME)

    plt.show()

plt.ioff()
# Out:
# out_spec lene is 1
# shape of value is (257, 3468)
# Huz invert mag to audio
# Spectrogram values range over [-0.7675542831420898,36.111976623535156 ]

# %%
print(OUTPUT_FILENAME)
display(Audio(OUTPUT_FILENAME, autoplay=True))
# Out:
# outputs/rftests/rftests_0.png
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:image/png;base64,..." type="image/png" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
OUTPUT_FILENAME="outputs/" + outname + '/' + outname + '_' + str(index) + '.png'
plt.savefig(OUTPUT_FILENAME)
