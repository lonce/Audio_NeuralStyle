# %% [markdown]
# Audio Neural Style Transfer with Pytorch
# ============================
# This is an implementation of neural style transfer using the alogrithm developed in
# [A Neural Algorithm of Artistic Style](https://arxiv.org/abs/1508.06576) by Leon A. Gatys, Alexander S. Ecker and Matthias Bethge.
#
# However instead of learning style from images we use the spectrogram in place to carry out the procedure on audio.
#
# General implementation is based off the [Pytorch tutorial on Neural Transfer](http://pytorch.org/tutorials/advanced/neural_style_tutorial.html) by Alexis Jacq. Also inspired by [Audio texture synthesis](https://github.com/DmitryUlyanov/neural-style-audio-torch) by Dmitry Ulyanov.

# %%
# %matplotlib inline

from __future__ import print_function

import numpy as np
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim

import librosa
from IPython.display import Audio, display
from PIL import Image
import matplotlib.pyplot as plt
import scipy.stats as stats

import torchvision.transforms as transforms
import torchvision.models as models
from torch.nn.modules.module import _addindent

import copy
import os
import math

import soundfile as sf
from matplotlib.pyplot import figure

# %%
def log_scale(img):
    img = np.log1p(img)
    return img

def inv_log(img):
    img = np.exp(img) - 1.
    return img

# %% [markdown]
# <div style="background-color: honeydew">
# <h2> Session Parameters </h2>
# </div>

# %%
# True uses PGHI (Truncated Gaussian window, log mag, PGHI reconstruction)
# False uses Log Mag spectrum and Griffin Lim reconstruction
tifresi=True

#STYLE_FILENAME = "inputs/fire.wav" #input filename
STYLE_FILENAME = "inputs/gansounds/pops4secs.wav" #input filename
#STYLE_FILENAME = "inputs/gansounds/hubub.10secs.wav" #input filename

#Go up to 20000 for high quality if you are on a GPU
num_steps=30000

# %%
display(Audio(STYLE_FILENAME))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <div style="background-color: honeydew">
# <h2> FFT and CNN parameters  </h2>
# (probably don't need to change)
# </div>

# %%
# set filenames
outname = 'test' #output dir
runs = 1 # no. of separate outputs (to test consistency), 1 if only want single output

#librosa audio params
N_FFT = 512 
K_HOP = 128 

# architecture
"""use a custom convolutional network randomly initialized""" 
use01scale = True #set to true if want to scale img to [0,1] prior to training. Recommended if using VGG19
boundopt = False #whether to regularize the input within [lower,upper]. Recommended if using VGG19
whichChannel = "freq" #2d=2d conv, 1d options:freq=freq bins as channels, time= time bins as channels 
N_FILTERS = 1024# 4096 #no. of filters in 1st conv layer
hor_filter = 5 #width of conv filter, for 2d also the height of (square) kernel

# %% [markdown]
# <div style="background-color: honeydew">
# <h4> TFResi params  </h4>
# (probably don't need to change)
# </div>

# %% [markdown]
# [Link to tfresi code.](https://github.com/andimarafioti/tifresi)

# %%
from tifresi.hparams import HParams
from tifresi.stft import GaussTruncTF

#from tifresi.transforms import log_spectrogram
#from tifresi.transforms import inv_log_spectrogram
#NOTE: Not using Marifioties 10 log_10 transform. Instead use natural log.
# This makes a HUGE difference !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
log_spectrogram=log_scale
inv_log_spectrogram=inv_log

stft_channels = HParams.stft_channels = N_FFT 
hop_size =  HParams.hop_size  = K_HOP
HParams.sr=16000 

# empirically set: - too small, get low-res ringing; too high, get distortion
tfresiMagSpectScale=5 # Takes the [0,1] mag spectrogram and maps it to [0, tfresiMagSpectScale]

# For faster processin, a truncated window can be used instead
stft_system = GaussTruncTF(hop_size=hop_size, stft_channels=stft_channels)

# %% [markdown]
# <div style="background-color: honeydew">
# <h4> Plumbing  </h4>
# </div>

# %%
use_cuda = torch.cuda.is_available() #use GPU if available
print('GPU available =',use_cuda)
dtype = torch.cuda.FloatTensor if use_cuda else torch.FloatTensor
# Out:
# GPU available = True

# %%
def read_audio_spectum(filename, tifresi=True):
    #x, fs = librosa.load(filename) #x=audiodata, fs=samplerate
    x, fs  = sf.read(filename)
    print(f'input file sample rate = {fs}')
    x=np.append(x, np.zeros(stft_channels-np.mod(len(x), stft_channels)))
    N_SAMPLES = len(x)
    x=x+np.random.normal(scale=.0001, size=N_SAMPLES)
    print(f'np.mod(len(x), stft_channels) = {np.mod(len(x), stft_channels)}')
    print(f' number of hops is {len(x)//hop_size}')
    
    if tifresi :
        print(f'In read audio, doing tifresi spectrogram')
        R=tfresiMagSpectScale*stft_system.spectrogram(x)
    else :
        print(f'In read audio, doing librosa spectrogram')
        R = np.abs(librosa.stft(x, n_fft=N_FFT, hop_length=K_HOP, win_length=N_FFT,  center=False))    
        
    print(f'R range is  [{np.amin(R)}, {np.amax(R)}')
    print(f'K_HOP - {K_HOP} and N_FFT is {N_FFT}')
    print(f'R shape is {R.shape}')
    return R, fs


def findMinMax(img):
    return int(math.floor(np.amin(img))),int(math.ceil(np.amax(img)))

def img_scale(img,datasetMin,datasetMax,scaleMin,scaleMax):
    """scales input numpy array from [datasetMin,datasetMax] -> [scaleMin,scaleMax]"""    
    shift = (scaleMax-scaleMin) / (datasetMax-datasetMin)
    scaled_values = shift * (img-datasetMin) + scaleMin
    print("Using [{0},{1}] -> [{2},{3}] for scale conversion".format(datasetMin,datasetMax,scaleMin,scaleMax))
    return scaled_values

def img_invscale(img,datasetMin,datasetMax,scaleMin,scaleMax):
    """scales input numpy array from [scaleMin,scaleMax] -> [datasetMin,datasetMax]"""
    shift = (datasetMax-datasetMin) / (scaleMax-scaleMin)
    scaled_values = shift * (img-scaleMin) + datasetMin
    print("Using [{0},{1}] -> [{2},{3}] for scale conversion".format(scaleMin,scaleMax,datasetMin,datasetMax))
    return scaled_values
    
#if 0
    # use below functions to use librosa db scale, normalized to [0,1]
    # note that this scaling does not work well for style transfer
    def db_scale(img,scale=80):
        img = librosa.amplitude_to_db(img)
        shift = float(np.amax(img))
        img = img - shift #put max at 0
        img = img/scale #scale from [-80,0] to [-1,0]
        img = img + 1. #shift to [0,1]
        img = np.maximum(img, 0) #clip anything below 0
        return img, shift

    def inv_db(img,shift,scale=80):
        img = img - 1. #shift from [0,1] to [-1,0]
        img = img * scale #[-1,0] -> [-80,0]
        img = img + shift
        img = librosa.db_to_amplitude(img)    
        return img

# %% [markdown]
# <div style="background-color: #AAFFAA">
# <h4> Prepare input and inspect.  </h4>
# </div>

# %%
R, fs = read_audio_spectum(STYLE_FILENAME, tifresi)
print(f"R range before log and scaling: [{np.amin(R)},{np.amax(R)}] ")
# Out:
# input file sample rate = 16000
# np.mod(len(x), stft_channels) = 0
#  number of hops is 504
# In read audio, doing tifresi spectrogram
# R range is  [5.9739249016106e-08, 5.0
# K_HOP - 128 and N_FFT is 512
# R shape is (257, 504)
# R range before log and scaling: [5.9739249016106e-08,5.0]

# %%
if tifresi :
    print('TIFResi: log_spectrogram')
    a_style = log_spectrogram(R)
else :
    print('HUZ: log_scase')
    a_style = log_scale(R)
    
print(f"    *  LOG  *  range before scaling: [{np.amin(a_style)},{np.amax(a_style)}]",)

if use01scale == True:
    a_min,a_max = findMinMax(a_style)
    a_style = img_scale(a_style,a_min,a_max,0,1)

"""we plot out the STFT magnitude range and the spectrogram do get a feel of the data"""
#plt.ion()
fig = plt.figure()
plt.title('Histogram of log Style Spectrogram vals')
ax = fig.add_subplot(111)
n,b,_ = ax.hist(a_style.flatten(),,bins=100)
#ax.set_yticklabels([])
#ax.set_xticks([])
maxbin = np.argmax(n)
plt.show()
print("Max bin:",b[maxbin])

plt.figure(figsize=(10, 5))
plt.title('Style spectrogram')
plt.imshow(a_style, origin='lower')
print("Style spectrogram range after scaling:",np.amin(a_style),np.amax(a_style))
temp_a_style=a_style # for reality check in next cell

N_SAMPLES = a_style.shape[1] #time bins
N_FREQ = a_style.shape[0] #freq bins

a_style = np.ascontiguousarray(a_style[None,None,:,:]) #[batch,channels,freq,samples]
if whichChannel == "2d":
    a_style = torch.from_numpy(a_style) #pytorch:[batch,channels(1),height(freq),width(samples)]
elif whichChannel == "freq":
    a_style = torch.from_numpy(a_style).permute(0,2,1,3) #pytorch:[batch,channels(freq),height(1),width(samples)]
elif whichChannel == "time":
    a_style = torch.from_numpy(a_style).permute(0,3,1,2) #pytorch:[batch,channels(samples),height(1),width(freq)]

style_img = Variable(a_style).type(dtype) #convert to pytorch variable
print("Using whichChannel ==",whichChannel," Input shape:",style_img.data.shape) #check shape is correct
# Out:
# TIFResi: log_spectrogram
#     *  LOG  *  range before scaling: [5.973924723171712e-08,1.791759469228055]
# Using [0,2] -> [0,1] for scale conversion
# Max bin: 6.136576156924852e-05
# Style spectrogram range after scaling: 2.986962361585856e-08 0.8958797346140275
# Using whichChannel == freq  Input shape: torch.Size([1, 257, 1, 504])

# %%
def imshow(tensor, channels=1, title=None, origin='lower'):
    """ transforms pytorch tensor to numpy array and plots it out """
    
    image = tensor.clone().cpu()  # we clone the tensor to not do changes on it
    if whichChannel == "2d":
        image = image
    if whichChannel == "freq":
        image = image.permute(0,2,1,3).contiguous() # get the dimensions in proper order
    elif whichChannel == "time":
        image = image.permute(0,2,3,1).contiguous() # get the dimensions in proper order
    image = image.view(N_FREQ,N_SAMPLES)  # remove the fake batch dimension
    
    image = image.numpy() #convert pytorch tensor to numpy array
    print(image.shape) #check shape
    print("Output range:",np.amin(image),np.amax(image))
    
    
    plt.imshow(image, origin=origin)
    if title is not None:
        plt.title(title)
    plt.pause(0.001) # pause a bit so that plots are updated
    return image #return numpy array

"Just to check we can get back the numpy array with the correct shape"
plt.figure(figsize=(10, 5))
plt.figure()
_=imshow(style_img.data, title='Style Spectrogram', origin='lower')

#plt.figure()
#imshow(content_img.data, title='Content Image')
# Out:
# (257, 504)
# Output range: 2.9869625e-08 0.89587975

# %% [markdown]
# <div style="background-color: #AAFFAA">
# <h4> Create network   </h4>
# </div>

# %%
"Here we create the custom network"
import collections as c

if whichChannel == "2d":
    IN_CHANNELS = 1
elif whichChannel == "freq":
    IN_CHANNELS = N_FREQ
elif whichChannel == "time":
    IN_CHANNELS = N_SAMPLES
    

# custom weights initialization
def weights_init(m):
    std = np.sqrt(2) * np.sqrt(2.0 / ((N_FREQ + N_FILTERS) * hor_filter))
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        m.weight.data.normal_(0.0, std)

class style_net(nn.Module):
    """Here create the network you want to use by adding/removing layers in nn.Sequential"""
    def __init__(self):
        super(style_net, self).__init__()
        self.layers = nn.Sequential(c.OrderedDict([
                            ('conv1',nn.Conv2d(IN_CHANNELS,N_FILTERS,kernel_size=(1,hor_filter),bias=False)),
                            ('relu1',nn.ReLU()),
                            ('max1', nn.MaxPool2d(kernel_size=(1,2))),
            
                            ('conv2',nn.Conv2d(N_FILTERS,N_FILTERS//2,kernel_size=(1,hor_filter),bias=False)),
                            ('relu2',nn.ReLU()),
                            ('max2', nn.MaxPool2d(kernel_size=(1,2))),
        
                            ('conv3',nn.Conv2d(N_FILTERS//2,N_FILTERS//2,kernel_size=(1,hor_filter),bias=False)),
                            ('relu3',nn.ReLU()),
                            ('max3', nn.MaxPool2d(kernel_size=(1,2))),
                
                            ('conv4',nn.Conv2d(N_FILTERS//2,N_FILTERS//4,kernel_size=(1,hor_filter),bias=False)),
                            ('relu4',nn.ReLU()),
                            ('max4', nn.MaxPool2d(kernel_size=(1,2))),

                            
                            ('conv5',nn.Conv2d(N_FILTERS//4,N_FILTERS//4,kernel_size=(1,hor_filter),bias=False)),
                            ('relu5',nn.ReLU()),
                            ('max5', nn.MaxPool2d(kernel_size=(1,2))),

            
                            ('conv6',nn.Conv2d(N_FILTERS//4,N_FILTERS//8,kernel_size=(1,hor_filter),bias=False)),
                            ('relu6',nn.ReLU())]))
        
    def forward(self,input):
        out = self.layers(input)
        return out
    
cnn = style_net()
cnn.apply(weights_init)
for param in cnn.parameters():
    param.requires_grad = False
print(list(cnn.layers))

# move it to the GPU if possible:
if use_cuda:
    cnn = cnn.cuda()

# Add the style/content loss 'layer' after the specified layer:
content_layers_default = [] #ignore for now
#style_layers_default = ['relu_1', 'relu_2', 'relu_3','relu_4', 'relu_5', 'relu_6'] #'relu_1'
style_layers_default = ['relu_1', 'relu_2', 'relu_3','relu_4', 'relu_5', 'relu_6']
# Out:
# [Conv2d(257, 1024, kernel_size=(1, 5), stride=(1, 1), bias=False), ReLU(), MaxPool2d(kernel_size=(1, 2), stride=(1, 2), padding=0, dilation=1, ceil_mode=False), Conv2d(1024, 512, kernel_size=(1, 5), stride=(1, 1), bias=False), ReLU(), MaxPool2d(kernel_size=(1, 2), stride=(1, 2), padding=0, dilation=1, ceil_mode=False), Conv2d(512, 512, kernel_size=(1, 5), stride=(1, 1), bias=False), ReLU(), MaxPool2d(kernel_size=(1, 2), stride=(1, 2), padding=0, dilation=1, ceil_mode=False), Conv2d(512, 256, kernel_size=(1, 5), stride=(1, 1), bias=False), ReLU(), MaxPool2d(kernel_size=(1, 2), stride=(1, 2), padding=0, dilation=1, ceil_mode=False), Conv2d(256, 256, kernel_size=(1, 5), stride=(1, 1), bias=False), ReLU(), MaxPool2d(kernel_size=(1, 2), stride=(1, 2), padding=0, dilation=1, ceil_mode=False), Conv2d(256, 128, kernel_size=(1, 5), stride=(1, 1), bias=False), ReLU()]

# %% [markdown]
# Content loss
# ~~~~~~~~~~~~
#
# The content loss is a function that takes as input the feature maps
# $F_{XL}$ at a layer $L$ in a network fed by $X$ and
# return the weigthed content distance $w_{CL}.D_C^L(X,C)$ between
# this image and the content image. Hence, the weight $w_{CL}$ and
# the target content $F_{CL}$ are parameters of the function. We
# implement this function as a torch module with a constructor that takes
# these parameters as input. The distance $\|F_{XL} - F_{YL}\|^2$ is
# the Mean Square Error between the two sets of feature maps, that can be
# computed using a criterion ``nn.MSELoss`` stated as a third parameter.
#
# We will add our content losses at each desired layer as additive modules
# of the neural network. That way, each time we will feed the network with
# an input image $X$, all the content losses will be computed at the
# desired layers and, thanks to autograd, all the gradients will be
# computed. For that, we just need to make the ``forward`` method of our
# module returning the input: the module becomes a ''transparent layer''
# of the neural network. The computed loss is saved as a parameter of the
# module.
#
# Finally, we define a fake ``backward`` method, that just call the
# backward method of ``nn.MSELoss`` in order to reconstruct the gradient.
# This method returns the computed loss: this will be useful when running
# the gradient descent in order to display the evolution of style and
# content losses.

# %%
class ContentLoss(nn.Module):
    """Since doing texture only we ignore this for now"""

    def __init__(self, target, weight): #weight here is the epsilon tuning (how much content vs style)
        super(ContentLoss, self).__init__()
        # we 'detach' the target content from the tree used
        self.target = target.detach() * weight
        # to dynamically compute the gradient: this is a stated value,
        # not a variable. Otherwise the forward method of the criterion
        # will throw an error.
        self.weight = weight
        self.criterion = nn.MSELoss()

    def forward(self, input):
        self.loss = self.criterion(input * self.weight, self.target)
        self.output = input
        return self.output

    def backward(self, retain_variables=True):
        self.loss.backward(retain_variables=retain_variables)
        return self.loss

# %% [markdown]
# .. Note::
#    **Important detail**: this module, although it is named ``ContentLoss``,
#    is not a true PyTorch Loss function. If you want to define your content
#    loss as a PyTorch Loss, you have to create a PyTorch autograd Function
#    and to recompute/implement the gradient by the hand in the ``backward``
#    method.
#
# Style loss
# ~~~~~~~~~~
#
# For the style loss, we need first to define a module that compute the
# gram produce $G_{XL}$ given the feature maps $F_{XL}$ of the
# neural network fed by $X$, at layer $L$. Let
# $\hat{F}_{XL}$ be the re-shaped version of $F_{XL}$ into a
# $K$\ x\ $N$ matrix, where $K$ is the number of feature
# maps at layer $L$ and $N$ the lenght of any vectorized
# feature map $F_{XL}^k$. The $k^{th}$ line of
# $\hat{F}_{XL}$ is $F_{XL}^k$. We let you check that
# $\hat{F}_{XL} \cdot \hat{F}_{XL}^T = G_{XL}$. Given that, it
# becomes easy to implement our module:

# %%
class GramMatrix(nn.Module):

    def forward(self, input):
        a, b, c, d = input.size() #a=batch size(=1)
                                  #b=number of feature maps
                                  #(c,d)=dimensions of a feat. map (N=c*d) -> for 1D conv c=1
        #features = input.view(a * b, c * d)  # resise F_XL into \hat F_XL
        features = input.view(b, a * c * d)  # resise F_XL into \hat F_XL

        G = torch.mm(features, features.t())  # compute the gram product

        # we 'normalize' the values of the gram matrix
        # by dividing by the number of element in each feature maps.
        return G.div(a * c * d)

# %% [markdown]
# The longer is the feature maps dimension $N$, the bigger are the
# values of the gram matrix. Therefore, if we don't normalize by $N$,
# the loss computed at the first layers (before pooling layers) will have
# much more importance during the gradient descent. We dont want that,
# since the most interesting style features are in the deepest layers!
#
# Then, the style loss module is implemented exactly the same way than the
# content loss module, but we have to add the ``gramMatrix`` as a
# parameter:

# %%
class StyleLoss(nn.Module):

    def __init__(self, target, weight): #weight here is the alpha tuning (how much content vs style)
        super(StyleLoss, self).__init__()
        self.target = target.detach() * weight
        self.weight = weight
        self.gram = GramMatrix()
        self.criterion = nn.MSELoss(size_average=False)

    def forward(self, input):
        self.output = input.clone()
        self.G = self.gram(input)
        self.G.mul_(self.weight)
        self.loss = self.criterion(self.G, self.target) #target=gram mat for style img, G=gram mat for current input ie. noise
        return self.output

    def backward(self, retain_variables=True):
        self.loss.backward(retain_graph=True)
        return self.loss

# %%
class OptReg(nn.Module):
    """soft bound the optimization between [lower,upper] by regularization"""
    
    def __init__(self, upper, lower, weight=1): #weight here is the alpha tuning (how much content vs style)
        super(OptReg, self).__init__()
        self.upper = Variable(torch.cuda.FloatTensor([upper]))
        self.lower = Variable(torch.cuda.FloatTensor([lower]))
        self.weight = weight

    def forward(self, input):
        #self.output = input.clone()
        self.zeros = Variable(torch.zeros(input.size()).type(dtype))
                              
        self.over = torch.max(input-self.upper,self.zeros)
        self.under = torch.max(self.lower-input,self.zeros)
        self.total= self.over + self.under
        self.l2total = self.weight * self.total.norm(2)
        #print(f'OptReg l2total = {self.l2total}')
        return self.l2total

# %% [raw]
# a = Variable(torch.cuda.FloatTensor([[2,0,2],[1,0,1]]))
# b = Variable(torch.cuda.FloatTensor([[5,0,5],[-1,0,-1]]))
# c = Variable(torch.cuda.FloatTensor([1]))
# d = c-a
# print(d)
# e = torch.max(d,b)
# f = e+e
# print(f)
# g = f.norm(2)
# print(g)
#
# def optbound_regularizer_old(img,upper,lower):
#     """soft bound the optimization between [lower,upper] by regularization"""
#     #print(torch.max(img),torch.min(img))
#     imgn = Variable(img)
#     over = torch.max(imgn.data-upper,torch.zeros(img.size()).type(dtype))
#     #print("over",over)
#     under = torch.max(lower-imgn.data,torch.zeros(img.size()).type(dtype))
#     #print("under",under)
#     out = over + under
#     #print("out",out)
#     out = out.norm(2)
#     #print("norm",out)
#     #l2_reg = torch.cuda.FloatTensor([out])
#     l2_reg = Variable(torch.cuda.FloatTensor([out]), requires_grad=True)
#
#     return l2_reg
#
# def optbound_regularizer(img,upper,lower,reg_weight):
#     """soft bound the optimization between [lower,upper] by regularization"""
#     #print(torch.max(img),torch.min(img))
#     zero_var = Variable(torch.zeros(img.size()).type(dtype))
#     over = Variable(torch.max(img-upper,torch.zeros(img.size()).type(dtype)), requires_grad=True)
#     crit_over = nn.MSELoss(size_average=False)
#     over_loss = crit_over(over,zero_var)
#     #print("over",over)
#     under = Variable(torch.max(lower-img,torch.zeros(img.size()).type(dtype)), requires_grad=True)
#     crit_under = nn.MSELoss(size_average=False)
#     under_loss = crit_under(under,zero_var)
#     #print("under",under)
#     out = over_loss + under_loss
#     #print("out",out)
#     #out = out.norm(2)
#     #print("norm",out)
#     #l2_reg = torch.cuda.FloatTensor([out])
#     #l2_reg = Variable(torch.cuda.FloatTensor([out]), requires_grad=True)
#     out = reg_weight * out
#     #optbound = out.backward(retain_graph=True)
#
#     return out #optbound

# %% [markdown]
# Load the neural network
# ~~~~~~~~~~~~~~~~~~~~~~~
#
# Now, we have to import a pre-trained neural network. As in the paper, we
# are going to use a pretrained VGG network with 19 layers (VGG19).
#
# PyTorch's implementation of VGG is a module divided in two child
# ``Sequential`` modules: ``features`` (containing convolution and pooling
# layers) and ``classifier`` (containing fully connected layers). We are
# just interested by ``features``:

# %% [markdown]
# A ``Sequential`` module contains an ordered list of child modules. For
# instance, ``vgg19.features`` contains a sequence (Conv2d, ReLU,
# Maxpool2d, Conv2d, ReLU...) aligned in the right order of depth. As we
# said in *Content loss* section, we wand to add our style and content
# loss modules as additive 'transparent' layers in our network, at desired
# depths. For that, we construct a new ``Sequential`` module, in wich we
# are going to add modules from ``vgg19`` and our loss modules in the
# right order:

# %%
#rebuild network with the layers we want
def get_style_model_and_losses(cnn, style_img, content_img=None,
                               style_weight=1, content_weight=0,
                               content_layers=content_layers_default,
                               style_layers=style_layers_default):
    cnn = copy.deepcopy(cnn)

    # just in order to have an iterable access to or list of content/syle losses
    content_losses = []
    style_losses = []
    
    model = nn.Sequential()
    layer_list = list(cnn.layers)
    
    gram = GramMatrix()  # we need a gram module in order to compute style targets

    # move these modules to the GPU if possible:
    if use_cuda:
        model = model.cuda()
        gram = gram.cuda()

    #here we rebuild the network adding the in content and style loss "layers"   
    i = 1  
    for layer in layer_list:
        
        if isinstance(layer, nn.Conv2d): #if layer in vgg19 belong to class nn.Conv2d
            name = "conv_" + str(i)
            model.add_module(name, layer) #add that layer to our sequential model
            
            if content_img != None:
                if name in content_layers: #at the right depth add the content loss "layer"
                    # add content loss:
                    target = model(content_img).clone()
                    content_loss = ContentLoss(target, content_weight)
                    model.add_module("content_loss_" + str(i), content_loss)
                    content_losses.append(content_loss)

            if name in style_layers: #at the right depth add the content loss "layer"
                # add style loss:
                target_feature = model(style_img).clone()
                target_feature_gram = gram(target_feature)
                style_loss = StyleLoss(target_feature_gram, style_weight)
                model.add_module("style_loss_" + str(i), style_loss)
                style_losses.append(style_loss)

        if isinstance(layer, nn.ReLU): #do the same for ReLUs
            name = "relu_" + str(i)
            model.add_module(name, layer)
            
            if content_img != None:
                if name in content_layers:
                    # add content loss:
                    target = model(content_img).clone()
                    content_loss = ContentLoss(target, content_weight)
                    model.add_module("content_loss_" + str(i), content_loss)
                    content_losses.append(content_loss)

            if name in style_layers:
                # add style loss:
                target_feature = model(style_img).clone()
                target_feature_gram = gram(target_feature)
                style_loss = StyleLoss(target_feature_gram, style_weight)
                model.add_module("style_loss_" + str(i), style_loss)
                style_losses.append(style_loss) 
                
            i += 1

        if isinstance(layer, nn.MaxPool2d): #do the same for maxpool
            name = "pool_" + str(i)
            model.add_module(name, layer)
            
            if name in style_layers:
                # add style loss:
                target_feature = model(style_img).clone()
                target_feature_gram = gram(target_feature)
                style_loss = StyleLoss(target_feature_gram, style_weight)
                model.add_module("style_loss_" + str(i), style_loss)
                style_losses.append(style_loss)
            
            #avgpool = nn.AvgPool2d(kernel_size=(1,2),
            #                stride=layer.stride, padding = layer.padding)
            #model.add_module(name, avgpool)  # *** can also replace certain layers if we want eg. maxpool -> avgpool


    #for param in model.parameters():
    #    param.requires_grad = False
    return model, style_losses, content_losses

# %% [markdown]
# .. Note::
#    In the paper they recommend to change max pooling layers into
#    average pooling. With AlexNet, that is a small network compared to VGG19
#    used in the paper, we are not going to see any difference of quality in
#    the result. However, you can use these lines instead if you want to do
#    this substitution:
#
#    ::
#
#        # avgpool = nn.AvgPool2d(kernel_size=layer.kernel_size,
#        #                         stride=layer.stride, padding = layer.padding)
#        # model.add_module(name,avgpool)

# %% [markdown]
# Input image
# ~~~~~~~~~~~
#
# Again, in order to simplify the code, we take an image of the same
# dimensions than content and style images. This image can be a white
# noise, or it can also be a copy of the content-image.

# %% [markdown]
# <div style="background-color: #AAFFAA">
# <h4> Prepare noise as input  </h4>
# </div>

# %%
"""image to input in generative network"""
#input_img = content_img.clone()

# if you want to use a white noise instead uncomment the below line:
#input_img = Variable(torch.randn(content_img.data.size())).type(dtype)

def in_img():
    """initialize (runs) number of unique random noise input images"""  
    input_imgs = []
    #rand_tensor = torch.randn(1,N_FREQ,1,N_SAMPLES)*1e-3
    lower,upper,mu,sigma = 1e-3,1,.5,1e-1
    dist = stats.truncnorm((lower-mu)/sigma,(upper-mu)/sigma,loc=mu,scale=sigma)
    
    i = 0
    while i < runs:
         #[batch,channels,h,w]
        if whichChannel == "2d":
            samples = dist.rvs([1,1,N_FREQ,N_SAMPLES])
            input_imgs.append(Variable(torch.from_numpy(samples)).type(dtype))
            #input_imgs.append(Variable(torch.rand(1,1,N_FREQ,N_SAMPLES)*1e-3).type(dtype))
            #input_imgs.append(Variable(torch.randn(1,1,N_FREQ,N_SAMPLES)*1e-3).type(dtype))
        if whichChannel == "freq":
            #samples = dist.rvs([1,N_FREQ,1,N_SAMPLES])
            #input_imgs.append(Variable(torch.from_numpy(samples)).type(dtype))
            #input_imgs.append(Variable(torch.rand(1,N_FREQ,1,N_SAMPLES)*1e-3).type(dtype))
            input_imgs.append(Variable(mu+torch.randn(1,N_FREQ,1,N_SAMPLES)*1e-3).type(dtype))
        elif whichChannel == "time":
            samples = dist.rvs([1,N_SAMPLES,1,N_FREQ])
            input_imgs.append(Variable(torch.from_numpy(samples)).type(dtype))
            #input_imgs.append(Variable(torch.rand(1,N_SAMPLES,1,N_FREQ)*1e-3).type(dtype))
            #input_imgs.append(Variable(torch.randn(1,N_SAMPLES,1,N_FREQ)*1e-3).type(dtype))
        i +=1
    return input_imgs

input_imgs = in_img()

# add the original input image to the figure:
plt.figure()
_=imshow(input_imgs[0].data, title='Input Image')
# Out:
# (257, 504)
# Output range: 0.49555984 0.50436026

# %% [markdown]
# Gradient descent
# ~~~~~~~~~~~~~~~~
#
# As Leon Gatys, the author of the algorithm, suggested
# `here <https://discuss.pytorch.org/t/pytorch-tutorial-for-neural-transfert-of-artistic-style/336/20?u=alexis-jacq>`__,
# we will use L-BFGS algorithm to run our gradient descent. Unlike
# training a network, we want to train the input image in order to
# minimise the content/style losses. We would like to simply create a
# PyTorch  L-BFGS optimizer, passing our image as the variable to optimize.
# But ``optim.LBFGS`` takes as first argument a list of PyTorch
# ``Variable`` that require gradient. Our input image is a ``Variable``
# but is not a leaf of the tree that requires computation of gradients. In
# order to show that this variable requires a gradient, a possibility is
# to construct a ``Parameter`` object from the input image. Then, we just
# give a list containing this ``Parameter`` to the optimizer's
# constructor:

# %%
def get_input_param_optimizer(input_img):
    # this line to show that input is a parameter that requires a gradient
    input_param = nn.Parameter(input_img.data)
    optimizer = optim.LBFGS([input_param])
    return input_param, optimizer

# %% [markdown]
# **Last step**: the loop of gradient descent. At each step, we must feed
# the network with the updated input in order to compute the new losses,
# we must run the ``backward`` methods of each loss to dynamically compute
# their gradients and perform the step of gradient descent. The optimizer
# requires as argument a "closure": a function that reevaluates the model
# and returns the loss.

# %%
def run_style_transfer(cnn, style_img, input_img, content_img=None, num_steps=num_steps,
                       style_weight=1, content_weight=0, reg_weight=0.001):
    """Run the style transfer"""
    
    print('Building the style transfer model..')
    model, style_losses, content_losses = get_style_model_and_losses(cnn,
        style_img, content_img, style_weight, content_weight)
    input_param, optimizer = get_input_param_optimizer(input_img)
    
    print("Input range:",torch.max(input_param.data),torch.min(input_param.data))   
    print(model)
    print('Optimizing..')
    run = [0]
    
    if boundopt == True:
        bound = OptReg(1,0, reg_weight)
    
    while run[0] <= num_steps:

        def closure():
            # correct the values of updated input image
            #if use01scale == True:
                #input_param.data.clamp_(0, 1)

            optimizer.zero_grad()
            model(input_param)
            style_score = 0
            content_score = 0
          
            if boundopt == True:
                bound.zero_grad()
                reg = bound(input_param)
                if not torch.equal(reg.data,torch.cuda.FloatTensor([0])):
                    reg.backward()

            for sl in style_losses:
                style_score += sl.backward() #call backward method to grab the loss

            #for cl in content_losses:
            #    content_score += cl.backward()
            
            if boundopt == True:
                total_loss = style_score + reg  #+ content_score
            else:
                total_loss = style_score

            run[0] += 1
            
            if run[0] % 50 == 0:
                #print("reg", reg)
                #print(torch.max(input_param.data),torch.min(input_param.data))
                
                print("run {}:".format(run))
                print('Style Loss : {:4f}'.format(
                    #style_score.data[0]))
                    style_score.data))
                if boundopt == True:
                    print('Bound Loss : {:4f}'.format(
                       #reg.data[0]))
                        reg.data))
                print(torch.max(input_param.data),torch.min(input_param.data))
                print('Total Loss : {:4f}'.format(
                    # total_loss.data[0]))
                    total_loss.data))
                          
            return total_loss   
        
        optimizer.step(closure)
        
    # a last correction...
    #if use01scale == True:
        #input_param.data.clamp_(0, 1)

    return input_param.data

# %% [markdown]
# <div style="background-color: #AAFFAA">
# <h4> Finally, run the algorithm  </h4>
# </div>

# %%
outputs = []
i = 0
while i < runs:
    
    output = run_style_transfer(cnn, style_img, input_imgs[i])

    plt.figure()
    out = imshow(output, title='Output Image')
    outputs.append(out)
    i += 1

# sphinx_gallery_thumbnail_number = 4
plt.show()
# Out:
# Building the style transfer model..
# Input range: tensor(0.5044, device='cuda:0') tensor(0.4956, device='cuda:0')
# Sequential(
#   (conv_1): Conv2d(257, 1024, kernel_size=(1, 5), stride=(1, 1), bias=False)
#   (relu_1): ReLU()
#   (style_loss_1): StyleLoss(
#     (gram): GramMatrix()
#     (criterion): MSELoss()
#   )
#   (pool_2): MaxPool2d(kernel_size=(1, 2), stride=(1, 2), padding=0, dilation=1, ceil_mode=False)
#   (conv_2): Conv2d(1024, 512, kernel_size=(1, 5), stride=(1, 1), bias=False)
#   (relu_2): ReLU()
#   (style_loss_2): StyleLoss(
#     (gram): GramMatrix()
#     (criterion): MSELoss()
#   )
#   (pool_3): MaxPool2d(kernel_size=(1, 2), stride=(1, 2), padding=0, dilation=1, ceil_mode=False)
#   (conv_3): Conv2d(512, 512, kernel_size=(1, 5), stride=(1, 1), bias=False)
#   (relu_3): ReLU()
#   (style_loss_3): StyleLoss(
#     (gram): GramMatrix()
#     (criterion): MSELoss()
#   )
#   (pool_4): MaxPool2d(kernel_size=(1, 2), stride=(1, 2), padding=0, dilation=1, ceil_mode=False)
#   (conv_4): Conv2d(512, 256, kernel_size=(1, 5), stride=(1, 1), bias=False)
#   (relu_4): ReLU()
#   (style_loss_4): StyleLoss(
#     (gram): GramMatrix()
#     (criterion): MSELoss()
#   )
#   (pool_5): MaxPool2d(kernel_size=(1, 2), stride=(1, 2), padding=0, dilation=1, ceil_mode=False)
#   (conv_5): Conv2d(256, 256, kernel_size=(1, 5), stride=(1, 1), bias=False)
#   (relu_5): ReLU()
#   (style_loss_5): StyleLoss(
#     (gram): GramMatrix()
#     (criterion): MSELoss()
#   )
#   (pool_6): MaxPool2d(kernel_size=(1, 2), stride=(1, 2), padding=0, dilation=1, ceil_mode=False)
#   (conv_6): Conv2d(256, 128, kernel_size=(1, 5), stride=(1, 1), bias=False)
#   (relu_6): ReLU()
#   (style_loss_6): StyleLoss(
#     (gram): GramMatrix()
#     (criterion): MSELoss()
#   )
# )
# Optimizing..
# run [50]:
# Style Loss : 0.002617
# tensor(0.9054, device='cuda:0') tensor(-0.3580, device='cuda:0')
# Total Loss : 0.002617
# run [100]:
# Style Loss : 0.000555
# tensor(0.9109, device='cuda:0') tensor(-0.3593, device='cuda:0')
# Total Loss : 0.000555
# run [150]:
# Style Loss : 0.000196
# tensor(0.9149, device='cuda:0') tensor(-0.3440, device='cuda:0')
# Total Loss : 0.000196
# run [200]:
# Style Loss : 0.000107
# tensor(0.9034, device='cuda:0') tensor(-0.3327, device='cuda:0')
# Total Loss : 0.000107
# run [250]:
# Style Loss : 0.000069
# tensor(0.8856, device='cuda:0') tensor(-0.3200, device='cuda:0')
# Total Loss : 0.000069
# run [300]:
# Style Loss : 0.000051
# tensor(0.8729, device='cuda:0') tensor(-0.3081, device='cuda:0')
# Total Loss : 0.000051
# run [350]:
# Style Loss : 0.000041
# tensor(0.8821, device='cuda:0') tensor(-0.3122, device='cuda:0')
# Total Loss : 0.000041
# run [400]:
# Style Loss : 0.000035
# tensor(0.9146, device='cuda:0') tensor(-0.3145, device='cuda:0')
# Total Loss : 0.000035
# run [450]:
# Style Loss : 0.000032
# tensor(0.9345, device='cuda:0') tensor(-0.3170, device='cuda:0')
# Total Loss : 0.000032
# run [500]:
# Style Loss : 0.000029
# tensor(0.9482, device='cuda:0') tensor(-0.3184, device='cuda:0')
# Total Loss : 0.000029
# run [550]:
# Style Loss : 0.000027
# tensor(0.9556, device='cuda:0') tensor(-0.3197, device='cuda:0')
# Total Loss : 0.000027
# run [600]:
# Style Loss : 0.000026
# tensor(0.9610, device='cuda:0') tensor(-0.3209, device='cuda:0')
# Total Loss : 0.000026
# run [650]:
# Style Loss : 0.000025
# tensor(0.9637, device='cuda:0') tensor(-0.3218, device='cuda:0')
# Total Loss : 0.000025
# run [700]:
# Style Loss : 0.000024
# tensor(0.9644, device='cuda:0') tensor(-0.3222, device='cuda:0')
# Total Loss : 0.000024
# run [750]:
# Style Loss : 0.000023
# tensor(0.9645, device='cuda:0') tensor(-0.3219, device='cuda:0')
# Total Loss : 0.000023
# run [800]:
# Style Loss : 0.000022
# tensor(0.9630, device='cuda:0') tensor(-0.3214, device='cuda:0')
# Total Loss : 0.000022
# run [850]:
# Style Loss : 0.000022
# tensor(0.9605, device='cuda:0') tensor(-0.3209, device='cuda:0')
# Total Loss : 0.000022
# run [900]:
# Style Loss : 0.000021
# tensor(0.9571, device='cuda:0') tensor(-0.3204, device='cuda:0')
# Total Loss : 0.000021
# run [950]:
# Style Loss : 0.000021
# tensor(0.9537, device='cuda:0') tensor(-0.3198, device='cuda:0')
# Total Loss : 0.000021
# run [1000]:
# Style Loss : 0.000020
# tensor(0.9505, device='cuda:0') tensor(-0.3194, device='cuda:0')
# Total Loss : 0.000020
# run [1050]:
# Style Loss : 0.000020
# tensor(0.9474, device='cuda:0') tensor(-0.3207, device='cuda:0')
# Total Loss : 0.000020
# run [1100]:
# Style Loss : 0.000020
# tensor(0.9448, device='cuda:0') tensor(-0.3218, device='cuda:0')
# Total Loss : 0.000020
# run [1150]:
# Style Loss : 0.000019
# tensor(0.9425, device='cuda:0') tensor(-0.3227, device='cuda:0')
# Total Loss : 0.000019
# run [1200]:
# Style Loss : 0.000019
# tensor(0.9399, device='cuda:0') tensor(-0.3235, device='cuda:0')
# Total Loss : 0.000019
# run [1250]:
# Style Loss : 0.000019
# tensor(0.9376, device='cuda:0') tensor(-0.3242, device='cuda:0')
# Total Loss : 0.000019
# run [1300]:
# Style Loss : 0.000019
# tensor(0.9348, device='cuda:0') tensor(-0.3249, device='cuda:0')
# Total Loss : 0.000019
# run [1350]:
# Style Loss : 0.000018
# tensor(0.9322, device='cuda:0') tensor(-0.3256, device='cuda:0')
# Total Loss : 0.000018
# run [1400]:
# Style Loss : 0.000018
# tensor(0.9297, device='cuda:0') tensor(-0.3263, device='cuda:0')
# Total Loss : 0.000018
# run [1450]:
# Style Loss : 0.000018
# tensor(0.9273, device='cuda:0') tensor(-0.3270, device='cuda:0')
# Total Loss : 0.000018
# run [1500]:
# Style Loss : 0.000018
# tensor(0.9250, device='cuda:0') tensor(-0.3279, device='cuda:0')
# Total Loss : 0.000018
# run [1550]:
# Style Loss : 0.000018
# tensor(0.9231, device='cuda:0') tensor(-0.3288, device='cuda:0')
# Total Loss : 0.000018
# run [1600]:
# Style Loss : 0.000018
# tensor(0.9210, device='cuda:0') tensor(-0.3297, device='cuda:0')
# Total Loss : 0.000018
# run [1650]:
# Style Loss : 0.000018
# tensor(0.9191, device='cuda:0') tensor(-0.3306, device='cuda:0')
# Total Loss : 0.000018
# run [1700]:
# Style Loss : 0.000017
# tensor(0.9170, device='cuda:0') tensor(-0.3315, device='cuda:0')
# Total Loss : 0.000017
# run [1750]:
# Style Loss : 0.000017
# tensor(0.9150, device='cuda:0') tensor(-0.3324, device='cuda:0')
# Total Loss : 0.000017
# run [1800]:
# Style Loss : 0.000017
# tensor(0.9131, device='cuda:0') tensor(-0.3332, device='cuda:0')
# Total Loss : 0.000017
# run [1850]:
# Style Loss : 0.000017
# tensor(0.9110, device='cuda:0') tensor(-0.3340, device='cuda:0')
# Total Loss : 0.000017
# run [1900]:
# Style Loss : 0.000017
# tensor(0.9092, device='cuda:0') tensor(-0.3345, device='cuda:0')
# Total Loss : 0.000017
# run [1950]:
# Style Loss : 0.000017
# tensor(0.9077, device='cuda:0') tensor(-0.3350, device='cuda:0')
# Total Loss : 0.000017
# run [2000]:
# Style Loss : 0.000017
# tensor(0.9060, device='cuda:0') tensor(-0.3355, device='cuda:0')
# Total Loss : 0.000017
# run [2050]:
# Style Loss : 0.000017
# tensor(0.9049, device='cuda:0') tensor(-0.3359, device='cuda:0')
# Total Loss : 0.000017
# run [2100]:
# Style Loss : 0.000017
# tensor(0.9041, device='cuda:0') tensor(-0.3362, device='cuda:0')
# Total Loss : 0.000017
# run [2150]:
# Style Loss : 0.000017
# tensor(0.9034, device='cuda:0') tensor(-0.3365, device='cuda:0')
# Total Loss : 0.000017
# run [2200]:
# Style Loss : 0.000017
# tensor(0.9028, device='cuda:0') tensor(-0.3368, device='cuda:0')
# Total Loss : 0.000017
# run [2250]:
# Style Loss : 0.000016
# tensor(0.9022, device='cuda:0') tensor(-0.3370, device='cuda:0')
# Total Loss : 0.000016
# run [2300]:
# Style Loss : 0.000016
# tensor(0.9018, device='cuda:0') tensor(-0.3372, device='cuda:0')
# Total Loss : 0.000016
# run [2350]:
# Style Loss : 0.000016
# tensor(0.9014, device='cuda:0') tensor(-0.3375, device='cuda:0')
# Total Loss : 0.000016
# run [2400]:
# Style Loss : 0.000016
# tensor(0.9012, device='cuda:0') tensor(-0.3377, device='cuda:0')
# Total Loss : 0.000016
# run [2450]:
# Style Loss : 0.000016
# tensor(0.9011, device='cuda:0') tensor(-0.3379, device='cuda:0')
# Total Loss : 0.000016
# run [2500]:
# Style Loss : 0.000016
# tensor(0.9010, device='cuda:0') tensor(-0.3381, device='cuda:0')
# Total Loss : 0.000016
# run [2550]:
# Style Loss : 0.000016
# tensor(0.9007, device='cuda:0') tensor(-0.3383, device='cuda:0')
# Total Loss : 0.000016
# run [2600]:
# Style Loss : 0.000016
# tensor(0.9005, device='cuda:0') tensor(-0.3385, device='cuda:0')
# Total Loss : 0.000016
# run [2650]:
# Style Loss : 0.000016
# tensor(0.9002, device='cuda:0') tensor(-0.3387, device='cuda:0')
# Total Loss : 0.000016
# run [2700]:
# Style Loss : 0.000016
# tensor(0.9000, device='cuda:0') tensor(-0.3389, device='cuda:0')
# Total Loss : 0.000016
# run [2750]:
# Style Loss : 0.000016
# tensor(0.8998, device='cuda:0') tensor(-0.3391, device='cuda:0')
# Total Loss : 0.000016
# run [2800]:
# Style Loss : 0.000016
# tensor(0.8996, device='cuda:0') tensor(-0.3393, device='cuda:0')
# Total Loss : 0.000016
# run [2850]:
# Style Loss : 0.000016
# tensor(0.8993, device='cuda:0') tensor(-0.3395, device='cuda:0')
# Total Loss : 0.000016
# run [2900]:
# Style Loss : 0.000016
# tensor(0.8991, device='cuda:0') tensor(-0.3396, device='cuda:0')
# Total Loss : 0.000016
# run [2950]:
# Style Loss : 0.000016
# tensor(0.8989, device='cuda:0') tensor(-0.3398, device='cuda:0')
# Total Loss : 0.000016
# run [3000]:
# Style Loss : 0.000016
# tensor(0.8985, device='cuda:0') tensor(-0.3401, device='cuda:0')
# Total Loss : 0.000016
# run [3050]:
# Style Loss : 0.000016
# tensor(0.8981, device='cuda:0') tensor(-0.3404, device='cuda:0')
# Total Loss : 0.000016
# run [3100]:
# Style Loss : 0.000016
# tensor(0.8978, device='cuda:0') tensor(-0.3407, device='cuda:0')
# Total Loss : 0.000016
# run [3150]:
# Style Loss : 0.000016
# tensor(0.8975, device='cuda:0') tensor(-0.3409, device='cuda:0')
# Total Loss : 0.000016
# run [3200]:
# Style Loss : 0.000016
# tensor(0.8972, device='cuda:0') tensor(-0.3411, device='cuda:0')
# Total Loss : 0.000016
# run [3250]:
# Style Loss : 0.000016
# tensor(0.8970, device='cuda:0') tensor(-0.3414, device='cuda:0')
# Total Loss : 0.000016
# run [3300]:
# Style Loss : 0.000016
# tensor(0.8966, device='cuda:0') tensor(-0.3416, device='cuda:0')
# Total Loss : 0.000016
# run [3350]:
# Style Loss : 0.000016
# tensor(0.8963, device='cuda:0') tensor(-0.3418, device='cuda:0')
# Total Loss : 0.000016
# run [3400]:
# Style Loss : 0.000016
# tensor(0.8960, device='cuda:0') tensor(-0.3420, device='cuda:0')
# Total Loss : 0.000016
# run [3450]:
# Style Loss : 0.000016
# tensor(0.8956, device='cuda:0') tensor(-0.3422, device='cuda:0')
# Total Loss : 0.000016
# run [3500]:
# Style Loss : 0.000016
# tensor(0.8954, device='cuda:0') tensor(-0.3423, device='cuda:0')
# Total Loss : 0.000016
# run [3550]:
# Style Loss : 0.000016
# tensor(0.8951, device='cuda:0') tensor(-0.3424, device='cuda:0')
# Total Loss : 0.000016
# run [3600]:
# Style Loss : 0.000016
# tensor(0.8949, device='cuda:0') tensor(-0.3426, device='cuda:0')
# Total Loss : 0.000016
# run [3650]:
# Style Loss : 0.000016
# tensor(0.8947, device='cuda:0') tensor(-0.3427, device='cuda:0')
# Total Loss : 0.000016
# run [3700]:
# Style Loss : 0.000016
# tensor(0.8945, device='cuda:0') tensor(-0.3429, device='cuda:0')
# Total Loss : 0.000016
# run [3750]:
# Style Loss : 0.000016
# tensor(0.8943, device='cuda:0') tensor(-0.3430, device='cuda:0')
# Total Loss : 0.000016
# run [3800]:
# Style Loss : 0.000016
# tensor(0.8941, device='cuda:0') tensor(-0.3431, device='cuda:0')
# Total Loss : 0.000016
# run [3850]:
# Style Loss : 0.000016
# tensor(0.8939, device='cuda:0') tensor(-0.3432, device='cuda:0')
# Total Loss : 0.000016
# run [3900]:
# Style Loss : 0.000016
# tensor(0.8937, device='cuda:0') tensor(-0.3433, device='cuda:0')
# Total Loss : 0.000016
# run [3950]:
# Style Loss : 0.000016
# tensor(0.8936, device='cuda:0') tensor(-0.3434, device='cuda:0')
# Total Loss : 0.000016
# run [4000]:
# Style Loss : 0.000016
# tensor(0.8935, device='cuda:0') tensor(-0.3435, device='cuda:0')
# Total Loss : 0.000016
# run [4050]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [4100]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [4150]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [4200]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [4250]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [4300]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [4350]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [4400]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [4450]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [4500]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [4550]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [4600]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [4650]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [4700]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [4750]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [4800]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [4850]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [4900]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [4950]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [5000]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [5050]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [5100]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [5150]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [5200]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [5250]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [5300]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [5350]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [5400]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [5450]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [5500]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [5550]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [5600]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [5650]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [5700]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [5750]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [5800]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [5850]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [5900]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [5950]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [6000]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [6050]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [6100]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [6150]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [6200]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [6250]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [6300]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [6350]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [6400]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [6450]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [6500]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [6550]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [6600]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [6650]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [6700]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [6750]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [6800]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [6850]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [6900]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [6950]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [7000]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [7050]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [7100]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [7150]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [7200]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [7250]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [7300]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [7350]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [7400]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [7450]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [7500]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [7550]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [7600]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [7650]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [7700]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [7750]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [7800]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [7850]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [7900]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [7950]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [8000]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [8050]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [8100]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [8150]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [8200]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [8250]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [8300]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [8350]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [8400]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [8450]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [8500]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [8550]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [8600]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [8650]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [8700]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [8750]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [8800]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [8850]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [8900]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [8950]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [9000]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [9050]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [9100]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [9150]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [9200]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [9250]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [9300]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [9350]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [9400]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [9450]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [9500]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [9550]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [9600]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [9650]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [9700]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [9750]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [9800]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [9850]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [9900]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [9950]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [10000]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [10050]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [10100]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [10150]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [10200]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [10250]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [10300]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [10350]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [10400]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [10450]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [10500]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [10550]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [10600]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [10650]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [10700]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [10750]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [10800]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [10850]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [10900]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [10950]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [11000]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [11050]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [11100]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [11150]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [11200]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [11250]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [11300]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [11350]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [11400]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [11450]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [11500]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [11550]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [11600]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [11650]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [11700]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [11750]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [11800]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [11850]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [11900]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [11950]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [12000]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [12050]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [12100]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [12150]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [12200]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [12250]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [12300]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [12350]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [12400]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [12450]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [12500]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [12550]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [12600]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [12650]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [12700]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [12750]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [12800]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [12850]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [12900]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [12950]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [13000]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [13050]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [13100]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [13150]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [13200]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [13250]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [13300]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [13350]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [13400]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [13450]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [13500]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [13550]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [13600]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [13650]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [13700]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [13750]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [13800]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [13850]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [13900]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [13950]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [14000]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [14050]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [14100]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [14150]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [14200]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [14250]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [14300]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [14350]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [14400]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [14450]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [14500]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [14550]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [14600]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [14650]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [14700]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [14750]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [14800]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [14850]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [14900]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [14950]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [15000]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [15050]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [15100]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [15150]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [15200]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [15250]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [15300]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [15350]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [15400]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [15450]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [15500]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [15550]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [15600]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [15650]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [15700]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [15750]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [15800]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [15850]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [15900]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [15950]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [16000]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [16050]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [16100]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [16150]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [16200]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [16250]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [16300]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [16350]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [16400]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [16450]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [16500]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [16550]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [16600]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [16650]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [16700]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [16750]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [16800]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [16850]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [16900]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [16950]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [17000]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [17050]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [17100]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [17150]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [17200]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [17250]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [17300]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [17350]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [17400]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [17450]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [17500]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [17550]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [17600]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [17650]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [17700]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [17750]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [17800]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [17850]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [17900]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [17950]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [18000]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [18050]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [18100]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [18150]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [18200]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [18250]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [18300]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [18350]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [18400]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [18450]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [18500]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [18550]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [18600]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [18650]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [18700]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [18750]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [18800]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [18850]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [18900]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [18950]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [19000]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [19050]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [19100]:
# ...
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [23550]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [23600]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [23650]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [23700]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [23750]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [23800]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [23850]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [23900]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [23950]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [24000]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [24050]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [24100]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [24150]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [24200]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [24250]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [24300]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [24350]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [24400]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [24450]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [24500]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [24550]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [24600]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [24650]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [24700]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [24750]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [24800]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [24850]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [24900]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [24950]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [25000]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [25050]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [25100]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [25150]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [25200]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [25250]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [25300]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [25350]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [25400]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [25450]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [25500]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [25550]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [25600]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [25650]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [25700]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [25750]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [25800]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [25850]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [25900]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [25950]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [26000]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [26050]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [26100]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [26150]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [26200]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [26250]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [26300]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [26350]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [26400]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [26450]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [26500]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [26550]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [26600]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [26650]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [26700]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [26750]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [26800]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [26850]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [26900]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [26950]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [27000]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [27050]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [27100]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [27150]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [27200]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [27250]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [27300]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [27350]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [27400]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [27450]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [27500]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [27550]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [27600]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [27650]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [27700]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [27750]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [27800]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [27850]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [27900]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [27950]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [28000]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [28050]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [28100]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [28150]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [28200]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [28250]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [28300]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [28350]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [28400]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [28450]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [28500]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [28550]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [28600]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [28650]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [28700]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [28750]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [28800]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [28850]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [28900]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [28950]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [29000]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [29050]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [29100]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [29150]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [29200]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [29250]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [29300]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [29350]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [29400]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [29450]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [29500]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [29550]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [29600]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [29650]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [29700]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [29750]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [29800]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [29850]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [29900]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [29950]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# run [30000]:
# Style Loss : 0.000016
# tensor(0.8934, device='cuda:0') tensor(-0.3436, device='cuda:0')
# Total Loss : 0.000016
# (257, 504)
# Output range: -0.3435586 0.89342755

# %%
#out_spec = inv_scale(out,shf)
for j in range(len(outputs)):
    print(f'Min/Max of outputs:  {np.amin(outputs[j])},{np.amax(outputs[j])}') # check values make sense
    fig = plt.figure()
    plt.title('Style spectrogram')
    ax = fig.add_subplot(111)
    n,b,_ = ax.hist(outputs[j].flatten(),bins='auto')
    plt.show()

if tifresi :
    #### Shift log spec to use max range before thresholding for tfresi inversion
    #outputs=[x+1-np.amax(x) for x in outputs]
    print(f'Adjusted for tfresi: Min/Max of outputs:  {np.amin(outputs[j])},{np.amax(outputs[j])}') # check values make sense
    print('TIFResi: inv_log_spectrogram')
    if use01scale == True:
        out_spec = [inv_log_spectrogram(img_invscale(x,a_min,a_max,0,1)) for x in outputs]
    else:
        out_spec = [inv_log_spectrogram(x) for x in outputs]

else : 
    print('HUZ: inv_log')
    if use01scale == True:
        out_spec = [inv_log(img_invscale(x,a_min,a_max,0,1)) for x in outputs]
    else:
        out_spec = [inv_log(x) for x in outputs]

for j in range(len(out_spec)):
    print(f'Min/Max of out_spec: {np.amin(out_spec[j])}, {np.amax(out_spec[j])}') # check values make sense
# Out:
# Min/Max of outputs:  -0.3435586094856262,0.8934275507926941
# Adjusted for tfresi: Min/Max of outputs:  -0.3435586094856262,0.8934275507926941
# TIFResi: inv_log_spectrogram
# Using [0,1] -> [0,2] for scale conversion
# Min/Max of out_spec: -0.4969758987426758, 4.970645427703857

# %%
# Griffin & Lim algo for phase reconstruction (not used for tifresi)

print(f'out_spec lene is {len(out_spec)}')
for index,value in enumerate(out_spec):
    print(f'shape of value is {value.shape}')
    if tifresi :
        print(f'TIFResi invert mag to audio')
        S = value
        x = stft_system.invert_spectrogram(np.clip(S, 0, None))
    else :
        print(f'Huz invert mag to audio')
        p = 2 * np.pi * np.random.random_sample(value.shape) - np.pi #start with some phase
        for i in range(500):
            S = value * np.exp(1j*p) #use magnitude a given by spectrogram and some random phase
            x = librosa.istft(S,hop_length=K_HOP, win_length=N_FFT, center=False) #do the inverse transform
            p = np.angle(librosa.stft(x, n_fft=N_FFT, hop_length=K_HOP, win_length=N_FFT, center=False)) #use this new phase value

    try:
        os.makedirs("outputs/" + outname)
    except FileExistsError:
        # directory already exists
        pass

    OUTPUT_FILENAME="outputs/" + outname + '/' + outname + '_' + str(index) + '.wav'
    #librosa.output.write_wav("outputs/" + outname + '/' + outname + '_' + str(index) + '.wav', x, fs)
    sf.write(OUTPUT_FILENAME, x, fs)
    print(f'Spectrogram values range over [{np.amin(value)},{np.amax(value)} ]')
    plt.figure()
    plt.title('Result')
    plt.imshow(value, origin='lower')
    plt.show()

plt.ioff()
# Out:
# out_spec lene is 1
# shape of value is (257, 504)
# TIFResi invert mag to audio
# Spectrogram values range over [-0.4969758987426758,4.970645427703857 ]

# %%
print(OUTPUT_FILENAME)
display(Audio(OUTPUT_FILENAME))
# Out:
# outputs/test/test_0.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
