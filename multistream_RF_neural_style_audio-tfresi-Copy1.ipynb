# %% [markdown]
# Audio Neural Style Transfer with Pytorch
# ============================
# This is an implementation of neural style transfer using the alogrithm developed in
# [A Neural Algorithm of Artistic Style](https://arxiv.org/abs/1508.06576) by Leon A. Gatys, Alexander S. Ecker and Matthias Bethge.
#
# However instead of learning style from images we use the spectrogram in place to carry out the procedure on audio.
#
# General implementation is based off the [Pytorch tutorial on Neural Transfer](http://pytorch.org/tutorials/advanced/neural_style_tutorial.html) by Alexis Jacq. Also inspired by [Audio texture synthesis](https://github.com/DmitryUlyanov/neural-style-audio-torch) by Dmitry Ulyanov.

# %%
# %matplotlib inline

from __future__ import print_function

import numpy as np
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim

import librosa
from IPython.display import Audio, display
from PIL import Image
import matplotlib.pyplot as plt
import scipy.stats as stats

import torchvision.transforms as transforms
import torchvision.models as models
from torch.nn.modules.module import _addindent

import copy
import os
import math

#for random feature projection
from scipy.stats import ortho_group


import soundfile as sf
from matplotlib.pyplot import figure

# %%
def log_scale(img):
    img = np.log1p(img)
    return img

def inv_log(img):
    img = np.exp(img) - 1.
    return img

# %% [markdown]
# <div style="background-color: honeydew">
# <h2> Session Parameters </h2>
# </div>

# %%
# True uses PGHI (Truncated Gaussian window, log mag, PGHI reconstruction)
# False uses Log Mag spectrum and Griffin Lim reconstruction
tifresi=True

#STYLE_FILENAME = "inputs/lemons.wav" #input filename
STYLE_FILENAME = "inputs/gansounds/pops4secs.wav" #input filename
#STYLE_FILENAME = "inputs/gansounds/hubub.10secs.wav" #input filename


#Go up to 20000 for high quality if you are on a GPU
num_steps=70

RANDOM_PROJECTION="None"
SYNTHETIC_LENGTH_FACTOR = 1 # duration of generated relative to target texture

#MS Number of separate CNNs operating on input
numStreams=2
learning_Rate=.1  # must be smaller for more streams (if numStream=1, then learning_Rate can be 1)

# %%
display(Audio(STYLE_FILENAME))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <div style="background-color: honeydew">
# <h2> FFT and CNN parameters  </h2>
# (probably don't need to change)
# </div>

# %%
# set filenames
outname = 'rftests' #output dir
runs = 1 # no. of separate outputs (to test consistency), 1 if only want single output

#librosa audio params
N_FFT = 512 
K_HOP = 128 

# architecture
"""use a custom convolutional network randomly initialized""" 
use01scale = False #set to true if want to scale img to [0,1] prior to training. Recommended if using VGG19
boundopt = False #whether to regularize the input within [lower,upper]. Recommended if using VGG19
whichChannel = "freq" #2d=2d conv, 1d options:freq=freq bins as channels, time= time bins as channels 
N_FILTERS = 1024# 4096 #no. of filters in 1st conv layer
hor_filter = 5 #width of conv filter, for 2d also the height of (square) kernel

# %% [markdown]
# <div style="background-color: honeydew">
# <h4> TFResi params  </h4>
# (probably don't need to change)
# </div>

# %% [markdown]
# [Link to tfresi code.](https://github.com/andimarafioti/tifresi)

# %%
from tifresi.hparams import HParams
from tifresi.stft import GaussTruncTF

#from tifresi.transforms import log_spectrogram
#from tifresi.transforms import inv_log_spectrogram
#NOTE: Not using Marifioties 10 log_10 transform. Instead use natural log.
# This makes a HUGE difference !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
log_spectrogram=log_scale
inv_log_spectrogram=inv_log

stft_channels = HParams.stft_channels = N_FFT 
hop_size =  HParams.hop_size  = K_HOP
HParams.sr=16000 

# empirically set: - too small, get low-res ringing; too high, get distortion
tfresiMagSpectScale=5 # Takes the [0,1] mag spectrogram and maps it to [0, tfresiMagSpectScale]

# For faster processin, a truncated window can be used instead
stft_system = GaussTruncTF(hop_size=hop_size, stft_channels=stft_channels)

# %% [markdown]
# <div style="background-color: honeydew">
# <h4> Plumbing  </h4>
# </div>

# %%
use_cuda = torch.cuda.is_available() #use GPU if available
print('GPU available =',use_cuda)
dtype = torch.cuda.FloatTensor if use_cuda else torch.FloatTensor
# Out:
# GPU available = True

# %%
def read_audio_spectum(filename, tifresi=True):
    #x, fs = librosa.load(filename) #x=audiodata, fs=samplerate
    x, fs  = sf.read(filename)
    print(f'input file sample rate = {fs}')
    x=np.append(x, np.zeros(stft_channels-np.mod(len(x), stft_channels)))
    N_SAMPLES = len(x)
    x=x+np.random.normal(scale=.0001, size=N_SAMPLES)
    print(f'np.mod(len(x), stft_channels) = {np.mod(len(x), stft_channels)}')
    print(f' number of hops is {len(x)//hop_size}')
    
    if tifresi :
        print(f'In read audio, doing tifresi spectrogram')
        R=tfresiMagSpectScale*stft_system.spectrogram(x)
    else :
        print(f'In read audio, doing librosa spectrogram')
        R = np.abs(librosa.stft(x, n_fft=N_FFT, hop_length=K_HOP, win_length=N_FFT,  center=False))    
        
    print(f'R range is  [{np.amin(R)}, {np.amax(R)}')
    print(f'K_HOP - {K_HOP} and N_FFT is {N_FFT}')
    print(f'R shape is {R.shape}')
    return R, fs


def findMinMax(img):
    return int(math.floor(np.amin(img))),int(math.ceil(np.amax(img)))

def img_scale(img,datasetMin,datasetMax,scaleMin,scaleMax):
    """scales input numpy array from [datasetMin,datasetMax] -> [scaleMin,scaleMax]"""    
    shift = (scaleMax-scaleMin) / (datasetMax-datasetMin)
    scaled_values = shift * (img-datasetMin) + scaleMin
    print("img_scale: Using [{0},{1}] -> [{2},{3}] for scale conversion".format(datasetMin,datasetMax,scaleMin,scaleMax))
    return scaled_values

def img_invscale(img,datasetMin,datasetMax,scaleMin,scaleMax):
    """scales input numpy array from [scaleMin,scaleMax] -> [datasetMin,datasetMax]"""
    shift = (datasetMax-datasetMin) / (scaleMax-scaleMin)
    scaled_values = shift * (img-scaleMin) + datasetMin
    print("img_invscale: Using [{0},{1}] -> [{2},{3}] for inverse scale conversion".format(scaleMin,scaleMax,datasetMin,datasetMax))
    return scaled_values
    
#if 0
    # use below functions to use librosa db scale, normalized to [0,1]
    # note that this scaling does not work well for style transfer
    def db_scale(img,scale=80):
        img = librosa.amplitude_to_db(img)
        shift = float(np.amax(img))
        img = img - shift #put max at 0
        img = img/scale #scale from [-80,0] to [-1,0]
        img = img + 1. #shift to [0,1]
        img = np.maximum(img, 0) #clip anything below 0
        return img, shift

    def inv_db(img,shift,scale=80):
        img = img - 1. #shift from [0,1] to [-1,0]
        img = img * scale #[-1,0] -> [-80,0]
        img = img + shift
        img = librosa.db_to_amplitude(img)    
        return img

# %% [markdown]
# <div style="background-color: #AAFFAA">
# <h4> Prepare input and inspect.  </h4>
# </div>

# %%
R, fs = read_audio_spectum(STYLE_FILENAME, tifresi)
print(f"raw spectrogram R range before log and scaling: [{np.amin(R)},{np.amax(R)}] ")
# Out:
# input file sample rate = 16000
# np.mod(len(x), stft_channels) = 0
#  number of hops is 504
# In read audio, doing tifresi spectrogram
# R range is  [5.049051793884659e-07, 5.0
# K_HOP - 128 and N_FFT is 512
# R shape is (257, 504)
# raw spectrogram R range before log and scaling: [5.049051793884659e-07,5.0]

# %%
if tifresi :
    print('TIFResi: log_spectrogram')
    a_style = log_spectrogram(R)
else :
    print('HUZ: log_scase')
    a_style = log_scale(R)
    
print(f"    LOG    range before scaling: [{np.amin(a_style)},{np.amax(a_style)}]",)
print(f'shape of a_style is {a_style.shape}')
# Out:
# TIFResi: log_spectrogram
#     LOG    range before scaling: [5.049050519238887e-07,1.791759469228055]
# shape of a_style is (257, 504)

# %%
if use01scale == True:
    a_min,a_max = findMinMax(a_style)
    a_style = img_scale(a_style,a_min,a_max,0,1)

# %%
"""we plot out the STFT magnitude range and the spectrogram do get a feel of the data"""
#plt.ion()
fig = plt.figure()
plt.title('Histogram of log Style Spectrogram vals')
ax = fig.add_subplot(111)
#n,b,_ = ax.hist(a_style.flatten(),bins='auto')
n,b,_ = ax.hist(a_style.flatten(),bins=100)
#ax.set_yticklabels([])
#ax.set_xticks([])
maxbin = np.argmax(n)
plt.show()
print("Max bin:",b[maxbin])

plt.figure(figsize=(10, 5))
plt.title('Style spectrogram')
plt.imshow(a_style, origin='lower')
print("Style spectrogram range after scaling:",np.amin(a_style),np.amax(a_style))
temp_a_style=a_style # for reality check in next cell
# Out:
# Max bin: 5.049050519238887e-07
# Style spectrogram range after scaling: 5.049050519238887e-07 1.791759469228055

# %%
if 0 : #RUN PGHI ON THE ORIGINAL INPUT DATA SPECTROGRAM  - ASSUMING TFRESI for the little experiment in this cell
    # now invert it, just like we will do with the GAN-generated images

    #SPECTOFFSET
    SPECTOFFSET=.25

    lspect=a_style
    print(f' shape of lspect is {bar.shape}')
    #ASSUMING TIFRES
    print('TIFResi: inv_log_spectrogram')
    if use01scale == True:
        foo = img_invscale(lspect,a_min,a_max,0,1)
        out_spec = inv_log_spectrogram(lspect+ SPECTOFFSET) 
        print(f'   RESCALED: Min/Max of outputs:  {np.amin(out_spec)},{np.amax(out_spec)}') # check values make sense

    else:
        out_spec =inv_log_spectrogram(lspect+SPECTOFFSET) 
        print(f'   inv_log_spectrogram: Min/Max of outputs:  {np.amin(out_spec)},{np.amax(out_spec)}') # check values make sense

    print(f' shape of out_spec is {out_spec.shape}')
    bar = np.clip(out_spec, 0,None)
    print(f' shape of bar is {bar.shape}')

    print(f'Min/Max of spectrogram: {np.amin(bar)}, {np.amax(bar)}') # check values make sense
    x = stft_system.invert_spectrogram(bar) 

    display(Audio(x, rate=16000, autoplay=True))

# %%
N_SAMPLES = a_style.shape[1] #time bins
N_FREQ = a_style.shape[0] #freq bins

a_style = np.ascontiguousarray(a_style[None,None,:,:]) #[batch,channels,freq,samples]
if whichChannel == "2d":
    a_style = torch.from_numpy(a_style) #pytorch:[batch,channels(1),height(freq),width(samples)]
elif whichChannel == "freq":
    a_style = torch.from_numpy(a_style).permute(0,2,1,3) #pytorch:[batch,channels(freq),height(1),width(samples)]
elif whichChannel == "time":
    a_style = torch.from_numpy(a_style).permute(0,3,1,2) #pytorch:[batch,channels(samples),height(1),width(freq)]

style_img = Variable(a_style).type(dtype) #convert to pytorch variable
print("Using whichChannel ==",whichChannel," Input shape:",style_img.data.shape) #check shape is correct
# Out:
# Using whichChannel == freq  Input shape: torch.Size([1, 257, 1, 504])

# %%
def imshow(tensor, n_freqs, n_samples, channels=1, title=None, origin='lower'):
    """ transforms pytorch tensor to numpy array and plots it out """
    
    image = tensor.clone().cpu()  # we clone the tensor to not do changes on it
    if whichChannel == "2d":
        image = image
    if whichChannel == "freq":
        image = image.permute(0,2,1,3).contiguous() # get the dimensions in proper order
    elif whichChannel == "time":
        image = image.permute(0,2,3,1).contiguous() # get the dimensions in proper order
    image = image.view(n_freqs, n_samples)  # remove the fake batch dimension
    
    image = image.numpy() #convert pytorch tensor to numpy array
    print(image.shape) #check shape
    print("Output range:",np.amin(image),np.amax(image))
    
    
    plt.imshow(image, origin=origin)
    if title is not None:
        plt.title(title)
    plt.pause(0.001) # pause a bit so that plots are updated
    return image #return numpy array

"Just to check we can get back the numpy array with the correct shape"
plt.figure(figsize=(10, 5))
plt.figure()
_=imshow(style_img.data, N_FREQ, N_SAMPLES, title='Style Spectrogram', origin='lower')

#plt.figure()
#imshow(content_img.data, title='Content Image')
# Out:
# (257, 504)
# Output range: 5.049051e-07 1.7917595

# %% [markdown]
# <div style="background-color: #FF4488">
# <h4> BeginNetwork   </h4>
# </div>

# %% [markdown]
# <div style="background-color: #AAFFAA">
# <h4> Create network   </h4>
# </div>

# %%
"Here we create the custom network"
import collections as c

if whichChannel == "2d":
    IN_CHANNELS = 1
elif whichChannel == "freq":
    IN_CHANNELS = N_FREQ
elif whichChannel == "time":
    IN_CHANNELS = N_SAMPLES
    

# custom weights initialization
def weights_init(m):
    std = np.sqrt(2) * np.sqrt(2.0 / ((N_FREQ + N_FILTERS) * hor_filter))
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        m.weight.data.normal_(0.0, std)

class style_net(nn.Module):
    """Here create the network you want to use by adding/removing layers in nn.Sequential"""
    def __init__(self):
        super(style_net, self).__init__()
        self.layers = nn.Sequential(c.OrderedDict([
                            ('conv1',nn.Conv2d(IN_CHANNELS,N_FILTERS,kernel_size=(1,hor_filter),bias=False)),
                            ('relu1',nn.ReLU()),
                            ('max1', nn.MaxPool2d(kernel_size=(1,2))),
            
                            ('conv2',nn.Conv2d(N_FILTERS,N_FILTERS//2,kernel_size=(1,hor_filter),bias=False)),
                            ('relu2',nn.ReLU())]))

                            #('relu2',nn.ReLU()),
                            #('max2', nn.MaxPool2d(kernel_size=(1,2))),


                            #('conv3',nn.Conv2d(N_FILTERS//2,N_FILTERS//2,kernel_size=(1,hor_filter),bias=False)),
                            #('relu3',nn.ReLU()),
                            #('max3', nn.MaxPool2d(kernel_size=(1,2))),

                            #('conv4',nn.Conv2d(N_FILTERS//2,N_FILTERS//4,kernel_size=(1,hor_filter),bias=False)),
                            #('relu4',nn.ReLU()),
                            #('max4', nn.MaxPool2d(kernel_size=(1,2))),


                            #('conv5',nn.Conv2d(N_FILTERS//4,N_FILTERS//4,kernel_size=(1,hor_filter),bias=False)),
                            #('relu5',nn.ReLU()),
                            #('max5', nn.MaxPool2d(kernel_size=(1,2))),


                            #('conv6',nn.Conv2d(N_FILTERS//4,N_FILTERS//8,kernel_size=(1,hor_filter),bias=False)),
                            #('relu6',nn.ReLU())]))

    def forward(self,input):
        out = self.layers(input)
        return out
    
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~    
cnnlist=[] 
#MS create a separate CNN for each stream
for j in range(numStreams) :
    cnn = style_net()
    cnn.apply(weights_init)
    for param in cnn.parameters():
        param.requires_grad = False
    print(list(cnn.layers))

    # move it to the GPU if possible:
    if use_cuda:
        cnn = cnn.cuda()
    
    cnnlist.append(cnn)

# Add the style/content loss 'layer' after the specified layer:
content_layers_default = [] #ignore for now
#style_layers_default = ['relu_1']
style_layers_default = ['relu_1', 'relu_2']
# Out:
# [Conv2d(257, 1024, kernel_size=(1, 5), stride=(1, 1), bias=False), ReLU(), MaxPool2d(kernel_size=(1, 2), stride=(1, 2), padding=0, dilation=1, ceil_mode=False), Conv2d(1024, 512, kernel_size=(1, 5), stride=(1, 1), bias=False), ReLU()]
# [Conv2d(257, 1024, kernel_size=(1, 5), stride=(1, 1), bias=False), ReLU(), MaxPool2d(kernel_size=(1, 2), stride=(1, 2), padding=0, dilation=1, ceil_mode=False), Conv2d(1024, 512, kernel_size=(1, 5), stride=(1, 1), bias=False), ReLU()]

# %% [markdown]
# Content loss
# ~~~~~~~~~~~~
#
# The content loss is a function that takes as input the feature maps
# $F_{XL}$ at a layer $L$ in a network fed by $X$ and
# return the weigthed content distance $w_{CL}.D_C^L(X,C)$ between
# this image and the content image. Hence, the weight $w_{CL}$ and
# the target content $F_{CL}$ are parameters of the function. We
# implement this function as a torch module with a constructor that takes
# these parameters as input. The distance $\|F_{XL} - F_{YL}\|^2$ is
# the Mean Square Error between the two sets of feature maps, that can be
# computed using a criterion ``nn.MSELoss`` stated as a third parameter.
#
# We will add our content losses at each desired layer as additive modules
# of the neural network. That way, each time we will feed the network with
# an input image $X$, all the content losses will be computed at the
# desired layers and, thanks to autograd, all the gradients will be
# computed. For that, we just need to make the ``forward`` method of our
# module returning the input: the module becomes a ''transparent layer''
# of the neural network. The computed loss is saved as a parameter of the
# module.
#
# Finally, we define a fake ``backward`` method, that just call the
# backward method of ``nn.MSELoss`` in order to reconstruct the gradient.
# This method returns the computed loss: this will be useful when running
# the gradient descent in order to display the evolution of style and
# content losses.

# %%
class ContentLoss(nn.Module):
    """Since doing texture only we ignore this for now"""

    def __init__(self, target, weight): #weight here is the epsilon tuning (how much content vs style)
        super(ContentLoss, self).__init__()
        # we 'detach' the target content from the tree used
        self.target = target.detach() * weight
        # to dynamically compute the gradient: this is a stated value,
        # not a variable. Otherwise the forward method of the criterion
        # will throw an error.
        self.weight = weight
        self.criterion = nn.MSELoss()

    def forward(self, input):
        self.loss = self.criterion(input * self.weight, self.target)
        self.output = input
        return self.output

    def backward(self, retain_variables=True):
        self.loss.backward(retain_variables=retain_variables)
        return self.loss

# %% [markdown]
# .. Note::
#    **Important detail**: this module, although it is named ``ContentLoss``,
#    is not a true PyTorch Loss function. If you want to define your content
#    loss as a PyTorch Loss, you have to create a PyTorch autograd Function
#    and to recompute/implement the gradient by the hand in the ``backward``
#    method.
#
# Style loss
# ~~~~~~~~~~
#
# For the style loss, we need first to define a module that compute the
# gram produce $G_{XL}$ given the feature maps $F_{XL}$ of the
# neural network fed by $X$, at layer $L$. Let
# $\hat{F}_{XL}$ be the re-shaped version of $F_{XL}$ into a
# $K$\ x\ $N$ matrix, where $K$ is the number of feature
# maps at layer $L$ and $N$ the lenght of any vectorized
# feature map $F_{XL}^k$. The $k^{th}$ line of
# $\hat{F}_{XL}$ is $F_{XL}^k$. We let you check that
# $\hat{F}_{XL} \cdot \hat{F}_{XL}^T = G_{XL}$. Given that, it
# becomes easy to implement our module:

# %%
# create random feature projection matrix
RFM={}

# This is the "sparse" Achlioptas matrix
if RANDOM_PROJECTION=="Sparse" : 
    RFM[1024]=torch.from_numpy(np.random.choice(np.sqrt(3)*np.array([1., 0., -1.]), (1024,512), p=[1./6.,2./3., 1./6.])).type(dtype)
    RFM[512]=torch.from_numpy(np.random.choice(np.sqrt(3)*np.array([1., 0., -1.]), (512,256), p=[1./6.,2./3., 1./6.])).type(dtype)
    RFM[256]=torch.from_numpy(np.random.choice(np.sqrt(3)*np.array([1., 0., -1.]), (256,128), p=[1./6.,2./3., 1./6.])).type(dtype)
    RFM[128]=torch.from_numpy(np.random.choice(np.sqrt(3)*np.array([1., 0., -1.]), (128,64), p=[1./6.,2./3., 1./6.])).type(dtype)

#Full orthonormal gaussian 
if RANDOM_PROJECTION=="Gaussian" : 
    RFM[1024]=torch.from_numpy(ortho_group.rvs(1024)[:512]).type(dtype)
    RFM[512]=torch.from_numpy(ortho_group.rvs(512)[:256]).type(dtype)
    RFM[256]=torch.from_numpy(ortho_group.rvs(256)[:128]).type(dtype)
    RFM[128]=torch.from_numpy(ortho_group.rvs(128)[:64]).type(dtype)

# %%
class GramMatrix(nn.Module):

    def forward(self, input):
        a, b, c, d = input.size() #a=batch size(=1)
                                  #b=number of feature maps
                                  #(c,d)=dimensions of a feat. map (N=c*d) -> for 1D conv c=1
        #features = input.view(a * b, c * d)  # resise F_XL into \hat F_XL
        features = input.view(b, a * c * d)  # resise F_XL into \hat F_XL
        
       # features2=torch.matmul(RFM[:b//2,:b], features)
        if RANDOM_PROJECTION=="None":
            features2=features
        else :
            features2=torch.matmul(RFM[b], features)

        G = torch.mm(features2, features2.t())  # compute the gram product

        # we 'normalize' the values of the gram matrix
        # by dividing by the number of element in each feature maps.
        return G.div(a * c * d)

# %% [markdown]
# The longer is the feature maps dimension $N$, the bigger are the
# values of the gram matrix. Therefore, if we don't normalize by $N$,
# the loss computed at the first layers (before pooling layers) will have
# much more importance during the gradient descent. We dont want that,
# since the most interesting style features are in the deepest layers!
#
# Then, the style loss module is implemented exactly the same way than the
# content loss module, but we have to add the ``gramMatrix`` as a
# parameter:

# %%
#foofoo
class StyleLoss(nn.Module):

    def __init__(self, target, weight, layer): #weight here is the alpha tuning (how much content vs style)
        super(StyleLoss, self).__init__()
        self.target = target.detach() * weight
        self.weight = weight
        self.gram = GramMatrix()
        self.criterion = nn.MSELoss(size_average=False)
        #print(f'Creating StyleLoss module - this one for layer {layer} with target shape {target.shape}' )


    def forward(self, input):
        #print(f' StyleLoss.forward with input of shape {input.shape}')
        self.output = input.clone()
        self.G = self.gram(input)
        self.G.mul_(self.weight)
        self.loss = self.criterion(self.G, self.target) #target=gram mat for style img, G=gram mat for current input ie. noise
        return self.output

    def backward(self, retain_variables=True):
        self.loss.backward(retain_graph=True)
        return self.loss

# %%
class OptReg(nn.Module):
    """soft bound the optimization between [lower,upper] by regularization"""
    
    def __init__(self, upper, lower, weight=1): #weight here is the alpha tuning (how much content vs style)
        super(OptReg, self).__init__()
        self.upper = Variable(torch.cuda.FloatTensor([upper]))
        self.lower = Variable(torch.cuda.FloatTensor([lower]))
        self.weight = weight

    def forward(self, input):
        #self.output = input.clone()
        self.zeros = Variable(torch.zeros(input.size()).type(dtype))
                              
        self.over = torch.max(input-self.upper,self.zeros)
        self.under = torch.max(self.lower-input,self.zeros)
        self.total= self.over + self.under
        self.l2total = self.weight * self.total.norm(2)
        #print(f'OptReg l2total = {self.l2total}')
        return self.l2total

# %% [raw]
# a = Variable(torch.cuda.FloatTensor([[2,0,2],[1,0,1]]))
# b = Variable(torch.cuda.FloatTensor([[5,0,5],[-1,0,-1]]))
# c = Variable(torch.cuda.FloatTensor([1]))
# d = c-a
# print(d)
# e = torch.max(d,b)
# f = e+e
# print(f)
# g = f.norm(2)
# print(g)
#
# def optbound_regularizer_old(img,upper,lower):
#     """soft bound the optimization between [lower,upper] by regularization"""
#     #print(torch.max(img),torch.min(img))
#     imgn = Variable(img)
#     over = torch.max(imgn.data-upper,torch.zeros(img.size()).type(dtype))
#     #print("over",over)
#     under = torch.max(lower-imgn.data,torch.zeros(img.size()).type(dtype))
#     #print("under",under)
#     out = over + under
#     #print("out",out)
#     out = out.norm(2)
#     #print("norm",out)
#     #l2_reg = torch.cuda.FloatTensor([out])
#     l2_reg = Variable(torch.cuda.FloatTensor([out]), requires_grad=True)
#
#     return l2_reg
#
# def optbound_regularizer(img,upper,lower,reg_weight):
#     """soft bound the optimization between [lower,upper] by regularization"""
#     #print(torch.max(img),torch.min(img))
#     zero_var = Variable(torch.zeros(img.size()).type(dtype))
#     over = Variable(torch.max(img-upper,torch.zeros(img.size()).type(dtype)), requires_grad=True)
#     crit_over = nn.MSELoss(size_average=False)
#     over_loss = crit_over(over,zero_var)
#     #print("over",over)
#     under = Variable(torch.max(lower-img,torch.zeros(img.size()).type(dtype)), requires_grad=True)
#     crit_under = nn.MSELoss(size_average=False)
#     under_loss = crit_under(under,zero_var)
#     #print("under",under)
#     out = over_loss + under_loss
#     #print("out",out)
#     #out = out.norm(2)
#     #print("norm",out)
#     #l2_reg = torch.cuda.FloatTensor([out])
#     #l2_reg = Variable(torch.cuda.FloatTensor([out]), requires_grad=True)
#     out = reg_weight * out
#     #optbound = out.backward(retain_graph=True)
#
#     return out #optbound

# %% [markdown]
# Load the neural network
# ~~~~~~~~~~~~~~~~~~~~~~~
#
# Now, we have to import a pre-trained neural network. As in the paper, we
# are going to use a pretrained VGG network with 19 layers (VGG19).
#
# PyTorch's implementation of VGG is a module divided in two child
# ``Sequential`` modules: ``features`` (containing convolution and pooling
# layers) and ``classifier`` (containing fully connected layers). We are
# just interested by ``features``:

# %% [markdown]
# A ``Sequential`` module contains an ordered list of child modules. For
# instance, ``vgg19.features`` contains a sequence (Conv2d, ReLU,
# Maxpool2d, Conv2d, ReLU...) aligned in the right order of depth. As we
# said in *Content loss* section, we wand to add our style and content
# loss modules as additive 'transparent' layers in our network, at desired
# depths. For that, we construct a new ``Sequential`` module, in wich we
# are going to add modules from ``vgg19`` and our loss modules in the
# right order:

# %%
#rebuild network with the layers we want
def get_style_model_and_losses(cnn, style_img, content_img=None,
                               style_weight=1, content_weight=0,
                               content_layers=content_layers_default,
                               style_layers=style_layers_default, style_img2=None):
    cnn = copy.deepcopy(cnn)

    # just in order to have an iterable access to or list of content/syle losses
    content_losses = []
    style_losses = []
    
    model = nn.Sequential()
    layer_list = list(cnn.layers)
    
    gram = GramMatrix()  # we need a gram module in order to compute style targets

    # move these modules to the GPU if possible:
    if use_cuda:
        model = model.cuda()
        gram = gram.cuda()

    #here we rebuild the network adding the in content and style loss "layers"   
    i = 1  
    for layer in layer_list:
        
        if isinstance(layer, nn.Conv2d): #if layer in vgg19 belong to class nn.Conv2d
            name = "conv_" + str(i)
            model.add_module(name, layer) #add that layer to our sequential model
            
            if content_img != None:
                if name in content_layers: #at the right depth add the content loss "layer"
                    # add content loss:
                    target = model(content_img).clone()
                    content_loss = ContentLoss(target, content_weight)
                    model.add_module("content_loss_" + str(i), content_loss)
                    content_losses.append(content_loss)

            if name in style_layers: #at the right depth add the content loss "layer"
                # add style loss:
                target_feature = model(style_img).clone()
                target_feature_gram = gram(target_feature)
                style_loss = StyleLoss(target_feature_gram, style_weight, name)
                model.add_module("style_loss_" + str(i), style_loss)
                style_losses.append(style_loss)

        if isinstance(layer, nn.ReLU): #do the same for ReLUs
            name = "relu_" + str(i)
            model.add_module(name, layer)
            
            if content_img != None:
                if name in content_layers:
                    # add content loss:
                    target = model(content_img).clone()
                    content_loss = ContentLoss(target, content_weight)
                    model.add_module("content_loss_" + str(i), content_loss)
                    content_losses.append(content_loss)

            if name in style_layers:
                # add style loss:
                target_feature = model(style_img).clone()
                target_feature_gram = gram(target_feature)
                style_loss = StyleLoss(target_feature_gram, style_weight, name)
                model.add_module("style_loss_" + str(i), style_loss)
                style_losses.append(style_loss) 
                
            i += 1

        if isinstance(layer, nn.MaxPool2d): #do the same for maxpool
            name = "pool_" + str(i)
            model.add_module(name, layer)
            
            if name in style_layers:
                # add style loss:
                target_feature = model(style_img).clone()
                target_feature_gram = gram(target_feature)
                style_loss = StyleLoss(target_feature_gram, style_weight, name)
                model.add_module("style_loss_" + str(i), style_loss)
                style_losses.append(style_loss)
            
            #avgpool = nn.AvgPool2d(kernel_size=(1,2),
            #                stride=layer.stride, padding = layer.padding)
            #model.add_module(name, avgpool)  # *** can also replace certain layers if we want eg. maxpool -> avgpool


    #for param in model.parameters():
    #    param.requires_grad = False
    return model, style_losses, content_losses

# %% [markdown]
# .. Note::
#    In the paper they recommend to change max pooling layers into
#    average pooling. With AlexNet, that is a small network compared to VGG19
#    used in the paper, we are not going to see any difference of quality in
#    the result. However, you can use these lines instead if you want to do
#    this substitution:
#
#    ::
#
#        # avgpool = nn.AvgPool2d(kernel_size=layer.kernel_size,
#        #                         stride=layer.stride, padding = layer.padding)
#        # model.add_module(name,avgpool)

# %% [markdown]
# Input image
# ~~~~~~~~~~~
#
# Again, in order to simplify the code, we take an image of the same
# dimensions than content and style images. This image can be a white
# noise, or it can also be a copy of the content-image.

# %% [markdown]
# <div style="background-color: #AAFFAA">
# <h4> Prepare noise as input  </h4>
# </div>

# %%
"""image to input in generative network"""
#input_img = content_img.clone()

# if you want to use a white noise instead uncomment the below line:
#input_img = Variable(torch.randn(content_img.data.size())).type(dtype)

def in_img(n_freqs, nsamples):
    """initialize (runs) number of unique random noise input images"""  
    input_imgs = []
    #rand_tensor = torch.randn(1,n_freqs,1,nsamples)*1e-3
    lower,upper,mu,sigma = 1e-3,1,.5,1e-1
    dist = stats.truncnorm((lower-mu)/sigma,(upper-mu)/sigma,loc=mu,scale=sigma)
    
    i = 0
    while i < runs:
         #[batch,channels,h,w]
        if whichChannel == "2d":
            samples = dist.rvs([1,1,n_freqs,nsamples])
            input_imgs.append(Variable(torch.from_numpy(samples)).type(dtype))
            #input_imgs.append(Variable(torch.rand(1,1,n_freqs,nsamples)*1e-3).type(dtype))
            #input_imgs.append(Variable(torch.randn(1,1,n_freqs,nsamples)*1e-3).type(dtype))
        if whichChannel == "freq":
            #samples = dist.rvs([1,n_freqs,1,nsamples])
            #input_imgs.append(Variable(torch.from_numpy(samples)).type(dtype))
            #input_imgs.append(Variable(torch.rand(1,n_freqs,1,nsamples)*1e-3).type(dtype))
            input_imgs.append(Variable(mu+torch.randn(1,n_freqs,1,nsamples)*1e-3).type(dtype))
        elif whichChannel == "time":
            samples = dist.rvs([1,nsamples,1,n_freqs])
            input_imgs.append(Variable(torch.from_numpy(samples)).type(dtype))
            #input_imgs.append(Variable(torch.rand(1,nsamples,1,n_freqs)*1e-3).type(dtype))
            #input_imgs.append(Variable(torch.randn(1,nsamples,1,n_freqs)*1e-3).type(dtype))
        i +=1
    return input_imgs

input_imgs = in_img(N_FREQ, int(N_SAMPLES*SYNTHETIC_LENGTH_FACTOR))

# add the original input image to the figure:
plt.figure()
_=imshow(input_imgs[0].data, N_FREQ, int(N_SAMPLES*SYNTHETIC_LENGTH_FACTOR), title='Input Image')
# Out:
# (257, 504)
# Output range: 0.4956499 0.504348

# %% [markdown]
# Gradient descent
# ~~~~~~~~~~~~~~~~
#
# As Leon Gatys, the author of the algorithm, suggested
# `here <https://discuss.pytorch.org/t/pytorch-tutorial-for-neural-transfert-of-artistic-style/336/20?u=alexis-jacq>`__,
# we will use L-BFGS algorithm to run our gradient descent. Unlike
# training a network, we want to train the input image in order to
# minimise the content/style losses. We would like to simply create a
# PyTorch  L-BFGS optimizer, passing our image as the variable to optimize.
# But ``optim.LBFGS`` takes as first argument a list of PyTorch
# ``Variable`` that require gradient. Our input image is a ``Variable``
# but is not a leaf of the tree that requires computation of gradients. In
# order to show that this variable requires a gradient, a possibility is
# to construct a ``Parameter`` object from the input image. Then, we just
# give a list containing this ``Parameter`` to the optimizer's
# constructor:

# %%
def get_input_param_optimizer(input_img):
    # this line to show that input is a parameter that requires a gradient
    input_param = nn.Parameter(input_img.data)
    optimizer = optim.LBFGS([input_param])
    return input_param, optimizer

# %% [markdown]
# **Last step**: the loop of gradient descent. At each step, we must feed
# the network with the updated input in order to compute the new losses,
# we must run the ``backward`` methods of each loss to dynamically compute
# their gradients and perform the step of gradient descent. The optimizer
# requires as argument a "closure": a function that reevaluates the model
# and returns the loss.

# %%
def run_style_transfer(cnnlist, style_img, input_img, content_img=None, num_steps=num_steps,
                       style_weight=1, content_weight=0, reg_weight=0.01): 
    """Run the style transfer"""
    
    #MS - one model, loss accumulator, and optimizer per stream 
    modelMS=[None for j in range(numStreams)]
    style_lossesMS=[None for j in range(numStreams)] 
    content_lossesMS=[None for j in range(numStreams)]
    optimizerMS=[None for j in range(numStreams)]

    #MS one input_param for all streams, each operating on the same data. 
    input_param = nn.Parameter(input_img.data)
    
    
    prev = input_param.data
    
    # first create the separate cnn models and losses
    for j in range(numStreams) :
        print('Building the style transfer model..')
        modelMS[j], style_lossesMS[j], content_lossesMS[j] = get_style_model_and_losses(cnnlist[j],
            style_img, content_img, style_weight, content_weight)
        #input_paramMS[j], optimizerMS[j] = get_input_param_optimizer(input_img)
        
        #input_param is the same variable passed to each separate CNN
        #MS Changed learning rate to prevent instabilities with lr=1.
        optimizerMS[j] = optim.LBFGS([input_param], lr=learning_Rate)

        print("Input range:",torch.max(input_param.data),torch.min(input_param.data))   
        print(modelMS[j])
        print('Optimizing..')
        
    
    print(f'Created {j} MS models')
    # print(f' input_param[0] is input_param[1] ? ...... {input_paramMS[0] is input_paramMS[1]}')    # FALSE!    
    

    run = [0]
    
    if boundopt == True:
        bound = OptReg(1,0.005, reg_weight)
    
    while run[0] <= num_steps:

        run[0] += 1
        
        #MS create the closure, and then run the optimizer for each stream in sequence
        # (the update from each stream becomes the input for the next, I think!)
        for j in range(numStreams) :
        
            def closure():
                # correct the values of updated input image
                #if use01scale == True:
                    #input_param.data.clamp_(0, 1)

                optimizerMS[j].zero_grad()
                modelMS[j](input_param)
                style_score = 0
                content_score = 0

                if boundopt == True:
                    bound.zero_grad()
                    reg = bound(input_param)
                    if not torch.equal(reg.data,torch.cuda.FloatTensor([0])):
                        reg.backward()

                for sl in style_lossesMS[j]:
                    style_score += sl.backward() #call backward method to grab the loss

                #for cl in content_losses:
                #    content_score += cl.backward()

                if boundopt == True:
                    total_loss = style_score + reg  #+ content_score
                else:
                    total_loss = style_score

                #run[0] += 1

                if run[0] % 10 == 0:
                    #print("reg", reg)
                    #print(torch.max(input_param.data),torch.min(input_param.data))

                    print(f"run: {run}, model[{j}]")
                    print('Style Loss : {:4f}'.format(
                        #style_score.data[0]))
                        style_score.data))
                    if boundopt == True:
                        print('Bound Loss : {:4f}'.format(
                           #reg.data[0]))
                            reg.data))
                    print(torch.max(input_param.data),torch.min(input_param.data))
                    print('Total Loss : {:4f}'.format(
                        # total_loss.data[0]))
                        total_loss.data))

                return total_loss   #return value for closer()

            # The update to an image happens in here:
            optimizerMS[j].step(closure)  #optimizer.step will call closure with its closure vars;
                
          
        # END MS loop
        
        
        
    # a last correction...
    #if use01scale == True:
        #input_param.data.clamp_(0, 1)

    return input_param.data   # Can return any of the MS input_params - they all refer to the same object

# %% [markdown]
# <div style="background-color: #AAFFAA">
# <h4> Finally, run the algorithm  </h4>
# </div>

# %%
outputs = []
i = 0
while i < runs:
    
    output = run_style_transfer(cnnlist, style_img, input_imgs[i])

    plt.figure()
    out = imshow(output, N_FREQ, int(N_SAMPLES*SYNTHETIC_LENGTH_FACTOR),title='Output Image')
    outputs.append(out)
    i += 1

# sphinx_gallery_thumbnail_number = 4
plt.show()
# Out:
# Building the style transfer model..
# Input range: tensor(0.5043, device='cuda:0') tensor(0.4956, device='cuda:0')
# Sequential(
#   (conv_1): Conv2d(257, 1024, kernel_size=(1, 5), stride=(1, 1), bias=False)
#   (relu_1): ReLU()
#   (style_loss_1): StyleLoss(
#     (gram): GramMatrix()
#     (criterion): MSELoss()
#   )
#   (pool_2): MaxPool2d(kernel_size=(1, 2), stride=(1, 2), padding=0, dilation=1, ceil_mode=False)
#   (conv_2): Conv2d(1024, 512, kernel_size=(1, 5), stride=(1, 1), bias=False)
#   (relu_2): ReLU()
#   (style_loss_2): StyleLoss(
#     (gram): GramMatrix()
#     (criterion): MSELoss()
#   )
# )
# Optimizing..
# Building the style transfer model..
# Input range: tensor(0.5043, device='cuda:0') tensor(0.4956, device='cuda:0')
# Sequential(
#   (conv_1): Conv2d(257, 1024, kernel_size=(1, 5), stride=(1, 1), bias=False)
#   (relu_1): ReLU()
#   (style_loss_1): StyleLoss(
#     (gram): GramMatrix()
#     (criterion): MSELoss()
#   )
#   (pool_2): MaxPool2d(kernel_size=(1, 2), stride=(1, 2), padding=0, dilation=1, ceil_mode=False)
#   (conv_2): Conv2d(1024, 512, kernel_size=(1, 5), stride=(1, 1), bias=False)
#   (relu_2): ReLU()
#   (style_loss_2): StyleLoss(
#     (gram): GramMatrix()
#     (criterion): MSELoss()
#   )
# )
# Optimizing..
# Created 1 MS models
# run: [10], model[0]
# Style Loss : 0.006209
# tensor(0.9152, device='cuda:0') tensor(-0.2670, device='cuda:0')
# Total Loss : 0.006209
# run: [10], model[0]
# Style Loss : 0.005045
# tensor(0.9341, device='cuda:0') tensor(-0.2648, device='cuda:0')
# Total Loss : 0.005045
# run: [10], model[0]
# Style Loss : 0.004497
# tensor(0.9394, device='cuda:0') tensor(-0.2643, device='cuda:0')
# Total Loss : 0.004497
# run: [10], model[0]
# Style Loss : 0.004095
# tensor(0.9450, device='cuda:0') tensor(-0.2635, device='cuda:0')
# Total Loss : 0.004095
# run: [10], model[0]
# Style Loss : 0.003726
# tensor(0.9507, device='cuda:0') tensor(-0.2627, device='cuda:0')
# Total Loss : 0.003726
# run: [10], model[0]
# Style Loss : 0.003422
# tensor(0.9558, device='cuda:0') tensor(-0.2620, device='cuda:0')
# Total Loss : 0.003422
# run: [10], model[0]
# Style Loss : 0.003167
# tensor(0.9606, device='cuda:0') tensor(-0.2612, device='cuda:0')
# Total Loss : 0.003167
# run: [10], model[0]
# Style Loss : 0.002952
# tensor(0.9650, device='cuda:0') tensor(-0.2606, device='cuda:0')
# Total Loss : 0.002952
# run: [10], model[0]
# Style Loss : 0.002768
# tensor(0.9694, device='cuda:0') tensor(-0.2599, device='cuda:0')
# Total Loss : 0.002768
# run: [10], model[0]
# Style Loss : 0.002613
# tensor(0.9734, device='cuda:0') tensor(-0.2593, device='cuda:0')
# Total Loss : 0.002613
# run: [10], model[0]
# Style Loss : 0.002480
# tensor(0.9775, device='cuda:0') tensor(-0.2586, device='cuda:0')
# Total Loss : 0.002480
# run: [10], model[0]
# Style Loss : 0.002367
# tensor(0.9812, device='cuda:0') tensor(-0.2580, device='cuda:0')
# Total Loss : 0.002367
# run: [10], model[0]
# Style Loss : 0.002269
# tensor(0.9849, device='cuda:0') tensor(-0.2574, device='cuda:0')
# Total Loss : 0.002269
# run: [10], model[0]
# Style Loss : 0.002185
# tensor(0.9883, device='cuda:0') tensor(-0.2569, device='cuda:0')
# Total Loss : 0.002185
# run: [10], model[0]
# Style Loss : 0.002113
# tensor(0.9918, device='cuda:0') tensor(-0.2564, device='cuda:0')
# Total Loss : 0.002113
# run: [10], model[0]
# Style Loss : 0.002046
# tensor(0.9954, device='cuda:0') tensor(-0.2559, device='cuda:0')
# Total Loss : 0.002046
# run: [10], model[0]
# Style Loss : 0.001988
# tensor(0.9987, device='cuda:0') tensor(-0.2553, device='cuda:0')
# Total Loss : 0.001988
# run: [10], model[0]
# Style Loss : 0.001934
# tensor(1.0022, device='cuda:0') tensor(-0.2548, device='cuda:0')
# Total Loss : 0.001934
# run: [10], model[0]
# Style Loss : 0.001882
# tensor(1.0056, device='cuda:0') tensor(-0.2543, device='cuda:0')
# Total Loss : 0.001882
# run: [10], model[0]
# Style Loss : 0.001833
# tensor(1.0095, device='cuda:0') tensor(-0.2537, device='cuda:0')
# Total Loss : 0.001833
# run: [10], model[1]
# Style Loss : 0.004201
# tensor(1.0133, device='cuda:0') tensor(-0.2531, device='cuda:0')
# Total Loss : 0.004201
# run: [10], model[1]
# Style Loss : 0.003058
# tensor(1.0222, device='cuda:0') tensor(-0.2515, device='cuda:0')
# Total Loss : 0.003058
# run: [10], model[1]
# Style Loss : 0.002812
# tensor(1.0252, device='cuda:0') tensor(-0.2515, device='cuda:0')
# Total Loss : 0.002812
# run: [10], model[1]
# Style Loss : 0.002512
# tensor(1.0286, device='cuda:0') tensor(-0.2514, device='cuda:0')
# Total Loss : 0.002512
# run: [10], model[1]
# Style Loss : 0.002282
# tensor(1.0314, device='cuda:0') tensor(-0.2512, device='cuda:0')
# Total Loss : 0.002282
# run: [10], model[1]
# Style Loss : 0.002091
# tensor(1.0339, device='cuda:0') tensor(-0.2510, device='cuda:0')
# Total Loss : 0.002091
# run: [10], model[1]
# Style Loss : 0.001934
# tensor(1.0362, device='cuda:0') tensor(-0.2509, device='cuda:0')
# Total Loss : 0.001934
# run: [10], model[1]
# Style Loss : 0.001800
# tensor(1.0384, device='cuda:0') tensor(-0.2506, device='cuda:0')
# Total Loss : 0.001800
# run: [10], model[1]
# Style Loss : 0.001690
# tensor(1.0406, device='cuda:0') tensor(-0.2504, device='cuda:0')
# Total Loss : 0.001690
# run: [10], model[1]
# Style Loss : 0.001598
# tensor(1.0425, device='cuda:0') tensor(-0.2502, device='cuda:0')
# Total Loss : 0.001598
# run: [10], model[1]
# Style Loss : 0.001520
# tensor(1.0443, device='cuda:0') tensor(-0.2498, device='cuda:0')
# Total Loss : 0.001520
# run: [10], model[1]
# Style Loss : 0.001453
# tensor(1.0460, device='cuda:0') tensor(-0.2495, device='cuda:0')
# Total Loss : 0.001453
# run: [10], model[1]
# Style Loss : 0.001397
# tensor(1.0476, device='cuda:0') tensor(-0.2491, device='cuda:0')
# Total Loss : 0.001397
# run: [10], model[1]
# Style Loss : 0.001349
# tensor(1.0492, device='cuda:0') tensor(-0.2488, device='cuda:0')
# Total Loss : 0.001349
# run: [10], model[1]
# Style Loss : 0.001307
# tensor(1.0508, device='cuda:0') tensor(-0.2485, device='cuda:0')
# Total Loss : 0.001307
# run: [10], model[1]
# Style Loss : 0.001269
# tensor(1.0523, device='cuda:0') tensor(-0.2480, device='cuda:0')
# Total Loss : 0.001269
# run: [10], model[1]
# Style Loss : 0.001236
# tensor(1.0539, device='cuda:0') tensor(-0.2476, device='cuda:0')
# Total Loss : 0.001236
# run: [10], model[1]
# Style Loss : 0.001204
# tensor(1.0555, device='cuda:0') tensor(-0.2471, device='cuda:0')
# Total Loss : 0.001204
# run: [10], model[1]
# Style Loss : 0.001175
# tensor(1.0572, device='cuda:0') tensor(-0.2466, device='cuda:0')
# Total Loss : 0.001175
# run: [10], model[1]
# Style Loss : 0.001146
# tensor(1.0589, device='cuda:0') tensor(-0.2461, device='cuda:0')
# Total Loss : 0.001146
# run: [20], model[0]
# Style Loss : 0.000934
# tensor(1.6371, device='cuda:0') tensor(-0.2530, device='cuda:0')
# Total Loss : 0.000934
# run: [20], model[0]
# Style Loss : 0.000721
# tensor(1.6384, device='cuda:0') tensor(-0.2530, device='cuda:0')
# Total Loss : 0.000721
# run: [20], model[0]
# Style Loss : 0.000593
# tensor(1.6391, device='cuda:0') tensor(-0.2530, device='cuda:0')
# Total Loss : 0.000593
# run: [20], model[0]
# Style Loss : 0.000496
# tensor(1.6397, device='cuda:0') tensor(-0.2530, device='cuda:0')
# Total Loss : 0.000496
# run: [20], model[0]
# Style Loss : 0.000420
# tensor(1.6402, device='cuda:0') tensor(-0.2529, device='cuda:0')
# Total Loss : 0.000420
# run: [20], model[0]
# Style Loss : 0.000362
# tensor(1.6406, device='cuda:0') tensor(-0.2529, device='cuda:0')
# Total Loss : 0.000362
# run: [20], model[0]
# Style Loss : 0.000313
# tensor(1.6410, device='cuda:0') tensor(-0.2529, device='cuda:0')
# Total Loss : 0.000313
# run: [20], model[0]
# Style Loss : 0.000277
# tensor(1.6413, device='cuda:0') tensor(-0.2529, device='cuda:0')
# Total Loss : 0.000277
# run: [20], model[0]
# Style Loss : 0.000247
# tensor(1.6416, device='cuda:0') tensor(-0.2529, device='cuda:0')
# Total Loss : 0.000247
# run: [20], model[0]
# Style Loss : 0.000224
# tensor(1.6419, device='cuda:0') tensor(-0.2529, device='cuda:0')
# Total Loss : 0.000224
# run: [20], model[0]
# Style Loss : 0.000205
# tensor(1.6421, device='cuda:0') tensor(-0.2529, device='cuda:0')
# Total Loss : 0.000205
# run: [20], model[0]
# Style Loss : 0.000190
# tensor(1.6423, device='cuda:0') tensor(-0.2528, device='cuda:0')
# Total Loss : 0.000190
# run: [20], model[0]
# Style Loss : 0.000177
# tensor(1.6425, device='cuda:0') tensor(-0.2528, device='cuda:0')
# Total Loss : 0.000177
# run: [20], model[0]
# Style Loss : 0.000168
# tensor(1.6427, device='cuda:0') tensor(-0.2528, device='cuda:0')
# Total Loss : 0.000168
# run: [20], model[0]
# Style Loss : 0.000160
# tensor(1.6429, device='cuda:0') tensor(-0.2528, device='cuda:0')
# Total Loss : 0.000160
# run: [20], model[0]
# Style Loss : 0.000153
# tensor(1.6430, device='cuda:0') tensor(-0.2528, device='cuda:0')
# Total Loss : 0.000153
# run: [20], model[0]
# Style Loss : 0.000148
# tensor(1.6432, device='cuda:0') tensor(-0.2528, device='cuda:0')
# Total Loss : 0.000148
# run: [20], model[0]
# Style Loss : 0.000144
# tensor(1.6433, device='cuda:0') tensor(-0.2528, device='cuda:0')
# Total Loss : 0.000144
# run: [20], model[0]
# Style Loss : 0.000140
# tensor(1.6435, device='cuda:0') tensor(-0.2528, device='cuda:0')
# Total Loss : 0.000140
# run: [20], model[0]
# Style Loss : 0.000137
# tensor(1.6436, device='cuda:0') tensor(-0.2528, device='cuda:0')
# Total Loss : 0.000137
# run: [20], model[1]
# Style Loss : 0.000827
# tensor(1.6437, device='cuda:0') tensor(-0.2528, device='cuda:0')
# Total Loss : 0.000827
# run: [20], model[1]
# Style Loss : 0.000639
# tensor(1.6450, device='cuda:0') tensor(-0.2523, device='cuda:0')
# Total Loss : 0.000639
# run: [20], model[1]
# Style Loss : 0.000521
# tensor(1.6457, device='cuda:0') tensor(-0.2520, device='cuda:0')
# Total Loss : 0.000521
# run: [20], model[1]
# Style Loss : 0.000434
# tensor(1.6464, device='cuda:0') tensor(-0.2518, device='cuda:0')
# Total Loss : 0.000434
# run: [20], model[1]
# Style Loss : 0.000366
# tensor(1.6468, device='cuda:0') tensor(-0.2516, device='cuda:0')
# Total Loss : 0.000366
# run: [20], model[1]
# Style Loss : 0.000313
# tensor(1.6472, device='cuda:0') tensor(-0.2514, device='cuda:0')
# Total Loss : 0.000313
# run: [20], model[1]
# Style Loss : 0.000270
# tensor(1.6476, device='cuda:0') tensor(-0.2512, device='cuda:0')
# Total Loss : 0.000270
# run: [20], model[1]
# Style Loss : 0.000238
# tensor(1.6480, device='cuda:0') tensor(-0.2510, device='cuda:0')
# Total Loss : 0.000238
# run: [20], model[1]
# Style Loss : 0.000211
# tensor(1.6482, device='cuda:0') tensor(-0.2509, device='cuda:0')
# Total Loss : 0.000211
# run: [20], model[1]
# Style Loss : 0.000191
# tensor(1.6485, device='cuda:0') tensor(-0.2507, device='cuda:0')
# Total Loss : 0.000191
# run: [20], model[1]
# Style Loss : 0.000174
# tensor(1.6488, device='cuda:0') tensor(-0.2506, device='cuda:0')
# Total Loss : 0.000174
# run: [20], model[1]
# Style Loss : 0.000161
# tensor(1.6490, device='cuda:0') tensor(-0.2505, device='cuda:0')
# Total Loss : 0.000161
# run: [20], model[1]
# Style Loss : 0.000150
# tensor(1.6492, device='cuda:0') tensor(-0.2504, device='cuda:0')
# Total Loss : 0.000150
# run: [20], model[1]
# Style Loss : 0.000142
# tensor(1.6494, device='cuda:0') tensor(-0.2503, device='cuda:0')
# Total Loss : 0.000142
# run: [20], model[1]
# Style Loss : 0.000135
# tensor(1.6496, device='cuda:0') tensor(-0.2502, device='cuda:0')
# Total Loss : 0.000135
# run: [20], model[1]
# Style Loss : 0.000130
# tensor(1.6498, device='cuda:0') tensor(-0.2502, device='cuda:0')
# Total Loss : 0.000130
# run: [20], model[1]
# Style Loss : 0.000125
# tensor(1.6499, device='cuda:0') tensor(-0.2501, device='cuda:0')
# Total Loss : 0.000125
# run: [20], model[1]
# Style Loss : 0.000121
# tensor(1.6501, device='cuda:0') tensor(-0.2500, device='cuda:0')
# Total Loss : 0.000121
# run: [20], model[1]
# Style Loss : 0.000118
# tensor(1.6502, device='cuda:0') tensor(-0.2500, device='cuda:0')
# Total Loss : 0.000118
# run: [20], model[1]
# Style Loss : 0.000116
# tensor(1.6504, device='cuda:0') tensor(-0.2499, device='cuda:0')
# Total Loss : 0.000116
# run: [30], model[0]
# Style Loss : 0.000573
# tensor(1.7080, device='cuda:0') tensor(-0.2293, device='cuda:0')
# Total Loss : 0.000573
# run: [30], model[0]
# Style Loss : 0.000444
# tensor(1.7079, device='cuda:0') tensor(-0.2288, device='cuda:0')
# Total Loss : 0.000444
# run: [30], model[0]
# Style Loss : 0.000351
# tensor(1.7078, device='cuda:0') tensor(-0.2284, device='cuda:0')
# Total Loss : 0.000351
# run: [30], model[0]
# Style Loss : 0.000281
# tensor(1.7076, device='cuda:0') tensor(-0.2281, device='cuda:0')
# Total Loss : 0.000281
# run: [30], model[0]
# Style Loss : 0.000229
# tensor(1.7075, device='cuda:0') tensor(-0.2278, device='cuda:0')
# Total Loss : 0.000229
# run: [30], model[0]
# Style Loss : 0.000190
# tensor(1.7074, device='cuda:0') tensor(-0.2276, device='cuda:0')
# Total Loss : 0.000190
# run: [30], model[0]
# Style Loss : 0.000159
# tensor(1.7073, device='cuda:0') tensor(-0.2274, device='cuda:0')
# Total Loss : 0.000159
# run: [30], model[0]
# Style Loss : 0.000136
# tensor(1.7072, device='cuda:0') tensor(-0.2272, device='cuda:0')
# Total Loss : 0.000136
# run: [30], model[0]
# Style Loss : 0.000118
# tensor(1.7071, device='cuda:0') tensor(-0.2270, device='cuda:0')
# Total Loss : 0.000118
# run: [30], model[0]
# Style Loss : 0.000103
# tensor(1.7070, device='cuda:0') tensor(-0.2269, device='cuda:0')
# Total Loss : 0.000103
# run: [30], model[0]
# Style Loss : 0.000091
# tensor(1.7069, device='cuda:0') tensor(-0.2268, device='cuda:0')
# Total Loss : 0.000091
# run: [30], model[0]
# Style Loss : 0.000083
# tensor(1.7069, device='cuda:0') tensor(-0.2266, device='cuda:0')
# Total Loss : 0.000083
# run: [30], model[0]
# Style Loss : 0.000075
# tensor(1.7068, device='cuda:0') tensor(-0.2265, device='cuda:0')
# Total Loss : 0.000075
# run: [30], model[0]
# Style Loss : 0.000070
# tensor(1.7067, device='cuda:0') tensor(-0.2264, device='cuda:0')
# Total Loss : 0.000070
# run: [30], model[0]
# Style Loss : 0.000065
# tensor(1.7067, device='cuda:0') tensor(-0.2264, device='cuda:0')
# Total Loss : 0.000065
# run: [30], model[0]
# Style Loss : 0.000061
# tensor(1.7066, device='cuda:0') tensor(-0.2263, device='cuda:0')
# Total Loss : 0.000061
# run: [30], model[0]
# Style Loss : 0.000059
# tensor(1.7066, device='cuda:0') tensor(-0.2262, device='cuda:0')
# Total Loss : 0.000059
# run: [30], model[0]
# Style Loss : 0.000056
# tensor(1.7066, device='cuda:0') tensor(-0.2262, device='cuda:0')
# Total Loss : 0.000056
# run: [30], model[0]
# Style Loss : 0.000054
# tensor(1.7065, device='cuda:0') tensor(-0.2261, device='cuda:0')
# Total Loss : 0.000054
# run: [30], model[0]
# Style Loss : 0.000053
# tensor(1.7065, device='cuda:0') tensor(-0.2261, device='cuda:0')
# Total Loss : 0.000053
# run: [30], model[1]
# Style Loss : 0.000526
# tensor(1.7065, device='cuda:0') tensor(-0.2260, device='cuda:0')
# Total Loss : 0.000526
# run: [30], model[1]
# Style Loss : 0.000404
# tensor(1.7071, device='cuda:0') tensor(-0.2259, device='cuda:0')
# Total Loss : 0.000404
# run: [30], model[1]
# Style Loss : 0.000318
# tensor(1.7076, device='cuda:0') tensor(-0.2258, device='cuda:0')
# Total Loss : 0.000318
# run: [30], model[1]
# Style Loss : 0.000256
# tensor(1.7080, device='cuda:0') tensor(-0.2257, device='cuda:0')
# Total Loss : 0.000256
# run: [30], model[1]
# Style Loss : 0.000209
# tensor(1.7084, device='cuda:0') tensor(-0.2256, device='cuda:0')
# Total Loss : 0.000209
# run: [30], model[1]
# Style Loss : 0.000173
# tensor(1.7087, device='cuda:0') tensor(-0.2255, device='cuda:0')
# Total Loss : 0.000173
# run: [30], model[1]
# Style Loss : 0.000145
# tensor(1.7090, device='cuda:0') tensor(-0.2255, device='cuda:0')
# Total Loss : 0.000145
# run: [30], model[1]
# Style Loss : 0.000123
# tensor(1.7092, device='cuda:0') tensor(-0.2254, device='cuda:0')
# Total Loss : 0.000123
# run: [30], model[1]
# Style Loss : 0.000106
# tensor(1.7095, device='cuda:0') tensor(-0.2254, device='cuda:0')
# Total Loss : 0.000106
# run: [30], model[1]
# Style Loss : 0.000093
# tensor(1.7097, device='cuda:0') tensor(-0.2253, device='cuda:0')
# Total Loss : 0.000093
# run: [30], model[1]
# Style Loss : 0.000082
# tensor(1.7098, device='cuda:0') tensor(-0.2253, device='cuda:0')
# Total Loss : 0.000082
# run: [30], model[1]
# Style Loss : 0.000074
# tensor(1.7100, device='cuda:0') tensor(-0.2252, device='cuda:0')
# Total Loss : 0.000074
# run: [30], model[1]
# Style Loss : 0.000068
# tensor(1.7101, device='cuda:0') tensor(-0.2252, device='cuda:0')
# Total Loss : 0.000068
# run: [30], model[1]
# Style Loss : 0.000062
# tensor(1.7103, device='cuda:0') tensor(-0.2252, device='cuda:0')
# Total Loss : 0.000062
# run: [30], model[1]
# Style Loss : 0.000058
# tensor(1.7104, device='cuda:0') tensor(-0.2252, device='cuda:0')
# Total Loss : 0.000058
# run: [30], model[1]
# Style Loss : 0.000055
# tensor(1.7105, device='cuda:0') tensor(-0.2251, device='cuda:0')
# Total Loss : 0.000055
# run: [30], model[1]
# Style Loss : 0.000053
# tensor(1.7106, device='cuda:0') tensor(-0.2251, device='cuda:0')
# Total Loss : 0.000053
# run: [30], model[1]
# Style Loss : 0.000050
# tensor(1.7107, device='cuda:0') tensor(-0.2251, device='cuda:0')
# Total Loss : 0.000050
# run: [30], model[1]
# Style Loss : 0.000049
# tensor(1.7108, device='cuda:0') tensor(-0.2251, device='cuda:0')
# Total Loss : 0.000049
# run: [30], model[1]
# Style Loss : 0.000047
# tensor(1.7109, device='cuda:0') tensor(-0.2251, device='cuda:0')
# Total Loss : 0.000047
# run: [40], model[0]
# Style Loss : 0.000544
# tensor(1.7167, device='cuda:0') tensor(-0.1817, device='cuda:0')
# Total Loss : 0.000544
# run: [40], model[0]
# Style Loss : 0.000422
# tensor(1.7166, device='cuda:0') tensor(-0.1813, device='cuda:0')
# Total Loss : 0.000422
# run: [40], model[0]
# Style Loss : 0.000322
# tensor(1.7167, device='cuda:0') tensor(-0.1808, device='cuda:0')
# Total Loss : 0.000322
# run: [40], model[0]
# Style Loss : 0.000254
# tensor(1.7167, device='cuda:0') tensor(-0.1805, device='cuda:0')
# Total Loss : 0.000254
# run: [40], model[0]
# Style Loss : 0.000204
# tensor(1.7166, device='cuda:0') tensor(-0.1802, device='cuda:0')
# Total Loss : 0.000204
# run: [40], model[0]
# Style Loss : 0.000164
# tensor(1.7166, device='cuda:0') tensor(-0.1800, device='cuda:0')
# Total Loss : 0.000164
# run: [40], model[0]
# Style Loss : 0.000136
# tensor(1.7166, device='cuda:0') tensor(-0.1798, device='cuda:0')
# Total Loss : 0.000136
# run: [40], model[0]
# Style Loss : 0.000112
# tensor(1.7165, device='cuda:0') tensor(-0.1796, device='cuda:0')
# Total Loss : 0.000112
# run: [40], model[0]
# Style Loss : 0.000095
# tensor(1.7165, device='cuda:0') tensor(-0.1795, device='cuda:0')
# Total Loss : 0.000095
# run: [40], model[0]
# Style Loss : 0.000081
# tensor(1.7164, device='cuda:0') tensor(-0.1793, device='cuda:0')
# Total Loss : 0.000081
# run: [40], model[0]
# Style Loss : 0.000070
# tensor(1.7163, device='cuda:0') tensor(-0.1792, device='cuda:0')
# Total Loss : 0.000070
# run: [40], model[0]
# Style Loss : 0.000062
# tensor(1.7163, device='cuda:0') tensor(-0.1791, device='cuda:0')
# Total Loss : 0.000062
# run: [40], model[0]
# Style Loss : 0.000055
# tensor(1.7162, device='cuda:0') tensor(-0.1790, device='cuda:0')
# Total Loss : 0.000055
# run: [40], model[0]
# Style Loss : 0.000050
# tensor(1.7162, device='cuda:0') tensor(-0.1789, device='cuda:0')
# Total Loss : 0.000050
# run: [40], model[0]
# Style Loss : 0.000045
# tensor(1.7162, device='cuda:0') tensor(-0.1789, device='cuda:0')
# Total Loss : 0.000045
# run: [40], model[0]
# Style Loss : 0.000042
# tensor(1.7161, device='cuda:0') tensor(-0.1788, device='cuda:0')
# Total Loss : 0.000042
# run: [40], model[0]
# Style Loss : 0.000040
# tensor(1.7161, device='cuda:0') tensor(-0.1787, device='cuda:0')
# Total Loss : 0.000040
# run: [40], model[0]
# Style Loss : 0.000037
# tensor(1.7160, device='cuda:0') tensor(-0.1787, device='cuda:0')
# Total Loss : 0.000037
# run: [40], model[0]
# Style Loss : 0.000036
# tensor(1.7160, device='cuda:0') tensor(-0.1786, device='cuda:0')
# Total Loss : 0.000036
# run: [40], model[0]
# Style Loss : 0.000035
# tensor(1.7160, device='cuda:0') tensor(-0.1786, device='cuda:0')
# Total Loss : 0.000035
# run: [40], model[1]
# Style Loss : 0.000501
# tensor(1.7159, device='cuda:0') tensor(-0.1785, device='cuda:0')
# Total Loss : 0.000501
# run: [40], model[1]
# Style Loss : 0.000386
# tensor(1.7165, device='cuda:0') tensor(-0.1783, device='cuda:0')
# Total Loss : 0.000386
# run: [40], model[1]
# Style Loss : 0.000297
# tensor(1.7170, device='cuda:0') tensor(-0.1780, device='cuda:0')
# Total Loss : 0.000297
# run: [40], model[1]
# Style Loss : 0.000233
# tensor(1.7174, device='cuda:0') tensor(-0.1778, device='cuda:0')
# Total Loss : 0.000233
# run: [40], model[1]
# Style Loss : 0.000187
# tensor(1.7177, device='cuda:0') tensor(-0.1776, device='cuda:0')
# Total Loss : 0.000187
# run: [40], model[1]
# Style Loss : 0.000151
# tensor(1.7179, device='cuda:0') tensor(-0.1775, device='cuda:0')
# Total Loss : 0.000151
# run: [40], model[1]
# Style Loss : 0.000124
# tensor(1.7182, device='cuda:0') tensor(-0.1773, device='cuda:0')
# Total Loss : 0.000124
# run: [40], model[1]
# Style Loss : 0.000104
# tensor(1.7184, device='cuda:0') tensor(-0.1772, device='cuda:0')
# Total Loss : 0.000104
# run: [40], model[1]
# Style Loss : 0.000087
# tensor(1.7185, device='cuda:0') tensor(-0.1771, device='cuda:0')
# Total Loss : 0.000087
# run: [40], model[1]
# Style Loss : 0.000075
# tensor(1.7186, device='cuda:0') tensor(-0.1771, device='cuda:0')
# Total Loss : 0.000075
# run: [40], model[1]
# Style Loss : 0.000065
# tensor(1.7187, device='cuda:0') tensor(-0.1770, device='cuda:0')
# Total Loss : 0.000065
# run: [40], model[1]
# Style Loss : 0.000057
# tensor(1.7188, device='cuda:0') tensor(-0.1769, device='cuda:0')
# Total Loss : 0.000057
# run: [40], model[1]
# Style Loss : 0.000051
# tensor(1.7189, device='cuda:0') tensor(-0.1768, device='cuda:0')
# Total Loss : 0.000051
# run: [40], model[1]
# Style Loss : 0.000046
# tensor(1.7190, device='cuda:0') tensor(-0.1768, device='cuda:0')
# Total Loss : 0.000046
# run: [40], model[1]
# Style Loss : 0.000042
# tensor(1.7191, device='cuda:0') tensor(-0.1767, device='cuda:0')
# Total Loss : 0.000042
# run: [40], model[1]
# Style Loss : 0.000039
# tensor(1.7191, device='cuda:0') tensor(-0.1767, device='cuda:0')
# Total Loss : 0.000039
# run: [40], model[1]
# Style Loss : 0.000036
# tensor(1.7192, device='cuda:0') tensor(-0.1766, device='cuda:0')
# Total Loss : 0.000036
# run: [40], model[1]
# Style Loss : 0.000034
# tensor(1.7193, device='cuda:0') tensor(-0.1766, device='cuda:0')
# Total Loss : 0.000034
# run: [40], model[1]
# Style Loss : 0.000033
# tensor(1.7193, device='cuda:0') tensor(-0.1766, device='cuda:0')
# Total Loss : 0.000033
# run: [40], model[1]
# Style Loss : 0.000032
# tensor(1.7193, device='cuda:0') tensor(-0.1765, device='cuda:0')
# Total Loss : 0.000032
# run: [50], model[0]
# Style Loss : 0.000737
# tensor(1.7426, device='cuda:0') tensor(-0.1433, device='cuda:0')
# Total Loss : 0.000737
# run: [50], model[0]
# Style Loss : 0.000579
# tensor(1.7427, device='cuda:0') tensor(-0.1434, device='cuda:0')
# Total Loss : 0.000579
# run: [50], model[0]
# Style Loss : 0.000425
# tensor(1.7429, device='cuda:0') tensor(-0.1435, device='cuda:0')
# Total Loss : 0.000425
# run: [50], model[0]
# Style Loss : 0.000326
# tensor(1.7431, device='cuda:0') tensor(-0.1435, device='cuda:0')
# Total Loss : 0.000326
# run: [50], model[0]
# Style Loss : 0.000257
# tensor(1.7432, device='cuda:0') tensor(-0.1436, device='cuda:0')
# Total Loss : 0.000257
# run: [50], model[0]
# Style Loss : 0.000207
# tensor(1.7433, device='cuda:0') tensor(-0.1437, device='cuda:0')
# Total Loss : 0.000207
# run: [50], model[0]
# Style Loss : 0.000169
# tensor(1.7433, device='cuda:0') tensor(-0.1437, device='cuda:0')
# Total Loss : 0.000169
# run: [50], model[0]
# Style Loss : 0.000139
# tensor(1.7434, device='cuda:0') tensor(-0.1438, device='cuda:0')
# Total Loss : 0.000139
# run: [50], model[0]
# Style Loss : 0.000115
# tensor(1.7434, device='cuda:0') tensor(-0.1438, device='cuda:0')
# Total Loss : 0.000115
# run: [50], model[0]
# Style Loss : 0.000097
# tensor(1.7434, device='cuda:0') tensor(-0.1438, device='cuda:0')
# Total Loss : 0.000097
# run: [50], model[0]
# Style Loss : 0.000083
# tensor(1.7435, device='cuda:0') tensor(-0.1438, device='cuda:0')
# Total Loss : 0.000083
# run: [50], model[0]
# Style Loss : 0.000072
# tensor(1.7435, device='cuda:0') tensor(-0.1439, device='cuda:0')
# Total Loss : 0.000072
# run: [50], model[0]
# Style Loss : 0.000063
# tensor(1.7435, device='cuda:0') tensor(-0.1439, device='cuda:0')
# Total Loss : 0.000063
# run: [50], model[0]
# Style Loss : 0.000056
# tensor(1.7435, device='cuda:0') tensor(-0.1439, device='cuda:0')
# Total Loss : 0.000056
# run: [50], model[0]
# Style Loss : 0.000050
# tensor(1.7435, device='cuda:0') tensor(-0.1439, device='cuda:0')
# Total Loss : 0.000050
# run: [50], model[0]
# Style Loss : 0.000046
# tensor(1.7435, device='cuda:0') tensor(-0.1439, device='cuda:0')
# Total Loss : 0.000046
# run: [50], model[0]
# Style Loss : 0.000043
# tensor(1.7435, device='cuda:0') tensor(-0.1439, device='cuda:0')
# Total Loss : 0.000043
# run: [50], model[0]
# Style Loss : 0.000040
# tensor(1.7435, device='cuda:0') tensor(-0.1440, device='cuda:0')
# Total Loss : 0.000040
# run: [50], model[0]
# Style Loss : 0.000038
# tensor(1.7435, device='cuda:0') tensor(-0.1440, device='cuda:0')
# Total Loss : 0.000038
# run: [50], model[0]
# Style Loss : 0.000036
# tensor(1.7435, device='cuda:0') tensor(-0.1440, device='cuda:0')
# Total Loss : 0.000036
# run: [50], model[1]
# Style Loss : 0.000666
# tensor(1.7435, device='cuda:0') tensor(-0.1440, device='cuda:0')
# Total Loss : 0.000666
# run: [50], model[1]
# Style Loss : 0.000509
# tensor(1.7437, device='cuda:0') tensor(-0.1436, device='cuda:0')
# Total Loss : 0.000509
# run: [50], model[1]
# Style Loss : 0.000370
# tensor(1.7440, device='cuda:0') tensor(-0.1432, device='cuda:0')
# Total Loss : 0.000370
# run: [50], model[1]
# Style Loss : 0.000288
# tensor(1.7442, device='cuda:0') tensor(-0.1429, device='cuda:0')
# Total Loss : 0.000288
# run: [50], model[1]
# Style Loss : 0.000226
# tensor(1.7444, device='cuda:0') tensor(-0.1426, device='cuda:0')
# Total Loss : 0.000226
# run: [50], model[1]
# Style Loss : 0.000182
# tensor(1.7446, device='cuda:0') tensor(-0.1424, device='cuda:0')
# Total Loss : 0.000182
# run: [50], model[1]
# Style Loss : 0.000149
# tensor(1.7447, device='cuda:0') tensor(-0.1422, device='cuda:0')
# Total Loss : 0.000149
# run: [50], model[1]
# Style Loss : 0.000123
# tensor(1.7447, device='cuda:0') tensor(-0.1421, device='cuda:0')
# Total Loss : 0.000123
# run: [50], model[1]
# Style Loss : 0.000102
# tensor(1.7448, device='cuda:0') tensor(-0.1420, device='cuda:0')
# Total Loss : 0.000102
# run: [50], model[1]
# Style Loss : 0.000086
# tensor(1.7449, device='cuda:0') tensor(-0.1418, device='cuda:0')
# Total Loss : 0.000086
# run: [50], model[1]
# Style Loss : 0.000073
# tensor(1.7449, device='cuda:0') tensor(-0.1417, device='cuda:0')
# Total Loss : 0.000073
# run: [50], model[1]
# Style Loss : 0.000064
# tensor(1.7450, device='cuda:0') tensor(-0.1417, device='cuda:0')
# Total Loss : 0.000064
# run: [50], model[1]
# Style Loss : 0.000056
# tensor(1.7450, device='cuda:0') tensor(-0.1416, device='cuda:0')
# Total Loss : 0.000056
# run: [50], model[1]
# Style Loss : 0.000050
# tensor(1.7451, device='cuda:0') tensor(-0.1415, device='cuda:0')
# Total Loss : 0.000050
# run: [50], model[1]
# Style Loss : 0.000045
# tensor(1.7451, device='cuda:0') tensor(-0.1415, device='cuda:0')
# Total Loss : 0.000045
# run: [50], model[1]
# Style Loss : 0.000041
# tensor(1.7451, device='cuda:0') tensor(-0.1414, device='cuda:0')
# Total Loss : 0.000041
# run: [50], model[1]
# Style Loss : 0.000038
# tensor(1.7451, device='cuda:0') tensor(-0.1414, device='cuda:0')
# Total Loss : 0.000038
# run: [50], model[1]
# Style Loss : 0.000036
# tensor(1.7452, device='cuda:0') tensor(-0.1413, device='cuda:0')
# Total Loss : 0.000036
# run: [50], model[1]
# Style Loss : 0.000034
# tensor(1.7451, device='cuda:0') tensor(-0.1413, device='cuda:0')
# Total Loss : 0.000034
# run: [50], model[1]
# Style Loss : 0.000032
# tensor(1.7451, device='cuda:0') tensor(-0.1412, device='cuda:0')
# Total Loss : 0.000032
# run: [60], model[0]
# Style Loss : 0.001405
# tensor(1.7366, device='cuda:0') tensor(-0.1268, device='cuda:0')
# Total Loss : 0.001405
# run: [60], model[0]
# Style Loss : 0.001106
# tensor(1.7367, device='cuda:0') tensor(-0.1271, device='cuda:0')
# Total Loss : 0.001106
# run: [60], model[0]
# Style Loss : 0.000759
# tensor(1.7371, device='cuda:0') tensor(-0.1276, device='cuda:0')
# Total Loss : 0.000759
# run: [60], model[0]
# Style Loss : 0.000579
# tensor(1.7374, device='cuda:0') tensor(-0.1279, device='cuda:0')
# Total Loss : 0.000579
# run: [60], model[0]
# Style Loss : 0.000455
# tensor(1.7377, device='cuda:0') tensor(-0.1281, device='cuda:0')
# Total Loss : 0.000455
# run: [60], model[0]
# Style Loss : 0.000362
# tensor(1.7380, device='cuda:0') tensor(-0.1283, device='cuda:0')
# Total Loss : 0.000362
# run: [60], model[0]
# Style Loss : 0.000295
# tensor(1.7382, device='cuda:0') tensor(-0.1285, device='cuda:0')
# Total Loss : 0.000295
# run: [60], model[0]
# Style Loss : 0.000241
# tensor(1.7384, device='cuda:0') tensor(-0.1286, device='cuda:0')
# Total Loss : 0.000241
# run: [60], model[0]
# Style Loss : 0.000201
# tensor(1.7385, device='cuda:0') tensor(-0.1287, device='cuda:0')
# Total Loss : 0.000201
# run: [60], model[0]
# Style Loss : 0.000168
# tensor(1.7386, device='cuda:0') tensor(-0.1288, device='cuda:0')
# Total Loss : 0.000168
# run: [60], model[0]
# Style Loss : 0.000143
# tensor(1.7388, device='cuda:0') tensor(-0.1289, device='cuda:0')
# Total Loss : 0.000143
# run: [60], model[0]
# Style Loss : 0.000123
# tensor(1.7388, device='cuda:0') tensor(-0.1290, device='cuda:0')
# Total Loss : 0.000123
# run: [60], model[0]
# Style Loss : 0.000107
# tensor(1.7389, device='cuda:0') tensor(-0.1290, device='cuda:0')
# Total Loss : 0.000107
# run: [60], model[0]
# Style Loss : 0.000094
# tensor(1.7390, device='cuda:0') tensor(-0.1291, device='cuda:0')
# Total Loss : 0.000094
# run: [60], model[0]
# Style Loss : 0.000084
# tensor(1.7390, device='cuda:0') tensor(-0.1291, device='cuda:0')
# Total Loss : 0.000084
# run: [60], model[0]
# Style Loss : 0.000076
# tensor(1.7391, device='cuda:0') tensor(-0.1292, device='cuda:0')
# Total Loss : 0.000076
# run: [60], model[0]
# Style Loss : 0.000070
# tensor(1.7391, device='cuda:0') tensor(-0.1292, device='cuda:0')
# Total Loss : 0.000070
# run: [60], model[0]
# Style Loss : 0.000065
# tensor(1.7392, device='cuda:0') tensor(-0.1292, device='cuda:0')
# Total Loss : 0.000065
# run: [60], model[0]
# Style Loss : 0.000061
# tensor(1.7392, device='cuda:0') tensor(-0.1293, device='cuda:0')
# Total Loss : 0.000061
# run: [60], model[0]
# Style Loss : 0.000057
# tensor(1.7393, device='cuda:0') tensor(-0.1293, device='cuda:0')
# Total Loss : 0.000057
# run: [60], model[1]
# Style Loss : 0.001239
# tensor(1.7393, device='cuda:0') tensor(-0.1293, device='cuda:0')
# Total Loss : 0.001239
# run: [60], model[1]
# Style Loss : 0.000990
# tensor(1.7391, device='cuda:0') tensor(-0.1294, device='cuda:0')
# Total Loss : 0.000990
# run: [60], model[1]
# Style Loss : 0.000666
# tensor(1.7391, device='cuda:0') tensor(-0.1296, device='cuda:0')
# Total Loss : 0.000666
# run: [60], model[1]
# Style Loss : 0.000503
# tensor(1.7390, device='cuda:0') tensor(-0.1297, device='cuda:0')
# Total Loss : 0.000503
# run: [60], model[1]
# Style Loss : 0.000394
# tensor(1.7390, device='cuda:0') tensor(-0.1297, device='cuda:0')
# Total Loss : 0.000394
# run: [60], model[1]
# Style Loss : 0.000316
# tensor(1.7389, device='cuda:0') tensor(-0.1298, device='cuda:0')
# Total Loss : 0.000316
# run: [60], model[1]
# Style Loss : 0.000257
# tensor(1.7388, device='cuda:0') tensor(-0.1298, device='cuda:0')
# Total Loss : 0.000257
# run: [60], model[1]
# Style Loss : 0.000211
# tensor(1.7386, device='cuda:0') tensor(-0.1299, device='cuda:0')
# Total Loss : 0.000211
# run: [60], model[1]
# Style Loss : 0.000175
# tensor(1.7385, device='cuda:0') tensor(-0.1299, device='cuda:0')
# Total Loss : 0.000175
# run: [60], model[1]
# Style Loss : 0.000148
# tensor(1.7384, device='cuda:0') tensor(-0.1299, device='cuda:0')
# Total Loss : 0.000148
# run: [60], model[1]
# Style Loss : 0.000126
# tensor(1.7383, device='cuda:0') tensor(-0.1300, device='cuda:0')
# Total Loss : 0.000126
# run: [60], model[1]
# Style Loss : 0.000108
# tensor(1.7382, device='cuda:0') tensor(-0.1300, device='cuda:0')
# Total Loss : 0.000108
# run: [60], model[1]
# Style Loss : 0.000095
# tensor(1.7380, device='cuda:0') tensor(-0.1300, device='cuda:0')
# Total Loss : 0.000095
# run: [60], model[1]
# Style Loss : 0.000084
# tensor(1.7379, device='cuda:0') tensor(-0.1300, device='cuda:0')
# Total Loss : 0.000084
# run: [60], model[1]
# Style Loss : 0.000075
# tensor(1.7378, device='cuda:0') tensor(-0.1300, device='cuda:0')
# Total Loss : 0.000075
# run: [60], model[1]
# Style Loss : 0.000068
# tensor(1.7377, device='cuda:0') tensor(-0.1300, device='cuda:0')
# Total Loss : 0.000068
# run: [60], model[1]
# Style Loss : 0.000063
# tensor(1.7376, device='cuda:0') tensor(-0.1301, device='cuda:0')
# Total Loss : 0.000063
# run: [60], model[1]
# Style Loss : 0.000059
# tensor(1.7375, device='cuda:0') tensor(-0.1301, device='cuda:0')
# Total Loss : 0.000059
# run: [60], model[1]
# Style Loss : 0.000055
# tensor(1.7374, device='cuda:0') tensor(-0.1301, device='cuda:0')
# Total Loss : 0.000055
# run: [60], model[1]
# Style Loss : 0.000052
# tensor(1.7374, device='cuda:0') tensor(-0.1301, device='cuda:0')
# Total Loss : 0.000052
# run: [70], model[0]
# Style Loss : 0.001828
# tensor(1.7322, device='cuda:0') tensor(-0.1443, device='cuda:0')
# Total Loss : 0.001828
# run: [70], model[0]
# Style Loss : 0.001432
# tensor(1.7326, device='cuda:0') tensor(-0.1443, device='cuda:0')
# Total Loss : 0.001432
# run: [70], model[0]
# Style Loss : 0.001034
# tensor(1.7330, device='cuda:0') tensor(-0.1443, device='cuda:0')
# Total Loss : 0.001034
# run: [70], model[0]
# Style Loss : 0.000800
# tensor(1.7334, device='cuda:0') tensor(-0.1443, device='cuda:0')
# Total Loss : 0.000800
# run: [70], model[0]
# Style Loss : 0.000635
# tensor(1.7336, device='cuda:0') tensor(-0.1443, device='cuda:0')
# Total Loss : 0.000635
# run: [70], model[0]
# Style Loss : 0.000510
# tensor(1.7337, device='cuda:0') tensor(-0.1443, device='cuda:0')
# Total Loss : 0.000510
# run: [70], model[0]
# Style Loss : 0.000415
# tensor(1.7338, device='cuda:0') tensor(-0.1443, device='cuda:0')
# Total Loss : 0.000415
# run: [70], model[0]
# Style Loss : 0.000342
# tensor(1.7338, device='cuda:0') tensor(-0.1443, device='cuda:0')
# Total Loss : 0.000342
# run: [70], model[0]
# Style Loss : 0.000285
# tensor(1.7338, device='cuda:0') tensor(-0.1443, device='cuda:0')
# Total Loss : 0.000285
# run: [70], model[0]
# Style Loss : 0.000239
# tensor(1.7338, device='cuda:0') tensor(-0.1443, device='cuda:0')
# Total Loss : 0.000239
# run: [70], model[0]
# Style Loss : 0.000203
# tensor(1.7337, device='cuda:0') tensor(-0.1443, device='cuda:0')
# Total Loss : 0.000203
# run: [70], model[0]
# Style Loss : 0.000174
# tensor(1.7336, device='cuda:0') tensor(-0.1443, device='cuda:0')
# Total Loss : 0.000174
# run: [70], model[0]
# Style Loss : 0.000152
# tensor(1.7335, device='cuda:0') tensor(-0.1443, device='cuda:0')
# Total Loss : 0.000152
# run: [70], model[0]
# Style Loss : 0.000134
# tensor(1.7334, device='cuda:0') tensor(-0.1443, device='cuda:0')
# Total Loss : 0.000134
# run: [70], model[0]
# Style Loss : 0.000120
# tensor(1.7334, device='cuda:0') tensor(-0.1443, device='cuda:0')
# Total Loss : 0.000120
# run: [70], model[0]
# Style Loss : 0.000108
# tensor(1.7333, device='cuda:0') tensor(-0.1443, device='cuda:0')
# Total Loss : 0.000108
# run: [70], model[0]
# Style Loss : 0.000099
# tensor(1.7332, device='cuda:0') tensor(-0.1443, device='cuda:0')
# Total Loss : 0.000099
# run: [70], model[0]
# Style Loss : 0.000092
# tensor(1.7331, device='cuda:0') tensor(-0.1443, device='cuda:0')
# Total Loss : 0.000092
# run: [70], model[0]
# Style Loss : 0.000086
# tensor(1.7330, device='cuda:0') tensor(-0.1443, device='cuda:0')
# Total Loss : 0.000086
# run: [70], model[0]
# Style Loss : 0.000081
# tensor(1.7330, device='cuda:0') tensor(-0.1443, device='cuda:0')
# Total Loss : 0.000081
# run: [70], model[1]
# Style Loss : 0.001544
# tensor(1.7329, device='cuda:0') tensor(-0.1443, device='cuda:0')
# Total Loss : 0.001544
# run: [70], model[1]
# Style Loss : 0.001238
# tensor(1.7329, device='cuda:0') tensor(-0.1442, device='cuda:0')
# Total Loss : 0.001238
# run: [70], model[1]
# Style Loss : 0.000876
# tensor(1.7330, device='cuda:0') tensor(-0.1442, device='cuda:0')
# Total Loss : 0.000876
# run: [70], model[1]
# Style Loss : 0.000671
# tensor(1.7332, device='cuda:0') tensor(-0.1441, device='cuda:0')
# Total Loss : 0.000671
# run: [70], model[1]
# Style Loss : 0.000530
# tensor(1.7333, device='cuda:0') tensor(-0.1441, device='cuda:0')
# Total Loss : 0.000530
# run: [70], model[1]
# Style Loss : 0.000426
# tensor(1.7334, device='cuda:0') tensor(-0.1441, device='cuda:0')
# Total Loss : 0.000426
# run: [70], model[1]
# Style Loss : 0.000346
# tensor(1.7335, device='cuda:0') tensor(-0.1440, device='cuda:0')
# Total Loss : 0.000346
# run: [70], model[1]
# Style Loss : 0.000287
# tensor(1.7335, device='cuda:0') tensor(-0.1440, device='cuda:0')
# Total Loss : 0.000287
# run: [70], model[1]
# Style Loss : 0.000239
# tensor(1.7335, device='cuda:0') tensor(-0.1440, device='cuda:0')
# Total Loss : 0.000239
# run: [70], model[1]
# Style Loss : 0.000202
# tensor(1.7336, device='cuda:0') tensor(-0.1440, device='cuda:0')
# Total Loss : 0.000202
# run: [70], model[1]
# Style Loss : 0.000172
# tensor(1.7335, device='cuda:0') tensor(-0.1439, device='cuda:0')
# Total Loss : 0.000172
# run: [70], model[1]
# Style Loss : 0.000149
# tensor(1.7335, device='cuda:0') tensor(-0.1439, device='cuda:0')
# Total Loss : 0.000149
# run: [70], model[1]
# Style Loss : 0.000129
# tensor(1.7335, device='cuda:0') tensor(-0.1439, device='cuda:0')
# Total Loss : 0.000129
# run: [70], model[1]
# Style Loss : 0.000115
# tensor(1.7335, device='cuda:0') tensor(-0.1439, device='cuda:0')
# Total Loss : 0.000115
# run: [70], model[1]
# Style Loss : 0.000102
# tensor(1.7335, device='cuda:0') tensor(-0.1439, device='cuda:0')
# Total Loss : 0.000102
# run: [70], model[1]
# Style Loss : 0.000093
# tensor(1.7334, device='cuda:0') tensor(-0.1439, device='cuda:0')
# Total Loss : 0.000093
# run: [70], model[1]
# Style Loss : 0.000085
# tensor(1.7334, device='cuda:0') tensor(-0.1439, device='cuda:0')
# Total Loss : 0.000085
# run: [70], model[1]
# Style Loss : 0.000079
# tensor(1.7334, device='cuda:0') tensor(-0.1439, device='cuda:0')
# Total Loss : 0.000079
# run: [70], model[1]
# Style Loss : 0.000074
# tensor(1.7334, device='cuda:0') tensor(-0.1438, device='cuda:0')
# Total Loss : 0.000074
# run: [70], model[1]
# Style Loss : 0.000070
# tensor(1.7333, device='cuda:0') tensor(-0.1438, device='cuda:0')
# Total Loss : 0.000070
# (257, 504)
# Output range: -0.14329265 1.7329683

# %%
#SPECTOFFSET
SPECTOFFSET=0

##out_spec = inv_scale(out,shf)
for j in range(len(outputs)):
    print(f'Min/Max of outputs:  {np.amin(outputs[j])},{np.amax(outputs[j])}') # check values make sense
    fig = plt.figure()
    plt.title('Style spectrogram')
    ax = fig.add_subplot(111)
    n,b,_ = ax.hist(outputs[j].flatten(),bins='auto')
    plt.show()

if tifresi :
    #### Shift log spec to use max range before thresholding for tfresi inversion
    #outputs=[x+1-np.amax(x) for x in outputs]
    print('TIFResi: inv_log_spectrogram')
    if use01scale == True:
        foo = [img_invscale(x,a_min,a_max,0,1) for x in outputs]
        out_spec = [inv_log_spectrogram(x+SPECTOFFSET) for x in foo]
        for j in range(len(outputs)):
            print(f'   RESCALED: Min/Max of outputs:  {np.amin(foo[j])},{np.amax(foo[j])}') # check values make sense

    else:
        out_spec = [inv_log_spectrogram(x+SPECTOFFSET) for x in outputs] 
        #out_spec = [inv_log(x+SPECTOFFSET) for x in outputs]
        for j in range(len(outputs)):
            print(f'   inv_log_spectrogram: Min/Max of outputs:  {np.amin(out_spec[j])},{np.amax(out_spec[j])}') # check values make sense

else : 
    print('HUZ: inv_log')
    if use01scale == True:
        out_spec = [inv_log(img_invscale(x,a_min,a_max,0,1)) for x in outputs]
    else:
        out_spec = [inv_log(x) for x in outputs]

    for j in range(len(out_spec)):
        print(f'Min/Max of out_spec: {np.amin(out_spec[j])}, {np.amax(out_spec[j])}') # check values make sense
# Out:
# Min/Max of outputs:  -0.1432926505804062,1.7329683303833008
# TIFResi: inv_log_spectrogram
#    inv_log_spectrogram: Min/Max of outputs:  -0.13349956274032593,4.657422065734863

# %%
# Griffin & Lim algo for phase reconstruction (not used for tifresi)

print(f'out_spec lene is {len(out_spec)}')
for index,value in enumerate(out_spec):
    print(f'shape of value is {value.shape}')
    if tifresi :
        print(f'TIFResi invert mag to audio')
        S = value
        bar=S#-np.amin(S)+.0001
        #bar=bar/np.amax(bar)
        bar = np.clip(bar, 0,None)
        print(f'Min/Max of spectrogram: {np.amin(bar)}, {np.amax(bar)}') # check values make sense
        x = stft_system.invert_spectrogram(bar) 
    else :
        print(f'Huz invert mag to audio')
        p = 2 * np.pi * np.random.random_sample(value.shape) - np.pi #start with some phase
        #Griffin Lim
        for i in range(500):
            S = value * np.exp(1j*p) #use magnitude a given by spectrogram and some random phase
            x = librosa.istft(S,hop_length=K_HOP, win_length=N_FFT, center=False) #do the inverse transform
            p = np.angle(librosa.stft(x, n_fft=N_FFT, hop_length=K_HOP, win_length=N_FFT, center=False)) #use this new phase value

    try:
        os.makedirs("outputs/" + outname)
    except FileExistsError:
        # directory already exists
        pass

    OUTPUT_FILENAME="outputs/" + outname + '/' + outname + '_' + str(index) + '.wav'
    #librosa.output.write_wav("outputs/" + outname + '/' + outname + '_' + str(index) + '.wav', x, fs)
    sf.write(OUTPUT_FILENAME, x, fs)
    print(f'Spectrogram values range over [{np.amin(value)},{np.amax(value)} ]')
    plt.figure()
    plt.title('Result')
    plt.imshow(value,  origin='lower')
    plt.show()

plt.ioff()
# Out:
# out_spec lene is 1
# shape of value is (257, 504)
# TIFResi invert mag to audio
# Min/Max of spectrogram: 0.0, 4.657422065734863
# Spectrogram values range over [-0.13349956274032593,4.657422065734863 ]

# %%
print(OUTPUT_FILENAME)
display(Audio(OUTPUT_FILENAME, autoplay=True))
# Out:
# outputs/rftests/rftests_0.wav
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from sklearn.random_projection import johnson_lindenstrauss_min_dim
johnson_lindenstrauss_min_dim(n_samples=1024, eps=[0.4, 0.1, 0.01])
# Out:
# array([   472,   5941, 558239])

# %%
from scipy.stats import ortho_group

x = ortho_group.rvs(N_FILTERS)[:N_FILTERS//2]

# %%
np.dot(x[20], x[31])
# Out:
# -1.0928757898653885e-16

# %%
np.dot(x[0], x[1])
# Out:
# -2.2551405187698492e-17

# %%
RFM.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-129-b9e999f87628> in <module>
# ----> 1 RFM.shape
#
# AttributeError: 'dict' object has no attribute 'shape'

# %%
x.shape
