# %% [markdown]
# Audio Neural Style Transfer with Pytorch
# ============================
# This is an implementation of neural style transfer using the alogrithm developed in
# [A Neural Algorithm of Artistic Style](https://arxiv.org/abs/1508.06576) by Leon A. Gatys, Alexander S. Ecker and Matthias Bethge.
#
# However instead of learning style from images we use the spectrogram in place to carry out the procedure on audio.
#
# General implementation is based off the [Pytorch tutorial on Neural Transfer](http://pytorch.org/tutorials/advanced/neural_style_tutorial.html) by Alexis Jacq. Also inspired by [Audio texture synthesis](https://github.com/DmitryUlyanov/neural-style-audio-torch) by Dmitry Ulyanov.

# %%
# %matplotlib inline
from __future__ import print_function
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim
import numpy as np

import librosa
from IPython.display import Audio, display
from PIL import Image
import matplotlib.pyplot as plt
import scipy.stats as stats

import torchvision.transforms as transforms
import torchvision.models as models
from torch.nn.modules.module import _addindent

import copy
import os
import math

#for random feature projection
from scipy.stats import ortho_group


import soundfile as sf
from matplotlib.pyplot import figure

# %%
def log_scale(img):
    img = np.log1p(img)
    return img

def inv_log(img):
    img = np.exp(img) - 1.
    return img

# %% [markdown]
# <div style="background-color: honeydew">
# <h2> Session Parameters </h2>
# </div>

# %%
# True uses PGHI (Truncated Gaussian window, log mag, PGHI reconstruction)
# False uses Log Mag spectrum and Griffin Lim reconstruction
tifresi=False

#STYLE_FILENAME = "inputs/lemons.wav" #input filename
#STYLE_FILENAME = "inputs/gansounds/pops4secs.wav" #input filename
#STYLE_FILENAME = "inputs/gansounds/hubub.10secs.wav" #input filename

#STYLE_FILENAME = "inputs/fm.wav" #input filename
#STYLE_FILENAME = "inputs/peepers.wav" #input filename
STYLE_FILENAME = "inputs/tokwotal.wav" #input filename
STYLE_FILENAME = "inputs/mcdermott/Tapping 1-2.wav" #input filename

# You can have your output length be anything! 
SYNTHETIC_LENGTH_FACTOR = 4 # duration of generated relative to target texture

#Go up to 20000 for high quality if you are on a GPU
num_steps=100 #00 #70

####################################################################################################
#Gram matrix dot product multiplies: RFMSTACK*(feature_size/RFMSALEFACTOR)^2
RANDOM_PROJECTION= "Gaussian" # "None", "Gaussian", "Sparse"   (n=None means no random projection at all)
RFMSCALEFACTOR=16   #RM project to size relative to feature dimension
RFMSTACK=32         # how many different RMs to stack
####################################################################################################

#MS Number of separate CNNs operating on input
numStreams=6
learning_Rate= 1 #0.1 #.1  # must be smaller for more streams (if numStream=1, then learning_Rate can be 1)

# %%
display(Audio(STYLE_FILENAME))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <div style="background-color: honeydew">
# <h2> FFT and CNN parameters  </h2>
# (probably don't need to change)
# </div>

# %%
# set filenames
outname = 'rftests' #output dir
runs = 1 # no. of separate outputs (to test consistency), 1 if only want single output

#librosa audio params
N_FFT = 512 
K_HOP = 128 

# architecture
"""use a custom convolutional network randomly initialized""" 
use01scale = False #set to true if want to scale img to [0,1] prior to training. Recommended if using VGG19
boundopt = False #whether to regularize the input within [lower,upper]. Recommended if using VGG19
whichChannel = "freq" #2d=2d conv, 1d options:freq=freq bins as channels, time= time bins as channels 
N_FILTERS = 512# 4096 #no. of filters in 1st conv layer
# hor_filter = 5 #width of conv filter, for 2d also the height of (square) kernel
possible_kernels = [2,4,8,16,64,128,256,512,1024,2048]
# possible_kernels = [2,4,8,16,32,64,128,256,512,1024,2048]
# possible_kernels = [5,5,5,5,5,5]
hor_filters = [0]*numStreams
for j in range(numStreams):
    hor_filters[j]=possible_kernels[j]

# %% [markdown]
# <div style="background-color: honeydew">
# <h4> TFResi params  </h4>
# (probably don't need to change)
# </div>

# %% [markdown]
# [Link to tfresi code.](https://github.com/andimarafioti/tifresi)

# %%
from tifresi.hparams import HParams
from tifresi.stft import GaussTruncTF

# from tifresi.transforms import log_spectrogram
# from tifresi.transforms import inv_log_spectrogram
#NOTE: Not using Marifioties 10 log_10 transform. Instead use natural log.
# This makes a HUGE difference !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
log_spectrogram=log_scale
inv_log_spectrogram=inv_log

stft_channels = HParams.stft_channels = N_FFT 
hop_size =  HParams.hop_size  = K_HOP
HParams.sr=16000 

# empirically set: - too small, get low-res ringing; too high, get distortion
tfresiMagSpectScale=1 # Takes the [0,1] mag spectrogram and maps it to [0, tfresiMagSpectScale]

# For faster processin, a truncated window can be used instead
stft_system = GaussTruncTF(hop_size=hop_size, stft_channels=stft_channels)

# %% [markdown]
# <div style="background-color: honeydew">
# <h4> Plumbing  </h4>
# </div>

# %%
use_cuda = torch.cuda.is_available() #use GPU if available
print('GPU available =',use_cuda)
dtype = torch.cuda.FloatTensor if use_cuda else torch.FloatTensor
# Out:
# GPU available = True

# %%
def read_audio_spectum(filename, tifresi=True):
    #x, fs = librosa.load(filename) #x=audiodata, fs=samplerate
    x, fs  = sf.read(filename)
    print(f'input file sample rate = {fs}')
#     x=np.append(x, np.zeros(stft_channels-np.mod(len(x), stft_channels)))
    N_SAMPLES = len(x)
#     x=x+np.random.normal(scale=.0001, size=N_SAMPLES)
    print(f'np.mod(len(x), stft_channels) = {np.mod(len(x), stft_channels)}')
    print(f' number of hops is {len(x)//hop_size}')
    
    if tifresi :
        print(f'In read audio, doing tifresi spectrogram')
#         R=tfresiMagSpectScale*stft_system.spectrogram(x)
        R=stft_system.spectrogram(x)
    else :
        print(f'In read audio, doing librosa spectrogram')
        R = np.abs(librosa.stft(x, n_fft=N_FFT, hop_length=K_HOP, win_length=N_FFT,  center=False))    
        
    print(f'R range is  [{np.amin(R)}, {np.amax(R)}')
    print(f'K_HOP - {K_HOP} and N_FFT is {N_FFT}')
    print(f'R shape is {R.shape}')
    return R, fs


def findMinMax(img):
    return int(math.floor(np.amin(img))),int(math.ceil(np.amax(img)))

def img_scale(img,datasetMin,datasetMax,scaleMin,scaleMax):
    """scales input numpy array from [datasetMin,datasetMax] -> [scaleMin,scaleMax]"""    
    shift = (scaleMax-scaleMin) / (datasetMax-datasetMin)
    scaled_values = shift * (img-datasetMin) + scaleMin
    print("img_scale: Using [{0},{1}] -> [{2},{3}] for scale conversion".format(datasetMin,datasetMax,scaleMin,scaleMax))
    return scaled_values

def img_invscale(img,datasetMin,datasetMax,scaleMin,scaleMax):
    """scales input numpy array from [scaleMin,scaleMax] -> [datasetMin,datasetMax]"""
    shift = (datasetMax-datasetMin) / (scaleMax-scaleMin)
    scaled_values = shift * (img-scaleMin) + datasetMin
    print("img_invscale: Using [{0},{1}] -> [{2},{3}] for inverse scale conversion".format(scaleMin,scaleMax,datasetMin,datasetMax))
    return scaled_values
    
#if 0
    # use below functions to use librosa db scale, normalized to [0,1]
    # note that this scaling does not work well for style transfer
    def db_scale(img,scale=80):
        img = librosa.amplitude_to_db(img)
        shift = float(np.amax(img))
        img = img - shift #put max at 0
        img = img/scale #scale from [-80,0] to [-1,0]
        img = img + 1. #shift to [0,1]
        img = np.maximum(img, 0) #clip anything below 0
        return img, shift

    def inv_db(img,shift,scale=80):
        img = img - 1. #shift from [0,1] to [-1,0]
        img = img * scale #[-1,0] -> [-80,0]
        img = img + shift
        img = librosa.db_to_amplitude(img)    
        return img

# %% [markdown]
# <div style="background-color: #AAFFAA">
# <h4> Prepare input and inspect.  </h4>
# </div>

# %%
R, fs = read_audio_spectum(STYLE_FILENAME, tifresi)
print(f"raw spectrogram R range before log and scaling: [{np.amin(R)},{np.amax(R)}] ")
# Out:
# input file sample rate = 16000
# np.mod(len(x), stft_channels) = 384
#  number of hops is 875
# In read audio, doing librosa spectrogram
# R range is  [1.4699799174145347e-06, 8.223469514339232
# K_HOP - 128 and N_FFT is 512
# R shape is (257, 872)
# raw spectrogram R range before log and scaling: [1.4699799174145347e-06,8.223469514339232]

# %%
if tifresi :
    print('TIFResi: log_spectrogram')
    a_style = log_spectrogram(R)
else :
    print('HUZ: log_scase')
    a_style = log_scale(R)
    
print(f"    LOG    range before scaling: [{np.amin(a_style)},{np.amax(a_style)}]",)
print(f'shape of a_style is {a_style.shape}')
# Out:
# HUZ: log_scase
#     LOG    range before scaling: [1.4699788369951148e-06,2.2217512698579274]
# shape of a_style is (257, 872)

# %%
if use01scale == True:
    a_min,a_max = findMinMax(a_style)
    a_style = img_scale(a_style,a_min,a_max,0,1)

# %%
"""we plot out the STFT magnitude range and the spectrogram do get a feel of the data"""
#plt.ion()
fig = plt.figure()
plt.title('Histogram of log Style Spectrogram vals')
ax = fig.add_subplot(111)
#n,b,_ = ax.hist(a_style.flatten(),bins='auto')
n,b,_ = ax.hist(a_style.flatten(),bins=100)
#ax.set_yticklabels([])
#ax.set_xticks([])
maxbin = np.argmax(n)
plt.show()
print("Max bin:",b[maxbin])

plt.figure(figsize=(10, 5))
plt.title('Style spectrogram')
plt.imshow(a_style, origin='lower')
print("Style spectrogram range after scaling:",np.amin(a_style),np.amax(a_style))
print("mean and std = ",np.mean(a_style),np.std(a_style))
temp_a_style=a_style # for reality check in next cell
# Out:
# Max bin: 1.4699788369951148e-06
# Style spectrogram range after scaling: 1.4699788369951148e-06 2.2217512698579274
# mean and std =  0.06148377570463736 0.19387057244724643

# %%
if 0 : #RUN PGHI ON THE ORIGINAL INPUT DATA SPECTROGRAM  - ASSUMING TFRESI for the little experiment in this cell
    # now invert it, just like we will do with the GAN-generated images

    #SPECTOFFSET
    SPECTOFFSET=0 #.25

    lspect=a_style
    print(f' shape of lspect is {lspect.shape}')
    print(use01scale)
    
    #ASSUMING TIFRES
    print('TIFResi: inv_log_spectrogram')
    if use01scale == True:
#         foo = img_invscale(lspect,a_min,a_max,0,1)
        out_spec = inv_log_spectrogram(lspect+ SPECTOFFSET) 
#         print(f'   RESCALED: Min/Max of outputs:  {np.amin(out_spec)},{np.amax(out_spec)}') # check values make sense

    else:
        out_spec =inv_log_spectrogram(lspect+SPECTOFFSET) 
#         print(f'   inv_log_spectrogram: Min/Max of outputs:  {np.amin(out_spec)},{np.amax(out_spec)}') # check values make sense

    print(f' shape of out_spec is {out_spec.shape}')
#     bar = np.clip(out_spec, 0,None)
#     print(f' shape of bar is {bar.shape}')

#     print(f'Min/Max of spectrogram: {np.amin(bar)}, {np.amax(bar)}') # check values make sense
    x = stft_system.invert_spectrogram(out_spec) 

    display(Audio(x, rate=16000, autoplay=True))

# %%
N_SAMPLES = a_style.shape[1] #time bins
N_FREQ = a_style.shape[0] #freq bins

a_style = np.ascontiguousarray(a_style[None,None,:,:]) #[batch,channels,freq,samples]
if whichChannel == "2d":
    a_style = torch.from_numpy(a_style) #pytorch:[batch,channels(1),height(freq),width(samples)]
elif whichChannel == "freq":
    a_style = torch.from_numpy(a_style).permute(0,2,1,3) #pytorch:[batch,channels(freq),height(1),width(samples)]
elif whichChannel == "time":
    a_style = torch.from_numpy(a_style).permute(0,3,1,2) #pytorch:[batch,channels(samples),height(1),width(freq)]

style_img = Variable(a_style).type(dtype) #convert to pytorch variable
print("Using whichChannel ==",whichChannel," Input shape:",style_img.data.shape) #check shape is correct
# Out:
# Using whichChannel == freq  Input shape: torch.Size([1, 257, 1, 872])

# %%
def imshow(tensor, n_freqs, n_samples, channels=1, title=None, origin='lower'):
    """ transforms pytorch tensor to numpy array and plots it out """
    
    image = tensor.clone().cpu()  # we clone the tensor to not do changes on it
    if whichChannel == "2d":
        image = image
    if whichChannel == "freq":
        image = image.permute(0,2,1,3).contiguous() # get the dimensions in proper order
    elif whichChannel == "time":
        image = image.permute(0,2,3,1).contiguous() # get the dimensions in proper order
    image = image.view(n_freqs, n_samples)  # remove the fake batch dimension
    
    image = image.numpy() #convert pytorch tensor to numpy array
    print(image.shape) #check shape
    print("Output range:",np.amin(image),np.amax(image))
    print("mean and sigma:",np.mean(image),np.std(image))
    
    
    plt.imshow(image, origin=origin)
    if title is not None:
        plt.title(title)
    plt.pause(0.001) # pause a bit so that plots are updated
    return image #return numpy array

"Just to check we can get back the numpy array with the correct shape"
plt.figure(figsize=(10, 5))
plt.figure()
_=imshow(style_img.data, N_FREQ, N_SAMPLES, title='Style Spectrogram', origin='lower')

#plt.figure()
#imshow(content_img.data, title='Content Image')
# Out:
# (257, 872)
# Output range: 1.4699789e-06 2.2217512
# mean and sigma: 0.061483778 0.19387057

# %% [markdown]
# <div style="background-color: #FF4488">
# <h4> BeginNetwork   </h4>
# </div>

# %% [markdown]
# <div style="background-color: #AAFFAA">
# <h4> Create network   </h4>
# </div>

# %%
"Here we create the custom network"
import collections as c

if whichChannel == "2d":
    IN_CHANNELS = 1
elif whichChannel == "freq":
    IN_CHANNELS = N_FREQ
elif whichChannel == "time":
    IN_CHANNELS = N_SAMPLES
    

# custom weights initialization
def weights_init(m,hor_filter):
    std = np.sqrt(2) * np.sqrt(2.0 / ((N_FREQ + N_FILTERS) * hor_filter))
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
#         torch.nn.init.xavier_uniform_(m.weight)
#         m.bias.data.fill_(0.01)
        m.weight.data.normal_(0.0, std)

class style_net(nn.Module):
    """Here create the network you want to use by adding/removing layers in nn.Sequential"""
    def __init__(self,hor_filter):
        super(style_net, self).__init__()
#         self.hor_filter=hor_filter
        self.layers = nn.Sequential(c.OrderedDict([
                            ('conv1',nn.Conv2d(IN_CHANNELS,N_FILTERS,kernel_size=(1,hor_filter),bias=False)),
                            ('relu1',nn.ReLU())#,
#                             ('max1', nn.MaxPool2d(kernel_size=(1,2))),
            
#                             ('conv2',nn.Conv2d(N_FILTERS,N_FILTERS//2,kernel_size=(1,hor_filter),bias=False)),
#                             ('relu2',nn.ReLU()),
#                             ('max2', nn.MaxPool2d(kernel_size=(1,2))),
            
#                             ('conv3',nn.Conv2d(N_FILTERS//2,N_FILTERS//4,kernel_size=(1,hor_filter),bias=False)),
#                             ('relu3',nn.ReLU())
        ]))

                            #('relu2',nn.ReLU()),
                            #('max2', nn.MaxPool2d(kernel_size=(1,2))),


                            #('conv3',nn.Conv2d(N_FILTERS//2,N_FILTERS//2,kernel_size=(1,hor_filter),bias=False)),
                            #('relu3',nn.ReLU()),
                            #('max3', nn.MaxPool2d(kernel_size=(1,2))),

                            #('conv4',nn.Conv2d(N_FILTERS//2,N_FILTERS//4,kernel_size=(1,hor_filter),bias=False)),
                            #('relu4',nn.ReLU()),
                            #('max4', nn.MaxPool2d(kernel_size=(1,2))),


                            #('conv5',nn.Conv2d(N_FILTERS//4,N_FILTERS//4,kernel_size=(1,hor_filter),bias=False)),
                            #('relu5',nn.ReLU()),
                            #('max5', nn.MaxPool2d(kernel_size=(1,2))),


                            #('conv6',nn.Conv2d(N_FILTERS//4,N_FILTERS//8,kernel_size=(1,hor_filter),bias=False)),
                            #('relu6',nn.ReLU())]))

    def forward(self,input):
        out = self.layers(input)
        return out
    
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~    
cnnlist=[] 
#MS create a separate CNN for each stream
for j in range(numStreams) :
    cnn = style_net(hor_filters[j])
    cnn.apply(lambda x, f=hor_filters[j]: weights_init(x,f))
    for param in cnn.parameters():
        param.requires_grad = False
    print(list(cnn.layers))

    # move it to the GPU if possible:
    if use_cuda:
        cnn = cnn.cuda()
    
    cnnlist.append(cnn)

# Add the style/content loss 'layer' after the specified layer:
content_layers_default = [] #ignore for now
# style_layers_default = ['relu_1']
style_layers_default = ['relu_1']
# Out:
# [Conv2d(257, 512, kernel_size=(1, 2), stride=(1, 1), bias=False), ReLU()]
# [Conv2d(257, 512, kernel_size=(1, 4), stride=(1, 1), bias=False), ReLU()]
# [Conv2d(257, 512, kernel_size=(1, 8), stride=(1, 1), bias=False), ReLU()]
# [Conv2d(257, 512, kernel_size=(1, 16), stride=(1, 1), bias=False), ReLU()]
# [Conv2d(257, 512, kernel_size=(1, 64), stride=(1, 1), bias=False), ReLU()]
# [Conv2d(257, 512, kernel_size=(1, 128), stride=(1, 1), bias=False), ReLU()]

# %% [markdown]
# Content loss
# ~~~~~~~~~~~~
#
# The content loss is a function that takes as input the feature maps
# $F_{XL}$ at a layer $L$ in a network fed by $X$ and
# return the weigthed content distance $w_{CL}.D_C^L(X,C)$ between
# this image and the content image. Hence, the weight $w_{CL}$ and
# the target content $F_{CL}$ are parameters of the function. We
# implement this function as a torch module with a constructor that takes
# these parameters as input. The distance $\|F_{XL} - F_{YL}\|^2$ is
# the Mean Square Error between the two sets of feature maps, that can be
# computed using a criterion ``nn.MSELoss`` stated as a third parameter.
#
# We will add our content losses at each desired layer as additive modules
# of the neural network. That way, each time we will feed the network with
# an input image $X$, all the content losses will be computed at the
# desired layers and, thanks to autograd, all the gradients will be
# computed. For that, we just need to make the ``forward`` method of our
# module returning the input: the module becomes a ''transparent layer''
# of the neural network. The computed loss is saved as a parameter of the
# module.
#
# Finally, we define a fake ``backward`` method, that just call the
# backward method of ``nn.MSELoss`` in order to reconstruct the gradient.
# This method returns the computed loss: this will be useful when running
# the gradient descent in order to display the evolution of style and
# content losses.

# %%
class ContentLoss(nn.Module):
    """Since doing texture only we ignore this for now"""

    def __init__(self, target, weight): #weight here is the epsilon tuning (how much content vs style)
        super(ContentLoss, self).__init__()
        # we 'detach' the target content from the tree used
        self.target = target.detach() * weight
        # to dynamically compute the gradient: this is a stated value,
        # not a variable. Otherwise the forward method of the criterion
        # will throw an error.
        self.weight = weight
        self.criterion = nn.MSELoss()

    def forward(self, input):
        self.loss = self.criterion(input * self.weight, self.target)
        self.output = input
        return self.output

    def backward(self, retain_variables=True):
        self.loss.backward(retain_variables=retain_variables)
        return self.loss

# %% [markdown]
# .. Note::
#    **Important detail**: this module, although it is named ``ContentLoss``,
#    is not a true PyTorch Loss function. If you want to define your content
#    loss as a PyTorch Loss, you have to create a PyTorch autograd Function
#    and to recompute/implement the gradient by the hand in the ``backward``
#    method.
#
# Style loss
# ~~~~~~~~~~
#
# For the style loss, we need first to define a module that compute the
# gram produce $G_{XL}$ given the feature maps $F_{XL}$ of the
# neural network fed by $X$, at layer $L$. Let
# $\hat{F}_{XL}$ be the re-shaped version of $F_{XL}$ into a
# $K$\ x\ $N$ matrix, where $K$ is the number of feature
# maps at layer $L$ and $N$ the lenght of any vectorized
# feature map $F_{XL}^k$. The $k^{th}$ line of
# $\hat{F}_{XL}$ is $F_{XL}^k$. We let you check that
# $\hat{F}_{XL} \cdot \hat{F}_{XL}^T = G_{XL}$. Given that, it
# becomes easy to implement our module:

# %%
# create random feature projection matrix
RFM={}

# This is the "sparse" Achlioptas matrix
if RANDOM_PROJECTION=="Sparse" : 
    RFM[1024]=torch.from_numpy(np.random.choice(np.sqrt(3)*np.array([1., 0., -1.]), (1024,int(1024/RFMSCALEFACTOR)), p=[1./6.,2./3., 1./6.])).type(dtype)
    RFM[512]=torch.from_numpy(np.random.choice(np.sqrt(3)*np.array([1., 0., -1.]), (512,int(512/RFMSCALEFACTOR)), p=[1./6.,2./3., 1./6.])).type(dtype)
    RFM[256]=torch.from_numpy(np.random.choice(np.sqrt(3)*np.array([1., 0., -1.]), (256,int(256/RFMSCALEFACTOR)), p=[1./6.,2./3., 1./6.])).type(dtype)
    RFM[128]=torch.from_numpy(np.random.choice(np.sqrt(3)*np.array([1., 0., -1.]), (128,int(128/RFMSCALEFACTOR)), p=[1./6.,2./3., 1./6.])).type(dtype)

#Full orthonormal gaussian 
if RANDOM_PROJECTION=="Gaussian" : 
    RFM[1024]=(torch.from_numpy(ortho_group.rvs(1024)[:int(1024/RFMSCALEFACTOR)]).type(dtype)).unsqueeze(0)
    RFM[512]= (torch.from_numpy(ortho_group.rvs(512)[: int(512/RFMSCALEFACTOR)]).type(dtype)).unsqueeze(0)
    RFM[256]= (torch.from_numpy(ortho_group.rvs(256)[: int(256/RFMSCALEFACTOR)]).type(dtype)).unsqueeze(0)
    RFM[128]= (torch.from_numpy(ortho_group.rvs(128)[: int(128/RFMSCALEFACTOR)]).type(dtype)).unsqueeze(0)
    for rm in range(1, RFMSTACK) : 
        #RFM[1024]= torch.cat( (RFM[1024], (torch.from_numpy(ortho_group.rvs(1024)[:int(1024/RFMSCALEFACTOR)]).type(dtype)).unsqueeze(0)), dim=0)
        RFM[512]=torch.cat( (RFM[512],    (torch.from_numpy(ortho_group.rvs(512)[ :int(512/RFMSCALEFACTOR)]).type(dtype)).unsqueeze(0)), dim=0)
        #RFM[256]=torch.cat( (RFM[256],    (torch.from_numpy(ortho_group.rvs(256)[ :int(256/RFMSCALEFACTOR)]).type(dtype)).unsqueeze(0)), dim=0)
        #RFM[128]=torch.cat( (RFM[128],    (torch.from_numpy(ortho_group.rvs(128)[ :int(128/RFMSCALEFACTOR)]).type(dtype)).unsqueeze(0)), dim=0)

# %%
class GramMatrix(nn.Module):

    def forward(self, input):
        a, b, c, d = input.size() #a=batch size(=1)
                                  #b=number of feature maps
                                  #(c,d)=dimensions of a feat. map (N=c*d) -> for 1D conv c=1
        #features = input.view(a * b, c * d)  # resise F_XL into \hat F_XL
        features = input.view(b, a * c * d)  # resise F_XL into \hat F_XL
        
       # features2=torch.matmul(RFM[:b//2,:b], features)
        if RANDOM_PROJECTION=="None":
            features2=features.unsqueeze(0)
        else :
            features2=torch.matmul(RFM[b], features)
        #print(f"In GramMatrix, shape of features = {np.shape(features2)}")

        #G = torch.matmul(features2, features2.t())  # compute the gram product #normalizing? - length of the features
        G = torch.matmul(features2, torch.transpose(features2, 1,2))  # compute the gram product #normalizing? - length of the features
        #print(f"In GramMatrix, shape of grammatrix = {np.shape(G)}")
        # we 'normalize' the values of the gram matrix
        # by dividing by the number of element in each feature maps.
        return G.div(a * c * d)

# %% [markdown]
# The longer is the feature maps dimension $N$, the bigger are the
# values of the gram matrix. Therefore, if we don't normalize by $N$,
# the loss computed at the first layers (before pooling layers) will have
# much more importance during the gradient descent. We dont want that,
# since the most interesting style features are in the deepest layers!
#
# Then, the style loss module is implemented exactly the same way than the
# content loss module, but we have to add the ``gramMatrix`` as a
# parameter:

# %%
#foofoo
class StyleLoss(nn.Module):

    def __init__(self, target, weight, layer): #weight here is the alpha tuning (how much content vs style)
        super(StyleLoss, self).__init__()
        self.target = target.detach() * weight
        self.weight = weight
        self.gram = GramMatrix()
        self.criterion = nn.MSELoss(size_average=False)
        #print(f'Creating StyleLoss module - this one for layer {layer} with target shape {target.shape}' )


    def forward(self, input):
        #print(f' StyleLoss.forward with input of shape {input.shape}')
        self.output = input.clone()
        self.G = self.gram(input)
        self.G.mul_(self.weight)
        self.loss = self.criterion(self.G, self.target) #/sum(sum(self.target**2)) #target=gram mat for style img, G=gram mat for current input ie. noise
        return self.output

    def backward(self, retain_variables=True):
        self.loss.backward(retain_graph=True)
        return self.loss

# %%
class OptReg(nn.Module):
    """soft bound the optimization between [lower,upper] by regularization"""
    
    def __init__(self, upper, lower, weight=1): #weight here is the alpha tuning (how much content vs style)
        super(OptReg, self).__init__()
        self.upper = Variable(torch.cuda.FloatTensor([upper]))
        self.lower = Variable(torch.cuda.FloatTensor([lower]))
        self.weight = weight

    def forward(self, input):
        #self.output = input.clone()
        self.zeros = Variable(torch.zeros(input.size()).type(dtype))
                              
        self.over = torch.max(input-self.upper,self.zeros)
        self.under = torch.max(self.lower-input,self.zeros)
        self.total= self.over + self.under
        self.l2total = self.weight * self.total.norm(2)
        #print(f'OptReg l2total = {self.l2total}')
        return self.l2total

# %% [raw]
# a = Variable(torch.cuda.FloatTensor([[2,0,2],[1,0,1]]))
# b = Variable(torch.cuda.FloatTensor([[5,0,5],[-1,0,-1]]))
# c = Variable(torch.cuda.FloatTensor([1]))
# d = c-a
# print(d)
# e = torch.max(d,b)
# f = e+e
# print(f)
# g = f.norm(2)
# print(g)
#
# def optbound_regularizer_old(img,upper,lower):
#     """soft bound the optimization between [lower,upper] by regularization"""
#     #print(torch.max(img),torch.min(img))
#     imgn = Variable(img)
#     over = torch.max(imgn.data-upper,torch.zeros(img.size()).type(dtype))
#     #print("over",over)
#     under = torch.max(lower-imgn.data,torch.zeros(img.size()).type(dtype))
#     #print("under",under)
#     out = over + under
#     #print("out",out)
#     out = out.norm(2)
#     #print("norm",out)
#     #l2_reg = torch.cuda.FloatTensor([out])
#     l2_reg = Variable(torch.cuda.FloatTensor([out]), requires_grad=True)
#
#     return l2_reg
#
# def optbound_regularizer(img,upper,lower,reg_weight):
#     """soft bound the optimization between [lower,upper] by regularization"""
#     #print(torch.max(img),torch.min(img))
#     zero_var = Variable(torch.zeros(img.size()).type(dtype))
#     over = Variable(torch.max(img-upper,torch.zeros(img.size()).type(dtype)), requires_grad=True)
#     crit_over = nn.MSELoss(size_average=False)
#     over_loss = crit_over(over,zero_var)
#     #print("over",over)
#     under = Variable(torch.max(lower-img,torch.zeros(img.size()).type(dtype)), requires_grad=True)
#     crit_under = nn.MSELoss(size_average=False)
#     under_loss = crit_under(under,zero_var)
#     #print("under",under)
#     out = over_loss + under_loss
#     #print("out",out)
#     #out = out.norm(2)
#     #print("norm",out)
#     #l2_reg = torch.cuda.FloatTensor([out])
#     #l2_reg = Variable(torch.cuda.FloatTensor([out]), requires_grad=True)
#     out = reg_weight * out
#     #optbound = out.backward(retain_graph=True)
#
#     return out #optbound

# %% [markdown]
# Load the neural network
# ~~~~~~~~~~~~~~~~~~~~~~~
#
# Now, we have to import a pre-trained neural network. As in the paper, we
# are going to use a pretrained VGG network with 19 layers (VGG19).
#
# PyTorch's implementation of VGG is a module divided in two child
# ``Sequential`` modules: ``features`` (containing convolution and pooling
# layers) and ``classifier`` (containing fully connected layers). We are
# just interested by ``features``:

# %% [markdown]
# A ``Sequential`` module contains an ordered list of child modules. For
# instance, ``vgg19.features`` contains a sequence (Conv2d, ReLU,
# Maxpool2d, Conv2d, ReLU...) aligned in the right order of depth. As we
# said in *Content loss* section, we wand to add our style and content
# loss modules as additive 'transparent' layers in our network, at desired
# depths. For that, we construct a new ``Sequential`` module, in wich we
# are going to add modules from ``vgg19`` and our loss modules in the
# right order:

# %%
#rebuild network with the layers we want
def get_style_model_and_losses(cnn, style_img, content_img=None,
                               style_weight=1, content_weight=0,
                               content_layers=content_layers_default,
                               style_layers=style_layers_default, style_img2=None):
    cnn = copy.deepcopy(cnn)

    # just in order to have an iterable access to or list of content/syle losses
    content_losses = []
    style_losses = []
    
    model = nn.Sequential()
    layer_list = list(cnn.layers)
    
    gram = GramMatrix()  # we need a gram module in order to compute style targets

    # move these modules to the GPU if possible:
    if use_cuda:
        model = model.cuda()
        gram = gram.cuda()

    #here we rebuild the network adding the in content and style loss "layers"   
    i = 1  
    for layer in layer_list:
        
        if isinstance(layer, nn.Conv2d): #if layer in vgg19 belong to class nn.Conv2d
            name = "conv_" + str(i)
            model.add_module(name, layer) #add that layer to our sequential model
            
            if content_img != None:
                if name in content_layers: #at the right depth add the content loss "layer"
                    # add content loss:
                    target = model(content_img).clone()
                    content_loss = ContentLoss(target, content_weight)
                    model.add_module("content_loss_" + str(i), content_loss)
                    content_losses.append(content_loss)

            if name in style_layers: #at the right depth add the content loss "layer"
                # add style loss:
                target_feature = model(style_img).clone()
                target_feature_gram = gram(target_feature)
                style_loss = StyleLoss(target_feature_gram, style_weight, name)
                model.add_module("style_loss_" + str(i), style_loss)
                style_losses.append(style_loss)

        if isinstance(layer, nn.ReLU): #do the same for ReLUs
            name = "relu_" + str(i)
            model.add_module(name, layer)
            
            if content_img != None:
                if name in content_layers:
                    # add content loss:
                    target = model(content_img).clone()
                    content_loss = ContentLoss(target, content_weight)
                    model.add_module("content_loss_" + str(i), content_loss)
                    content_losses.append(content_loss)

            if name in style_layers:
                # add style loss:
                target_feature = model(style_img).clone()
                target_feature_gram = gram(target_feature)
                style_loss = StyleLoss(target_feature_gram, style_weight, name)
                model.add_module("style_loss_" + str(i), style_loss)
                style_losses.append(style_loss) 
                
            i += 1

        if isinstance(layer, nn.MaxPool2d): #do the same for maxpool
            name = "pool_" + str(i)
            model.add_module(name, layer)
            
            if name in style_layers:
                # add style loss:
                target_feature = model(style_img).clone()
                target_feature_gram = gram(target_feature)
                style_loss = StyleLoss(target_feature_gram, style_weight, name)
                model.add_module("style_loss_" + str(i), style_loss)
                style_losses.append(style_loss)
            
            #avgpool = nn.AvgPool2d(kernel_size=(1,2),
            #                stride=layer.stride, padding = layer.padding)
            #model.add_module(name, avgpool)  # *** can also replace certain layers if we want eg. maxpool -> avgpool


    #for param in model.parameters():
    #    param.requires_grad = False
    return model, style_losses, content_losses

# %% [markdown]
# .. Note::
#    In the paper they recommend to change max pooling layers into
#    average pooling. With AlexNet, that is a small network compared to VGG19
#    used in the paper, we are not going to see any difference of quality in
#    the result. However, you can use these lines instead if you want to do
#    this substitution:
#
#    ::
#
#        # avgpool = nn.AvgPool2d(kernel_size=layer.kernel_size,
#        #                         stride=layer.stride, padding = layer.padding)
#        # model.add_module(name,avgpool)

# %% [markdown]
# Input image
# ~~~~~~~~~~~
#
# Again, in order to simplify the code, we take an image of the same
# dimensions than content and style images. This image can be a white
# noise, or it can also be a copy of the content-image.

# %% [markdown]
# <div style="background-color: #AAFFAA">
# <h4> Prepare noise as input  </h4>
# </div>

# %%
"""image to input in generative network"""
#input_img = content_img.clone()

# if you want to use a white noise instead uncomment the below line:
#input_img = Variable(torch.randn(content_img.data.size())).type(dtype)

def in_img(n_freqs, nsamples):
    """initialize (runs) number of unique random noise input images"""  
    input_imgs = []
    #rand_tensor = torch.randn(1,n_freqs,1,nsamples)*1e-3
#     lower,upper,mu,sigma = 1e-3,1,.5,1e-1
#     lower,upper,mu,sigma = -50,0,-45,7
    lower,upper,mu,sigma = 1e-9,0.7,0.001,0.01

    dist = stats.truncnorm((lower-mu)/sigma,(upper-mu)/sigma,loc=mu,scale=sigma)
    
    i = 0
    while i < runs:
         #[batch,channels,h,w]
        if whichChannel == "2d":
            samples = dist.rvs([1,1,n_freqs,nsamples])
            input_imgs.append(Variable(torch.from_numpy(samples)).type(dtype))
            #input_imgs.append(Variable(torch.rand(1,1,n_freqs,nsamples)*1e-3).type(dtype))
            #input_imgs.append(Variable(torch.randn(1,1,n_freqs,nsamples)*1e-3).type(dtype))
        if whichChannel == "freq":
            #samples = dist.rvs([1,n_freqs,1,nsamples])
            #input_imgs.append(Variable(torch.from_numpy(samples)).type(dtype))
            #input_imgs.append(Variable(torch.rand(1,n_freqs,1,nsamples)*1e-3).type(dtype))
            input_imgs.append(Variable(mu+torch.randn(1,n_freqs,1,nsamples)*1e-2).type(dtype))
        elif whichChannel == "time":
            samples = dist.rvs([1,nsamples,1,n_freqs])
            input_imgs.append(Variable(torch.from_numpy(samples)).type(dtype))
            #input_imgs.append(Variable(torch.rand(1,nsamples,1,n_freqs)*1e-3).type(dtype))
            #input_imgs.append(Variable(torch.randn(1,nsamples,1,n_freqs)*1e-3).type(dtype))
        i +=1
    return input_imgs

input_imgs = in_img(N_FREQ, int(N_SAMPLES*SYNTHETIC_LENGTH_FACTOR))

# add the original input image to the figure:
plt.figure()
_=imshow(input_imgs[0].data, N_FREQ, int(N_SAMPLES*SYNTHETIC_LENGTH_FACTOR), title='Input Image')
# Out:
# (257, 3488)
# Output range: -0.050228212 0.048570015
# mean and sigma: 0.0010018196 0.010015814

# %% [markdown]
# Gradient descent
# ~~~~~~~~~~~~~~~~
#
# As Leon Gatys, the author of the algorithm, suggested
# `here <https://discuss.pytorch.org/t/pytorch-tutorial-for-neural-transfert-of-artistic-style/336/20?u=alexis-jacq>`__,
# we will use L-BFGS algorithm to run our gradient descent. Unlike
# training a network, we want to train the input image in order to
# minimise the content/style losses. We would like to simply create a
# PyTorch  L-BFGS optimizer, passing our image as the variable to optimize.
# But ``optim.LBFGS`` takes as first argument a list of PyTorch
# ``Variable`` that require gradient. Our input image is a ``Variable``
# but is not a leaf of the tree that requires computation of gradients. In
# order to show that this variable requires a gradient, a possibility is
# to construct a ``Parameter`` object from the input image. Then, we just
# give a list containing this ``Parameter`` to the optimizer's
# constructor:

# %%
def get_input_param_optimizer(input_img):
    # this line to show that input is a parameter that requires a gradient
    input_param = nn.Parameter(input_img.data)
    optimizer = optim.LBFGS([input_param])
    return input_param, optimizer

# %% [markdown]
# **Last step**: the loop of gradient descent. At each step, we must feed
# the network with the updated input in order to compute the new losses,
# we must run the ``backward`` methods of each loss to dynamically compute
# their gradients and perform the step of gradient descent. The optimizer
# requires as argument a "closure": a function that reevaluates the model
# and returns the loss.

# %%
def run_style_transfer(cnnlist, style_img, input_img, content_img=None, num_steps=num_steps,
                       style_weight=1, content_weight=0, reg_weight=0.01): 
    """Run the style transfer"""
    
    #MS - one model, loss accumulator, and optimizer per stream 
    modelMS=[None for j in range(numStreams)]
    style_lossesMS=[None for j in range(numStreams)] 
    content_lossesMS=[None for j in range(numStreams)]
#     optimizerMS=[None for j in range(numStreams)]

    #MS one input_param for all streams, each operating on the same data. 
    input_param = nn.Parameter(input_img.data)
    
    
    prev = input_param.data
    
    # first create the separate cnn models and losses
    for j in range(numStreams) :
        print('Building the style transfer model..')
        modelMS[j], style_lossesMS[j], content_lossesMS[j] = get_style_model_and_losses(cnnlist[j],
            style_img, content_img, style_weight, content_weight)
        #input_paramMS[j], optimizerMS[j] = get_input_param_optimizer(input_img)
        
        #input_param is the same variable passed to each separate CNN
        #MS Changed learning rate to prevent instabilities with lr=1.
#         optimizerMS[j] = optim.LBFGS([input_param], lr=learning_Rate)

        print("Input range:",torch.max(input_param.data),torch.min(input_param.data))   
        print(modelMS[j])
        print('Optimizing..')
    optimizerMS = optim.LBFGS([input_param],lr=learning_Rate)
        
    
    print(f'Created {j} MS models')
    # print(f' input_param[0] is input_param[1] ? ...... {input_paramMS[0] is input_paramMS[1]}')    # FALSE!    
    

    run = [0]
    
    if boundopt == True:
        bound = OptReg(1,0.005, reg_weight)
    

    plt.figure()
    while run[0] <= num_steps:

        run[0] += 1
        print("Current Run Number = ",run[0])
        
        #MS create the closure, and then run the optimizer for each stream in sequence
        # (the update from each stream becomes the input for the next, I think!)
        print("numStreams = ",numStreams)
        def closure():
            optimizerMS.zero_grad()
            style_score = 0
            content_score = 0
            for j in range(numStreams) :
        
            
                # correct the values of updated input image
                #if use01scale == True:
                    #input_param.data.clamp_(0, 1)

                #print("Current stream Number in closure() = ",j)
#                 optimizerMS.zero_grad()
                modelMS[j](input_param)
                

                if boundopt == True:
                    bound.zero_grad()
                    reg = bound(input_param)
                    if not torch.equal(reg.data,torch.cuda.FloatTensor([0])):
                        reg.backward()

                for sl in style_lossesMS[j]:
                    style_score += sl.backward() #call backward method to grab the loss
                #print("stylescore for run", run[0], " stream ",j ," is ",style_score)

                #for cl in content_losses:
                #    content_score += cl.backward()

                if boundopt == True:
                    total_loss = style_score + reg  #+ content_score
                else:
                    total_loss = style_score

                #run[0] += 1

                if run[0] % 10 == 0:
                    #print("reg", reg)
                    #print(torch.max(input_param.data),torch.min(input_param.data))

                    print(f"run: {run}, model[{j}]")
                    print('Style Loss : {:4f}'.format(
                        #style_score.data[0]))
                        style_score.data))
                    plt.plot(run[0],style_score.data.cpu(),'bo')
                    if boundopt == True:
                        print('Bound Loss : {:4f}'.format(
                           #reg.data[0]))
                            reg.data))
#                     print(torch.max(input_param.data),torch.min(input_param.data))
#                     print('Total Loss : {:4f}'.format(
#                         # total_loss.data[0]))
#                         total_loss.data))
#                     plt.figure()
#                     plt.imshow(input_param.data.detach().cpu().numpy().squeeze(),origin='lower')
#                     plt.title("For step %d input_param.data is "%run[0])
#                     plt.show()

            return total_loss/numStreams   #return value for closer()

            # The update to an image happens in here:
        optimizerMS.step(closure)  #optimizer.step will call closure with its closure vars; #executes 20 iterations in this one line
                
          
        # END MS loop
        
        
        
    # a last correction...
    #if use01scale == True:
        #input_param.data.clamp_(0, 1)
    plt.show()
    return input_param.data   # Can return any of the MS input_params - they all refer to the same object

# %% [markdown]
# <div style="background-color: #AAFFAA">
# <h4> Finally, run the algorithm  </h4>
# </div>

# %%
outputs = []
i = 0
while i < runs:
    
    output = run_style_transfer(cnnlist, style_img, input_imgs[i])


    plt.figure().set_size_inches(20, 20)
    out = imshow(output, N_FREQ, int(N_SAMPLES*SYNTHETIC_LENGTH_FACTOR),title='Output Image')
    outputs.append(out)
    i += 1

# sphinx_gallery_thumbnail_number = 4
#figure(figsize=(8, 6), dpi=80)
plt.show()
# Out:
# Building the style transfer model..
# /opt/conda/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Input range: tensor(0.0486, device='cuda:0') tensor(-0.0502, device='cuda:0')
# Sequential(
#   (conv_1): Conv2d(257, 512, kernel_size=(1, 2), stride=(1, 1), bias=False)
#   (relu_1): ReLU()
#   (style_loss_1): StyleLoss(
#     (gram): GramMatrix()
#     (criterion): MSELoss()
#   )
# )
# Optimizing..
# Building the style transfer model..
# Input range: tensor(0.0486, device='cuda:0') tensor(-0.0502, device='cuda:0')
# Sequential(
#   (conv_1): Conv2d(257, 512, kernel_size=(1, 4), stride=(1, 1), bias=False)
#   (relu_1): ReLU()
#   (style_loss_1): StyleLoss(
#     (gram): GramMatrix()
#     (criterion): MSELoss()
#   )
# )
# Optimizing..
# Building the style transfer model..
# Input range: tensor(0.0486, device='cuda:0') tensor(-0.0502, device='cuda:0')
# Sequential(
#   (conv_1): Conv2d(257, 512, kernel_size=(1, 8), stride=(1, 1), bias=False)
#   (relu_1): ReLU()
#   (style_loss_1): StyleLoss(
#     (gram): GramMatrix()
#     (criterion): MSELoss()
#   )
# )
# Optimizing..
# Building the style transfer model..
# Input range: tensor(0.0486, device='cuda:0') tensor(-0.0502, device='cuda:0')
# Sequential(
#   (conv_1): Conv2d(257, 512, kernel_size=(1, 16), stride=(1, 1), bias=False)
#   (relu_1): ReLU()
#   (style_loss_1): StyleLoss(
#     (gram): GramMatrix()
#     (criterion): MSELoss()
#   )
# )
# Optimizing..
# Building the style transfer model..
# Input range: tensor(0.0486, device='cuda:0') tensor(-0.0502, device='cuda:0')
# Sequential(
#   (conv_1): Conv2d(257, 512, kernel_size=(1, 64), stride=(1, 1), bias=False)
#   (relu_1): ReLU()
#   (style_loss_1): StyleLoss(
#     (gram): GramMatrix()
#     (criterion): MSELoss()
#   )
# )
# Optimizing..
# Building the style transfer model..
# Input range: tensor(0.0486, device='cuda:0') tensor(-0.0502, device='cuda:0')
# Sequential(
#   (conv_1): Conv2d(257, 512, kernel_size=(1, 128), stride=(1, 1), bias=False)
#   (relu_1): ReLU()
#   (style_loss_1): StyleLoss(
#     (gram): GramMatrix()
#     (criterion): MSELoss()
#   )
# )
# Optimizing..
# Created 5 MS models
# Current Run Number =  1
# numStreams =  6
# Current Run Number =  2
# numStreams =  6
# Current Run Number =  3
# numStreams =  6
# Current Run Number =  4
# numStreams =  6
# Current Run Number =  5
# numStreams =  6
# Current Run Number =  6
# numStreams =  6
# Current Run Number =  7
# numStreams =  6
# Current Run Number =  8
# numStreams =  6
# Current Run Number =  9
# numStreams =  6
# Current Run Number =  10
# numStreams =  6
# run: [10], model[0]
# Style Loss : 15.920677
# run: [10], model[1]
# Style Loss : 29.594507
# run: [10], model[2]
# Style Loss : 38.549706
# run: [10], model[3]
# Style Loss : 45.319031
# run: [10], model[4]
# Style Loss : 51.068401
# run: [10], model[5]
# Style Loss : 55.457142
# run: [10], model[0]
# Style Loss : 15.915702
# run: [10], model[1]
# Style Loss : 29.586010
# run: [10], model[2]
# Style Loss : 38.538628
# run: [10], model[3]
# Style Loss : 45.305698
# run: [10], model[4]
# Style Loss : 51.053101
# run: [10], model[5]
# Style Loss : 55.440311
# run: [10], model[0]
# Style Loss : 15.910637
# run: [10], model[1]
# Style Loss : 29.577358
# run: [10], model[2]
# Style Loss : 38.527351
# run: [10], model[3]
# Style Loss : 45.292130
# run: [10], model[4]
# Style Loss : 51.037533
# run: [10], model[5]
# Style Loss : 55.423191
# run: [10], model[0]
# Style Loss : 15.905478
# run: [10], model[1]
# Style Loss : 29.568554
# run: [10], model[2]
# Style Loss : 38.515877
# run: [10], model[3]
# Style Loss : 45.278324
# run: [10], model[4]
# Style Loss : 51.021698
# run: [10], model[5]
# Style Loss : 55.405777
# run: [10], model[0]
# Style Loss : 15.900221
# run: [10], model[1]
# Style Loss : 29.559582
# run: [10], model[2]
# Style Loss : 38.504189
# run: [10], model[3]
# Style Loss : 45.264263
# run: [10], model[4]
# Style Loss : 51.005569
# run: [10], model[5]
# Style Loss : 55.388039
# run: [10], model[0]
# Style Loss : 15.894870
# run: [10], model[1]
# Style Loss : 29.550457
# run: [10], model[2]
# Style Loss : 38.492302
# run: [10], model[3]
# Style Loss : 45.249969
# run: [10], model[4]
# Style Loss : 50.989178
# run: [10], model[5]
# Style Loss : 55.370018
# run: [10], model[0]
# Style Loss : 15.889416
# run: [10], model[1]
# Style Loss : 29.541159
# run: [10], model[2]
# Style Loss : 38.480198
# run: [10], model[3]
# Style Loss : 45.235413
# run: [10], model[4]
# Style Loss : 50.972488
# run: [10], model[5]
# Style Loss : 55.351669
# run: [10], model[0]
# Style Loss : 15.883862
# run: [10], model[1]
# Style Loss : 29.531696
# run: [10], model[2]
# Style Loss : 38.467880
# run: [10], model[3]
# Style Loss : 45.220604
# run: [10], model[4]
# Style Loss : 50.955513
# run: [10], model[5]
# Style Loss : 55.333008
# run: [10], model[0]
# Style Loss : 15.878204
# run: [10], model[1]
# Style Loss : 29.522057
# run: [10], model[2]
# Style Loss : 38.455334
# run: [10], model[3]
# Style Loss : 45.205524
# run: [10], model[4]
# Style Loss : 50.938229
# run: [10], model[5]
# Style Loss : 55.314011
# run: [10], model[0]
# Style Loss : 15.872442
# run: [10], model[1]
# Style Loss : 29.512245
# run: [10], model[2]
# Style Loss : 38.442570
# run: [10], model[3]
# Style Loss : 45.190182
# run: [10], model[4]
# Style Loss : 50.920647
# run: [10], model[5]
# Style Loss : 55.294689
# run: [10], model[0]
# Style Loss : 15.866574
# run: [10], model[1]
# Style Loss : 29.502256
# run: [10], model[2]
# Style Loss : 38.429573
# run: [10], model[3]
# Style Loss : 45.174568
# run: [10], model[4]
# Style Loss : 50.902760
# run: [10], model[5]
# Style Loss : 55.275032
# run: [10], model[0]
# Style Loss : 15.860596
# run: [10], model[1]
# Style Loss : 29.492085
# run: [10], model[2]
# Style Loss : 38.416348
# run: [10], model[3]
# Style Loss : 45.158676
# run: [10], model[4]
# Style Loss : 50.884556
# run: [10], model[5]
# Style Loss : 55.255032
# run: [10], model[0]
# Style Loss : 15.854506
# run: [10], model[1]
# Style Loss : 29.481728
# run: [10], model[2]
# Style Loss : 38.402882
# run: [10], model[3]
# Style Loss : 45.142502
# run: [10], model[4]
# Style Loss : 50.866028
# run: [10], model[5]
# Style Loss : 55.234676
# run: [10], model[0]
# Style Loss : 15.848304
# run: [10], model[1]
# Style Loss : 29.471180
# run: [10], model[2]
# Style Loss : 38.389172
# run: [10], model[3]
# Style Loss : 45.126038
# run: [10], model[4]
# Style Loss : 50.847176
# run: [10], model[5]
# Style Loss : 55.213966
# run: [10], model[0]
# Style Loss : 15.841987
# run: [10], model[1]
# Style Loss : 29.460445
# run: [10], model[2]
# Style Loss : 38.375221
# run: [10], model[3]
# Style Loss : 45.109283
# run: [10], model[4]
# Style Loss : 50.827995
# run: [10], model[5]
# Style Loss : 55.192898
# run: [10], model[0]
# Style Loss : 15.835550
# run: [10], model[1]
# Style Loss : 29.449511
# run: [10], model[2]
# Style Loss : 38.361015
# run: [10], model[3]
# Style Loss : 45.092228
# run: [10], model[4]
# Style Loss : 50.808472
# run: [10], model[5]
# Style Loss : 55.171455
# run: [10], model[0]
# Style Loss : 15.828996
# run: [10], model[1]
# Style Loss : 29.438377
# run: [10], model[2]
# Style Loss : 38.346558
# run: [10], model[3]
# Style Loss : 45.074875
# run: [10], model[4]
# Style Loss : 50.788609
# run: [10], model[5]
# Style Loss : 55.149643
# run: [10], model[0]
# Style Loss : 15.822318
# run: [10], model[1]
# Style Loss : 29.427044
# run: [10], model[2]
# Style Loss : 38.331841
# run: [10], model[3]
# Style Loss : 45.057209
# run: [10], model[4]
# Style Loss : 50.768394
# run: [10], model[5]
# Style Loss : 55.127449
# run: [10], model[0]
# Style Loss : 15.815517
# run: [10], model[1]
# Style Loss : 29.415501
# run: [10], model[2]
# Style Loss : 38.316856
# run: [10], model[3]
# Style Loss : 45.039230
# run: [10], model[4]
# Style Loss : 50.747826
# run: [10], model[5]
# Style Loss : 55.104866
# run: [10], model[0]
# Style Loss : 15.808589
# run: [10], model[1]
# Style Loss : 29.403748
# run: [10], model[2]
# Style Loss : 38.301601
# run: [10], model[3]
# Style Loss : 45.020927
# run: [10], model[4]
# Style Loss : 50.726891
# run: [10], model[5]
# Style Loss : 55.081886
# Current Run Number =  11
# numStreams =  6
# Current Run Number =  12
# numStreams =  6
# Current Run Number =  13
# numStreams =  6
# Current Run Number =  14
# numStreams =  6
# Current Run Number =  15
# numStreams =  6
# Current Run Number =  16
# numStreams =  6
# Current Run Number =  17
# numStreams =  6
# Current Run Number =  18
# numStreams =  6
# Current Run Number =  19
# numStreams =  6
# Current Run Number =  20
# numStreams =  6
# run: [20], model[0]
# Style Loss : 9.692264
# run: [20], model[1]
# Style Loss : 19.112522
# run: [20], model[2]
# Style Loss : 25.229750
# run: [20], model[3]
# Style Loss : 29.667881
# run: [20], model[4]
# Style Loss : 33.523293
# run: [20], model[5]
# Style Loss : 36.423809
# run: [20], model[0]
# Style Loss : 9.691469
# run: [20], model[1]
# Style Loss : 19.111076
# run: [20], model[2]
# Style Loss : 25.227917
# run: [20], model[3]
# Style Loss : 29.665756
# run: [20], model[4]
# Style Loss : 33.520935
# run: [20], model[5]
# Style Loss : 36.421265
# run: [20], model[0]
# Style Loss : 9.690671
# run: [20], model[1]
# Style Loss : 19.109623
# run: [20], model[2]
# Style Loss : 25.226082
# run: [20], model[3]
# Style Loss : 29.663618
# run: [20], model[4]
# Style Loss : 33.518559
# run: [20], model[5]
# Style Loss : 36.418701
# run: [20], model[0]
# Style Loss : 9.689880
# run: [20], model[1]
# Style Loss : 19.108183
# run: [20], model[2]
# Style Loss : 25.224245
# run: [20], model[3]
# Style Loss : 29.661484
# run: [20], model[4]
# Style Loss : 33.516186
# run: [20], model[5]
# Style Loss : 36.416142
# run: [20], model[0]
# Style Loss : 9.689074
# run: [20], model[1]
# Style Loss : 19.106730
# run: [20], model[2]
# Style Loss : 25.222408
# run: [20], model[3]
# Style Loss : 29.659349
# run: [20], model[4]
# Style Loss : 33.513824
# run: [20], model[5]
# Style Loss : 36.413597
# run: [20], model[0]
# Style Loss : 9.688271
# run: [20], model[1]
# Style Loss : 19.105286
# run: [20], model[2]
# Style Loss : 25.220577
# run: [20], model[3]
# Style Loss : 29.657219
# run: [20], model[4]
# Style Loss : 33.511459
# run: [20], model[5]
# Style Loss : 36.411045
# run: [20], model[0]
# Style Loss : 9.687466
# run: [20], model[1]
# Style Loss : 19.103830
# run: [20], model[2]
# Style Loss : 25.218735
# run: [20], model[3]
# Style Loss : 29.655075
# run: [20], model[4]
# Style Loss : 33.509083
# run: [20], model[5]
# Style Loss : 36.408482
# run: [20], model[0]
# Style Loss : 9.686641
# run: [20], model[1]
# Style Loss : 19.102348
# run: [20], model[2]
# Style Loss : 25.216862
# run: [20], model[3]
# Style Loss : 29.652901
# run: [20], model[4]
# Style Loss : 33.506676
# run: [20], model[5]
# Style Loss : 36.405888
# run: [20], model[0]
# Style Loss : 9.685841
# run: [20], model[1]
# Style Loss : 19.100897
# run: [20], model[2]
# Style Loss : 25.215017
# run: [20], model[3]
# Style Loss : 29.650759
# run: [20], model[4]
# Style Loss : 33.504299
# run: [20], model[5]
# Style Loss : 36.403328
# run: [20], model[0]
# Style Loss : 9.685027
# run: [20], model[1]
# Style Loss : 19.099438
# run: [20], model[2]
# Style Loss : 25.213165
# run: [20], model[3]
# Style Loss : 29.648605
# run: [20], model[4]
# Style Loss : 33.501911
# run: [20], model[5]
# Style Loss : 36.400749
# run: [20], model[0]
# Style Loss : 9.684223
# run: [20], model[1]
# Style Loss : 19.097994
# run: [20], model[2]
# Style Loss : 25.211334
# run: [20], model[3]
# Style Loss : 29.646475
# run: [20], model[4]
# Style Loss : 33.499546
# run: [20], model[5]
# Style Loss : 36.398201
# run: [20], model[0]
# Style Loss : 9.683408
# run: [20], model[1]
# Style Loss : 19.096523
# run: [20], model[2]
# Style Loss : 25.209473
# run: [20], model[3]
# Style Loss : 29.644314
# run: [20], model[4]
# Style Loss : 33.497143
# run: [20], model[5]
# Style Loss : 36.395611
# run: [20], model[0]
# Style Loss : 9.682602
# run: [20], model[1]
# Style Loss : 19.095066
# run: [20], model[2]
# Style Loss : 25.207624
# run: [20], model[3]
# Style Loss : 29.642168
# run: [20], model[4]
# Style Loss : 33.494762
# run: [20], model[5]
# Style Loss : 36.393044
# run: [20], model[0]
# Style Loss : 9.681815
# run: [20], model[1]
# Style Loss : 19.093632
# run: [20], model[2]
# Style Loss : 25.205807
# run: [20], model[3]
# Style Loss : 29.640053
# run: [20], model[4]
# Style Loss : 33.492420
# run: [20], model[5]
# Style Loss : 36.390518
# run: [20], model[0]
# Style Loss : 9.681021
# run: [20], model[1]
# Style Loss : 19.092190
# run: [20], model[2]
# Style Loss : 25.203976
# run: [20], model[3]
# Style Loss : 29.637926
# run: [20], model[4]
# Style Loss : 33.490059
# run: [20], model[5]
# Style Loss : 36.387974
# run: [20], model[0]
# Style Loss : 9.680212
# run: [20], model[1]
# Style Loss : 19.090729
# run: [20], model[2]
# Style Loss : 25.202126
# run: [20], model[3]
# Style Loss : 29.635775
# run: [20], model[4]
# Style Loss : 33.487675
# run: [20], model[5]
# Style Loss : 36.385403
# run: [20], model[0]
# Style Loss : 9.679410
# run: [20], model[1]
# Style Loss : 19.089272
# run: [20], model[2]
# Style Loss : 25.200279
# run: [20], model[3]
# Style Loss : 29.633629
# run: [20], model[4]
# Style Loss : 33.485294
# run: [20], model[5]
# Style Loss : 36.382839
# run: [20], model[0]
# Style Loss : 9.678593
# run: [20], model[1]
# Style Loss : 19.087814
# run: [20], model[2]
# Style Loss : 25.198431
# run: [20], model[3]
# Style Loss : 29.631481
# run: [20], model[4]
# Style Loss : 33.482914
# run: [20], model[5]
# Style Loss : 36.380268
# run: [20], model[0]
# Style Loss : 9.677790
# run: [20], model[1]
# Style Loss : 19.086357
# run: [20], model[2]
# Style Loss : 25.196579
# run: [20], model[3]
# Style Loss : 29.629330
# run: [20], model[4]
# Style Loss : 33.480526
# run: [20], model[5]
# Style Loss : 36.377697
# run: [20], model[0]
# Style Loss : 9.676983
# run: [20], model[1]
# Style Loss : 19.084904
# run: [20], model[2]
# Style Loss : 25.194736
# run: [20], model[3]
# Style Loss : 29.627186
# run: [20], model[4]
# Style Loss : 33.478146
# run: [20], model[5]
# Style Loss : 36.375130
# Current Run Number =  21
# numStreams =  6
# Current Run Number =  22
# numStreams =  6
# Current Run Number =  23
# numStreams =  6
# Current Run Number =  24
# numStreams =  6
# Current Run Number =  25
# numStreams =  6
# Current Run Number =  26
# numStreams =  6
# Current Run Number =  27
# numStreams =  6
# Current Run Number =  28
# numStreams =  6
# Current Run Number =  29
# numStreams =  6
# Current Run Number =  30
# numStreams =  6
# run: [30], model[0]
# Style Loss : 9.530767
# run: [30], model[1]
# Style Loss : 18.820530
# run: [30], model[2]
# Style Loss : 24.859596
# run: [30], model[3]
# Style Loss : 29.237785
# run: [30], model[4]
# Style Loss : 33.046272
# run: [30], model[5]
# Style Loss : 35.909546
# run: [30], model[0]
# Style Loss : 9.529949
# run: [30], model[1]
# Style Loss : 18.819048
# run: [30], model[2]
# Style Loss : 24.857716
# run: [30], model[3]
# Style Loss : 29.235601
# run: [30], model[4]
# Style Loss : 33.043850
# run: [30], model[5]
# Style Loss : 35.906937
# run: [30], model[0]
# Style Loss : 9.529138
# run: [30], model[1]
# Style Loss : 18.817570
# run: [30], model[2]
# Style Loss : 24.855846
# run: [30], model[3]
# Style Loss : 29.233431
# run: [30], model[4]
# Style Loss : 33.041447
# run: [30], model[5]
# Style Loss : 35.904346
# run: [30], model[0]
# Style Loss : 9.528320
# run: [30], model[1]
# Style Loss : 18.816097
# run: [30], model[2]
# Style Loss : 24.853977
# run: [30], model[3]
# Style Loss : 29.231258
# run: [30], model[4]
# Style Loss : 33.039036
# run: [30], model[5]
# Style Loss : 35.901749
# run: [30], model[0]
# Style Loss : 9.527502
# run: [30], model[1]
# Style Loss : 18.814615
# run: [30], model[2]
# Style Loss : 24.852100
# run: [30], model[3]
# Style Loss : 29.229080
# run: [30], model[4]
# Style Loss : 33.036625
# run: [30], model[5]
# Style Loss : 35.899155
# run: [30], model[0]
# Style Loss : 9.526692
# run: [30], model[1]
# Style Loss : 18.813156
# run: [30], model[2]
# Style Loss : 24.850254
# run: [30], model[3]
# Style Loss : 29.226933
# run: [30], model[4]
# Style Loss : 33.034245
# run: [30], model[5]
# Style Loss : 35.896587
# run: [30], model[0]
# Style Loss : 9.525896
# run: [30], model[1]
# Style Loss : 18.811707
# run: [30], model[2]
# Style Loss : 24.848415
# run: [30], model[3]
# Style Loss : 29.224798
# run: [30], model[4]
# Style Loss : 33.031879
# run: [30], model[5]
# Style Loss : 35.894039
# run: [30], model[0]
# Style Loss : 9.525087
# run: [30], model[1]
# Style Loss : 18.810238
# run: [30], model[2]
# Style Loss : 24.846550
# run: [30], model[3]
# Style Loss : 29.222628
# run: [30], model[4]
# Style Loss : 33.029469
# run: [30], model[5]
# Style Loss : 35.891438
# run: [30], model[0]
# Style Loss : 9.524280
# run: [30], model[1]
# Style Loss : 18.808784
# run: [30], model[2]
# Style Loss : 24.844711
# run: [30], model[3]
# Style Loss : 29.220491
# run: [30], model[4]
# Style Loss : 33.027103
# run: [30], model[5]
# Style Loss : 35.888885
# run: [30], model[0]
# Style Loss : 9.523466
# run: [30], model[1]
# Style Loss : 18.807308
# run: [30], model[2]
# Style Loss : 24.842846
# run: [30], model[3]
# Style Loss : 29.218325
# run: [30], model[4]
# Style Loss : 33.024700
# run: [30], model[5]
# Style Loss : 35.886295
# run: [30], model[0]
# Style Loss : 9.522650
# run: [30], model[1]
# Style Loss : 18.805843
# run: [30], model[2]
# Style Loss : 24.840984
# run: [30], model[3]
# Style Loss : 29.216167
# run: [30], model[4]
# Style Loss : 33.022308
# run: [30], model[5]
# Style Loss : 35.883720
# run: [30], model[0]
# Style Loss : 9.521846
# run: [30], model[1]
# Style Loss : 18.804379
# run: [30], model[2]
# Style Loss : 24.839125
# run: [30], model[3]
# Style Loss : 29.214005
# run: [30], model[4]
# Style Loss : 33.019905
# run: [30], model[5]
# Style Loss : 35.881126
# run: [30], model[0]
# Style Loss : 9.521036
# run: [30], model[1]
# Style Loss : 18.802910
# run: [30], model[2]
# Style Loss : 24.837261
# run: [30], model[3]
# Style Loss : 29.211842
# run: [30], model[4]
# Style Loss : 33.017509
# run: [30], model[5]
# Style Loss : 35.878548
# run: [30], model[0]
# Style Loss : 9.520220
# run: [30], model[1]
# Style Loss : 18.801430
# run: [30], model[2]
# Style Loss : 24.835388
# run: [30], model[3]
# Style Loss : 29.209665
# run: [30], model[4]
# Style Loss : 33.015099
# run: [30], model[5]
# Style Loss : 35.875954
# run: [30], model[0]
# Style Loss : 9.519409
# run: [30], model[1]
# Style Loss : 18.799965
# run: [30], model[2]
# Style Loss : 24.833530
# run: [30], model[3]
# Style Loss : 29.207508
# run: [30], model[4]
# Style Loss : 33.012707
# run: [30], model[5]
# Style Loss : 35.873367
# run: [30], model[0]
# Style Loss : 9.518600
# run: [30], model[1]
# Style Loss : 18.798504
# run: [30], model[2]
# Style Loss : 24.831676
# run: [30], model[3]
# Style Loss : 29.205357
# run: [30], model[4]
# Style Loss : 33.010319
# run: [30], model[5]
# Style Loss : 35.870800
# run: [30], model[0]
# Style Loss : 9.517784
# run: [30], model[1]
# Style Loss : 18.797028
# run: [30], model[2]
# Style Loss : 24.829807
# run: [30], model[3]
# Style Loss : 29.203186
# run: [30], model[4]
# Style Loss : 33.007912
# run: [30], model[5]
# Style Loss : 35.868202
# run: [30], model[0]
# Style Loss : 9.516981
# run: [30], model[1]
# Style Loss : 18.795574
# run: [30], model[2]
# Style Loss : 24.827963
# run: [30], model[3]
# Style Loss : 29.201042
# run: [30], model[4]
# Style Loss : 33.005535
# run: [30], model[5]
# Style Loss : 35.865643
# run: [30], model[0]
# Style Loss : 9.516159
# run: [30], model[1]
# Style Loss : 18.794086
# run: [30], model[2]
# Style Loss : 24.826078
# run: [30], model[3]
# Style Loss : 29.198853
# run: [30], model[4]
# Style Loss : 33.003105
# run: [30], model[5]
# Style Loss : 35.863022
# run: [30], model[0]
# Style Loss : 9.515356
# run: [30], model[1]
# Style Loss : 18.792627
# run: [30], model[2]
# Style Loss : 24.824230
# run: [30], model[3]
# Style Loss : 29.196711
# run: [30], model[4]
# Style Loss : 33.000736
# run: [30], model[5]
# Style Loss : 35.860466
# Current Run Number =  31
# numStreams =  6
# Current Run Number =  32
# numStreams =  6
# Current Run Number =  33
# numStreams =  6
# Current Run Number =  34
# numStreams =  6
# Current Run Number =  35
# numStreams =  6
# Current Run Number =  36
# numStreams =  6
# Current Run Number =  37
# numStreams =  6
# Current Run Number =  38
# numStreams =  6
# Current Run Number =  39
# numStreams =  6
# Current Run Number =  40
# numStreams =  6
# run: [40], model[0]
# Style Loss : 9.368330
# run: [40], model[1]
# Style Loss : 18.526165
# run: [40], model[2]
# Style Loss : 24.486511
# run: [40], model[3]
# Style Loss : 28.804573
# run: [40], model[4]
# Style Loss : 32.566051
# run: [40], model[5]
# Style Loss : 35.392017
# run: [40], model[0]
# Style Loss : 9.367522
# run: [40], model[1]
# Style Loss : 18.524698
# run: [40], model[2]
# Style Loss : 24.484648
# run: [40], model[3]
# Style Loss : 28.802416
# run: [40], model[4]
# Style Loss : 32.563660
# run: [40], model[5]
# Style Loss : 35.389439
# run: [40], model[0]
# Style Loss : 9.366703
# run: [40], model[1]
# Style Loss : 18.523220
# run: [40], model[2]
# Style Loss : 24.482769
# run: [40], model[3]
# Style Loss : 28.800232
# run: [40], model[4]
# Style Loss : 32.561241
# run: [40], model[5]
# Style Loss : 35.386833
# run: [40], model[0]
# Style Loss : 9.365885
# run: [40], model[1]
# Style Loss : 18.521732
# run: [40], model[2]
# Style Loss : 24.480890
# run: [40], model[3]
# Style Loss : 28.798050
# run: [40], model[4]
# Style Loss : 32.558823
# run: [40], model[5]
# Style Loss : 35.384228
# run: [40], model[0]
# Style Loss : 9.365073
# run: [40], model[1]
# Style Loss : 18.520260
# run: [40], model[2]
# Style Loss : 24.479025
# run: [40], model[3]
# Style Loss : 28.795887
# run: [40], model[4]
# Style Loss : 32.556419
# run: [40], model[5]
# Style Loss : 35.381638
# run: [40], model[0]
# Style Loss : 9.364257
# run: [40], model[1]
# Style Loss : 18.518784
# run: [40], model[2]
# Style Loss : 24.477158
# run: [40], model[3]
# Style Loss : 28.793715
# run: [40], model[4]
# Style Loss : 32.554016
# run: [40], model[5]
# Style Loss : 35.379047
# run: [40], model[0]
# Style Loss : 9.363442
# run: [40], model[1]
# Style Loss : 18.517315
# run: [40], model[2]
# Style Loss : 24.475300
# run: [40], model[3]
# Style Loss : 28.791565
# run: [40], model[4]
# Style Loss : 32.551636
# run: [40], model[5]
# Style Loss : 35.376480
# run: [40], model[0]
# Style Loss : 9.362621
# run: [40], model[1]
# Style Loss : 18.515821
# run: [40], model[2]
# Style Loss : 24.473406
# run: [40], model[3]
# Style Loss : 28.789364
# run: [40], model[4]
# Style Loss : 32.549198
# run: [40], model[5]
# Style Loss : 35.373856
# run: [40], model[0]
# Style Loss : 9.361810
# run: [40], model[1]
# Style Loss : 18.514343
# run: [40], model[2]
# Style Loss : 24.471531
# run: [40], model[3]
# Style Loss : 28.787182
# run: [40], model[4]
# Style Loss : 32.546780
# run: [40], model[5]
# Style Loss : 35.371250
# run: [40], model[0]
# Style Loss : 9.360992
# run: [40], model[1]
# Style Loss : 18.512861
# run: [40], model[2]
# Style Loss : 24.469646
# run: [40], model[3]
# Style Loss : 28.785002
# run: [40], model[4]
# Style Loss : 32.544361
# run: [40], model[5]
# Style Loss : 35.368645
# run: [40], model[0]
# Style Loss : 9.360185
# run: [40], model[1]
# Style Loss : 18.511391
# run: [40], model[2]
# Style Loss : 24.467783
# run: [40], model[3]
# Style Loss : 28.782831
# run: [40], model[4]
# Style Loss : 32.541950
# run: [40], model[5]
# Style Loss : 35.366043
# run: [40], model[0]
# Style Loss : 9.359366
# run: [40], model[1]
# Style Loss : 18.509907
# run: [40], model[2]
# Style Loss : 24.465906
# run: [40], model[3]
# Style Loss : 28.780659
# run: [40], model[4]
# Style Loss : 32.539547
# run: [40], model[5]
# Style Loss : 35.363457
# run: [40], model[0]
# Style Loss : 9.358562
# run: [40], model[1]
# Style Loss : 18.508446
# run: [40], model[2]
# Style Loss : 24.464054
# run: [40], model[3]
# Style Loss : 28.778507
# run: [40], model[4]
# Style Loss : 32.537163
# run: [40], model[5]
# Style Loss : 35.360889
# run: [40], model[0]
# Style Loss : 9.357749
# run: [40], model[1]
# Style Loss : 18.506966
# run: [40], model[2]
# Style Loss : 24.462179
# run: [40], model[3]
# Style Loss : 28.776337
# run: [40], model[4]
# Style Loss : 32.534760
# run: [40], model[5]
# Style Loss : 35.358299
# run: [40], model[0]
# Style Loss : 9.356926
# run: [40], model[1]
# Style Loss : 18.505486
# run: [40], model[2]
# Style Loss : 24.460304
# run: [40], model[3]
# Style Loss : 28.774158
# run: [40], model[4]
# Style Loss : 32.532349
# run: [40], model[5]
# Style Loss : 35.355701
# run: [40], model[0]
# Style Loss : 9.356114
# run: [40], model[1]
# Style Loss : 18.504009
# run: [40], model[2]
# Style Loss : 24.458431
# run: [40], model[3]
# Style Loss : 28.771984
# run: [40], model[4]
# Style Loss : 32.529938
# run: [40], model[5]
# Style Loss : 35.353104
# run: [40], model[0]
# Style Loss : 9.355298
# run: [40], model[1]
# Style Loss : 18.502525
# run: [40], model[2]
# Style Loss : 24.456554
# run: [40], model[3]
# Style Loss : 28.769802
# run: [40], model[4]
# Style Loss : 32.527519
# run: [40], model[5]
# Style Loss : 35.350494
# run: [40], model[0]
# Style Loss : 9.354496
# run: [40], model[1]
# Style Loss : 18.501074
# run: [40], model[2]
# Style Loss : 24.454708
# run: [40], model[3]
# Style Loss : 28.767656
# run: [40], model[4]
# Style Loss : 32.525139
# run: [40], model[5]
# Style Loss : 35.347931
# run: [40], model[0]
# Style Loss : 9.353683
# run: [40], model[1]
# Style Loss : 18.499596
# run: [40], model[2]
# Style Loss : 24.452833
# run: [40], model[3]
# Style Loss : 28.765478
# run: [40], model[4]
# Style Loss : 32.522728
# run: [40], model[5]
# Style Loss : 35.345333
# run: [40], model[0]
# Style Loss : 9.352862
# run: [40], model[1]
# Style Loss : 18.498106
# run: [40], model[2]
# Style Loss : 24.450947
# run: [40], model[3]
# Style Loss : 28.763287
# run: [40], model[4]
# Style Loss : 32.520294
# run: [40], model[5]
# Style Loss : 35.342712
# Current Run Number =  41
# numStreams =  6
# Current Run Number =  42
# numStreams =  6
# Current Run Number =  43
# numStreams =  6
# Current Run Number =  44
# numStreams =  6
# Current Run Number =  45
# numStreams =  6
# Current Run Number =  46
# numStreams =  6
# Current Run Number =  47
# numStreams =  6
# Current Run Number =  48
# numStreams =  6
# Current Run Number =  49
# numStreams =  6
# Current Run Number =  50
# numStreams =  6
# run: [50], model[0]
# Style Loss : 9.205155
# run: [50], model[1]
# Style Loss : 18.229790
# run: [50], model[2]
# Style Loss : 24.110954
# run: [50], model[3]
# Style Loss : 28.368803
# run: [50], model[4]
# Style Loss : 32.083237
# run: [50], model[5]
# Style Loss : 34.871868
# run: [50], model[0]
# Style Loss : 9.204338
# run: [50], model[1]
# Style Loss : 18.228306
# run: [50], model[2]
# Style Loss : 24.109076
# run: [50], model[3]
# Style Loss : 28.366619
# run: [50], model[4]
# Style Loss : 32.080818
# run: [50], model[5]
# Style Loss : 34.869263
# run: [50], model[0]
# Style Loss : 9.203517
# run: [50], model[1]
# Style Loss : 18.226818
# run: [50], model[2]
# Style Loss : 24.107191
# run: [50], model[3]
# Style Loss : 28.364433
# run: [50], model[4]
# Style Loss : 32.078400
# run: [50], model[5]
# Style Loss : 34.866657
# run: [50], model[0]
# Style Loss : 9.202709
# run: [50], model[1]
# Style Loss : 18.225348
# run: [50], model[2]
# Style Loss : 24.105320
# run: [50], model[3]
# Style Loss : 28.362263
# run: [50], model[4]
# Style Loss : 32.075993
# run: [50], model[5]
# Style Loss : 34.864063
# run: [50], model[0]
# Style Loss : 9.201912
# run: [50], model[1]
# Style Loss : 18.223881
# run: [50], model[2]
# Style Loss : 24.103458
# run: [50], model[3]
# Style Loss : 28.360107
# run: [50], model[4]
# Style Loss : 32.073608
# run: [50], model[5]
# Style Loss : 34.861496
# run: [50], model[0]
# Style Loss : 9.201094
# run: [50], model[1]
# Style Loss : 18.222389
# run: [50], model[2]
# Style Loss : 24.101570
# run: [50], model[3]
# Style Loss : 28.357914
# run: [50], model[4]
# Style Loss : 32.071178
# run: [50], model[5]
# Style Loss : 34.858875
# run: [50], model[0]
# Style Loss : 9.200264
# run: [50], model[1]
# Style Loss : 18.220886
# run: [50], model[2]
# Style Loss : 24.099670
# run: [50], model[3]
# Style Loss : 28.355709
# run: [50], model[4]
# Style Loss : 32.068737
# run: [50], model[5]
# Style Loss : 34.856247
# run: [50], model[0]
# Style Loss : 9.199446
# run: [50], model[1]
# Style Loss : 18.219410
# run: [50], model[2]
# Style Loss : 24.097797
# run: [50], model[3]
# Style Loss : 28.353539
# run: [50], model[4]
# Style Loss : 32.066330
# run: [50], model[5]
# Style Loss : 34.853657
# run: [50], model[0]
# Style Loss : 9.198635
# run: [50], model[1]
# Style Loss : 18.217922
# run: [50], model[2]
# Style Loss : 24.095915
# run: [50], model[3]
# Style Loss : 28.351353
# run: [50], model[4]
# Style Loss : 32.063911
# run: [50], model[5]
# Style Loss : 34.851051
# run: [50], model[0]
# Style Loss : 9.197811
# run: [50], model[1]
# Style Loss : 18.216438
# run: [50], model[2]
# Style Loss : 24.094030
# run: [50], model[3]
# Style Loss : 28.349174
# run: [50], model[4]
# Style Loss : 32.061493
# run: [50], model[5]
# Style Loss : 34.848446
# run: [50], model[0]
# Style Loss : 9.196987
# run: [50], model[1]
# Style Loss : 18.214935
# run: [50], model[2]
# Style Loss : 24.092136
# run: [50], model[3]
# Style Loss : 28.346973
# run: [50], model[4]
# Style Loss : 32.059055
# run: [50], model[5]
# Style Loss : 34.845821
# run: [50], model[0]
# Style Loss : 9.196181
# run: [50], model[1]
# Style Loss : 18.213467
# run: [50], model[2]
# Style Loss : 24.090267
# run: [50], model[3]
# Style Loss : 28.344805
# run: [50], model[4]
# Style Loss : 32.056656
# run: [50], model[5]
# Style Loss : 34.843235
# run: [50], model[0]
# Style Loss : 9.195349
# run: [50], model[1]
# Style Loss : 18.211962
# run: [50], model[2]
# Style Loss : 24.088362
# run: [50], model[3]
# Style Loss : 28.342594
# run: [50], model[4]
# Style Loss : 32.054207
# run: [50], model[5]
# Style Loss : 34.840599
# run: [50], model[0]
# Style Loss : 9.194530
# run: [50], model[1]
# Style Loss : 18.210476
# run: [50], model[2]
# Style Loss : 24.086479
# run: [50], model[3]
# Style Loss : 28.340406
# run: [50], model[4]
# Style Loss : 32.051785
# run: [50], model[5]
# Style Loss : 34.837990
# run: [50], model[0]
# Style Loss : 9.193712
# run: [50], model[1]
# Style Loss : 18.208984
# run: [50], model[2]
# Style Loss : 24.084589
# run: [50], model[3]
# Style Loss : 28.338219
# run: [50], model[4]
# Style Loss : 32.049362
# run: [50], model[5]
# Style Loss : 34.835381
# run: [50], model[0]
# Style Loss : 9.192905
# run: [50], model[1]
# Style Loss : 18.207510
# run: [50], model[2]
# Style Loss : 24.082714
# run: [50], model[3]
# Style Loss : 28.336040
# run: [50], model[4]
# Style Loss : 32.046951
# run: [50], model[5]
# Style Loss : 34.832783
# run: [50], model[0]
# Style Loss : 9.192100
# run: [50], model[1]
# Style Loss : 18.206036
# run: [50], model[2]
# Style Loss : 24.080849
# run: [50], model[3]
# Style Loss : 28.333878
# run: [50], model[4]
# Style Loss : 32.044556
# run: [50], model[5]
# Style Loss : 34.830200
# run: [50], model[0]
# Style Loss : 9.191278
# run: [50], model[1]
# Style Loss : 18.204542
# run: [50], model[2]
# Style Loss : 24.078962
# run: [50], model[3]
# Style Loss : 28.331688
# run: [50], model[4]
# Style Loss : 32.042126
# run: [50], model[5]
# Style Loss : 34.827583
# run: [50], model[0]
# Style Loss : 9.190460
# run: [50], model[1]
# Style Loss : 18.203053
# run: [50], model[2]
# Style Loss : 24.077074
# run: [50], model[3]
# Style Loss : 28.329502
# run: [50], model[4]
# Style Loss : 32.039707
# run: [50], model[5]
# Style Loss : 34.824978
# run: [50], model[0]
# Style Loss : 9.189632
# run: [50], model[1]
# Style Loss : 18.201553
# run: [50], model[2]
# Style Loss : 24.075171
# run: [50], model[3]
# Style Loss : 28.327293
# run: [50], model[4]
# Style Loss : 32.037262
# run: [50], model[5]
# Style Loss : 34.822346
# Current Run Number =  51
# numStreams =  6
# Current Run Number =  52
# numStreams =  6
# Current Run Number =  53
# numStreams =  6
# Current Run Number =  54
# numStreams =  6
# Current Run Number =  55
# numStreams =  6
# Current Run Number =  56
# numStreams =  6
# Current Run Number =  57
# numStreams =  6
# Current Run Number =  58
# numStreams =  6
# Current Run Number =  59
# numStreams =  6
# Current Run Number =  60
# numStreams =  6
# run: [60], model[0]
# Style Loss : 0.001210
# run: [60], model[1]
# Style Loss : 0.002184
# run: [60], model[2]
# Style Loss : 0.002917
# run: [60], model[3]
# Style Loss : 0.003465
# run: [60], model[4]
# Style Loss : 0.004126
# run: [60], model[5]
# Style Loss : 0.005149
# run: [60], model[0]
# Style Loss : 0.001181
# run: [60], model[1]
# Style Loss : 0.002132
# run: [60], model[2]
# Style Loss : 0.002849
# run: [60], model[3]
# Style Loss : 0.003385
# run: [60], model[4]
# Style Loss : 0.004031
# run: [60], model[5]
# Style Loss : 0.005031
# run: [60], model[0]
# Style Loss : 0.001176
# run: [60], model[1]
# Style Loss : 0.002114
# run: [60], model[2]
# Style Loss : 0.002819
# run: [60], model[3]
# Style Loss : 0.003344
# run: [60], model[4]
# Style Loss : 0.003974
# run: [60], model[5]
# Style Loss : 0.004944
# run: [60], model[0]
# Style Loss : 0.001143
# run: [60], model[1]
# Style Loss : 0.002061
# run: [60], model[2]
# Style Loss : 0.002752
# run: [60], model[3]
# Style Loss : 0.003269
# run: [60], model[4]
# Style Loss : 0.003891
# run: [60], model[5]
# Style Loss : 0.004856
# run: [60], model[0]
# Style Loss : 0.001134
# run: [60], model[1]
# Style Loss : 0.002050
# run: [60], model[2]
# Style Loss : 0.002738
# run: [60], model[3]
# Style Loss : 0.003248
# run: [60], model[4]
# Style Loss : 0.003856
# run: [60], model[5]
# Style Loss : 0.004799
# run: [60], model[0]
# Style Loss : 0.001116
# run: [60], model[1]
# Style Loss : 0.002016
# run: [60], model[2]
# Style Loss : 0.002693
# run: [60], model[3]
# Style Loss : 0.003199
# run: [60], model[4]
# Style Loss : 0.003802
# run: [60], model[5]
# Style Loss : 0.004741
# run: [60], model[0]
# Style Loss : 0.001102
# run: [60], model[1]
# Style Loss : 0.001991
# run: [60], model[2]
# Style Loss : 0.002661
# run: [60], model[3]
# Style Loss : 0.003159
# run: [60], model[4]
# Style Loss : 0.003752
# run: [60], model[5]
# Style Loss : 0.004677
# run: [60], model[0]
# Style Loss : 0.001088
# run: [60], model[1]
# Style Loss : 0.001966
# run: [60], model[2]
# Style Loss : 0.002627
# run: [60], model[3]
# Style Loss : 0.003120
# run: [60], model[4]
# Style Loss : 0.003694
# run: [60], model[5]
# Style Loss : 0.004588
# run: [60], model[0]
# Style Loss : 0.001073
# run: [60], model[1]
# Style Loss : 0.001939
# run: [60], model[2]
# Style Loss : 0.002592
# run: [60], model[3]
# Style Loss : 0.003075
# run: [60], model[4]
# Style Loss : 0.003642
# run: [60], model[5]
# Style Loss : 0.004525
# run: [60], model[0]
# Style Loss : 0.001060
# run: [60], model[1]
# Style Loss : 0.001915
# run: [60], model[2]
# Style Loss : 0.002557
# run: [60], model[3]
# Style Loss : 0.003033
# run: [60], model[4]
# Style Loss : 0.003593
# run: [60], model[5]
# Style Loss : 0.004467
# run: [60], model[0]
# Style Loss : 0.001044
# run: [60], model[1]
# Style Loss : 0.001885
# run: [60], model[2]
# Style Loss : 0.002515
# run: [60], model[3]
# Style Loss : 0.002983
# run: [60], model[4]
# Style Loss : 0.003530
# run: [60], model[5]
# Style Loss : 0.004384
# run: [60], model[0]
# Style Loss : 0.001041
# run: [60], model[1]
# Style Loss : 0.001878
# run: [60], model[2]
# Style Loss : 0.002506
# run: [60], model[3]
# Style Loss : 0.002971
# run: [60], model[4]
# Style Loss : 0.003509
# run: [60], model[5]
# Style Loss : 0.004342
# run: [60], model[0]
# Style Loss : 0.001018
# run: [60], model[1]
# Style Loss : 0.001840
# run: [60], model[2]
# Style Loss : 0.002457
# run: [60], model[3]
# Style Loss : 0.002914
# run: [60], model[4]
# Style Loss : 0.003448
# run: [60], model[5]
# Style Loss : 0.004278
# run: [60], model[0]
# Style Loss : 0.001010
# run: [60], model[1]
# Style Loss : 0.001822
# run: [60], model[2]
# Style Loss : 0.002433
# run: [60], model[3]
# Style Loss : 0.002884
# run: [60], model[4]
# Style Loss : 0.003408
# run: [60], model[5]
# Style Loss : 0.004224
# run: [60], model[0]
# Style Loss : 0.000999
# run: [60], model[1]
# Style Loss : 0.001802
# run: [60], model[2]
# Style Loss : 0.002407
# run: [60], model[3]
# Style Loss : 0.002853
# run: [60], model[4]
# Style Loss : 0.003373
# run: [60], model[5]
# Style Loss : 0.004184
# run: [60], model[0]
# Style Loss : 0.000985
# run: [60], model[1]
# Style Loss : 0.001777
# run: [60], model[2]
# Style Loss : 0.002374
# run: [60], model[3]
# Style Loss : 0.002814
# run: [60], model[4]
# Style Loss : 0.003323
# run: [60], model[5]
# Style Loss : 0.004117
# run: [60], model[0]
# Style Loss : 0.000968
# run: [60], model[1]
# Style Loss : 0.001750
# run: [60], model[2]
# Style Loss : 0.002335
# run: [60], model[3]
# Style Loss : 0.002767
# run: [60], model[4]
# Style Loss : 0.003264
# run: [60], model[5]
# Style Loss : 0.004035
# run: [60], model[0]
# Style Loss : 0.000950
# run: [60], model[1]
# Style Loss : 0.001719
# run: [60], model[2]
# Style Loss : 0.002294
# run: [60], model[3]
# Style Loss : 0.002719
# run: [60], model[4]
# Style Loss : 0.003210
# run: [60], model[5]
# Style Loss : 0.003971
# run: [60], model[0]
# Style Loss : 0.000943
# run: [60], model[1]
# Style Loss : 0.001704
# run: [60], model[2]
# Style Loss : 0.002272
# run: [60], model[3]
# Style Loss : 0.002690
# run: [60], model[4]
# Style Loss : 0.003174
# run: [60], model[5]
# Style Loss : 0.003928
# run: [60], model[0]
# Style Loss : 0.000932
# run: [60], model[1]
# Style Loss : 0.001683
# run: [60], model[2]
# Style Loss : 0.002241
# run: [60], model[3]
# Style Loss : 0.002651
# run: [60], model[4]
# Style Loss : 0.003123
# run: [60], model[5]
# Style Loss : 0.003861
# Current Run Number =  61
# numStreams =  6
# Current Run Number =  62
# numStreams =  6
# Current Run Number =  63
# numStreams =  6
# Current Run Number =  64
# numStreams =  6
# Current Run Number =  65
# numStreams =  6
# Current Run Number =  66
# numStreams =  6
# Current Run Number =  67
# numStreams =  6
# Current Run Number =  68
# numStreams =  6
# Current Run Number =  69
# numStreams =  6
# Current Run Number =  70
# numStreams =  6
# run: [70], model[0]
# Style Loss : 0.000216
# run: [70], model[1]
# Style Loss : 0.000380
# run: [70], model[2]
# Style Loss : 0.000492
# run: [70], model[3]
# Style Loss : 0.000565
# run: [70], model[4]
# Style Loss : 0.000629
# run: [70], model[5]
# Style Loss : 0.000729
# run: [70], model[0]
# Style Loss : 0.000214
# run: [70], model[1]
# Style Loss : 0.000378
# run: [70], model[2]
# Style Loss : 0.000489
# run: [70], model[3]
# Style Loss : 0.000562
# run: [70], model[4]
# Style Loss : 0.000625
# run: [70], model[5]
# Style Loss : 0.000725
# run: [70], model[0]
# Style Loss : 0.000213
# run: [70], model[1]
# Style Loss : 0.000375
# run: [70], model[2]
# Style Loss : 0.000485
# run: [70], model[3]
# Style Loss : 0.000558
# run: [70], model[4]
# Style Loss : 0.000621
# run: [70], model[5]
# Style Loss : 0.000720
# run: [70], model[0]
# Style Loss : 0.000212
# run: [70], model[1]
# Style Loss : 0.000373
# run: [70], model[2]
# Style Loss : 0.000483
# run: [70], model[3]
# Style Loss : 0.000555
# run: [70], model[4]
# Style Loss : 0.000617
# run: [70], model[5]
# Style Loss : 0.000715
# run: [70], model[0]
# Style Loss : 0.000211
# run: [70], model[1]
# Style Loss : 0.000371
# run: [70], model[2]
# Style Loss : 0.000480
# run: [70], model[3]
# Style Loss : 0.000551
# run: [70], model[4]
# Style Loss : 0.000613
# run: [70], model[5]
# Style Loss : 0.000711
# run: [70], model[0]
# Style Loss : 0.000210
# run: [70], model[1]
# Style Loss : 0.000369
# run: [70], model[2]
# Style Loss : 0.000477
# run: [70], model[3]
# Style Loss : 0.000548
# run: [70], model[4]
# Style Loss : 0.000610
# run: [70], model[5]
# Style Loss : 0.000707
# run: [70], model[0]
# Style Loss : 0.000209
# run: [70], model[1]
# Style Loss : 0.000367
# run: [70], model[2]
# Style Loss : 0.000475
# run: [70], model[3]
# Style Loss : 0.000545
# run: [70], model[4]
# Style Loss : 0.000606
# run: [70], model[5]
# Style Loss : 0.000702
# run: [70], model[0]
# Style Loss : 0.000208
# run: [70], model[1]
# Style Loss : 0.000365
# run: [70], model[2]
# Style Loss : 0.000472
# run: [70], model[3]
# Style Loss : 0.000543
# run: [70], model[4]
# Style Loss : 0.000603
# run: [70], model[5]
# Style Loss : 0.000698
# run: [70], model[0]
# Style Loss : 0.000206
# run: [70], model[1]
# Style Loss : 0.000363
# run: [70], model[2]
# Style Loss : 0.000469
# run: [70], model[3]
# Style Loss : 0.000539
# run: [70], model[4]
# Style Loss : 0.000599
# run: [70], model[5]
# Style Loss : 0.000694
# run: [70], model[0]
# Style Loss : 0.000206
# run: [70], model[1]
# Style Loss : 0.000361
# run: [70], model[2]
# Style Loss : 0.000468
# run: [70], model[3]
# Style Loss : 0.000537
# run: [70], model[4]
# Style Loss : 0.000597
# run: [70], model[5]
# Style Loss : 0.000691
# run: [70], model[0]
# Style Loss : 0.000205
# run: [70], model[1]
# Style Loss : 0.000360
# run: [70], model[2]
# Style Loss : 0.000465
# run: [70], model[3]
# Style Loss : 0.000534
# run: [70], model[4]
# Style Loss : 0.000594
# run: [70], model[5]
# Style Loss : 0.000687
# run: [70], model[0]
# Style Loss : 0.000204
# run: [70], model[1]
# Style Loss : 0.000358
# run: [70], model[2]
# Style Loss : 0.000463
# run: [70], model[3]
# Style Loss : 0.000532
# run: [70], model[4]
# Style Loss : 0.000591
# run: [70], model[5]
# Style Loss : 0.000683
# run: [70], model[0]
# Style Loss : 0.000203
# run: [70], model[1]
# Style Loss : 0.000357
# run: [70], model[2]
# Style Loss : 0.000461
# run: [70], model[3]
# Style Loss : 0.000529
# run: [70], model[4]
# Style Loss : 0.000587
# run: [70], model[5]
# Style Loss : 0.000679
# run: [70], model[0]
# Style Loss : 0.000202
# run: [70], model[1]
# Style Loss : 0.000355
# run: [70], model[2]
# Style Loss : 0.000458
# run: [70], model[3]
# Style Loss : 0.000526
# run: [70], model[4]
# Style Loss : 0.000584
# run: [70], model[5]
# Style Loss : 0.000676
# run: [70], model[0]
# Style Loss : 0.000201
# run: [70], model[1]
# Style Loss : 0.000353
# run: [70], model[2]
# Style Loss : 0.000456
# run: [70], model[3]
# Style Loss : 0.000523
# run: [70], model[4]
# Style Loss : 0.000581
# run: [70], model[5]
# Style Loss : 0.000672
# run: [70], model[0]
# Style Loss : 0.000200
# run: [70], model[1]
# Style Loss : 0.000351
# run: [70], model[2]
# Style Loss : 0.000454
# run: [70], model[3]
# Style Loss : 0.000521
# run: [70], model[4]
# Style Loss : 0.000578
# run: [70], model[5]
# Style Loss : 0.000668
# run: [70], model[0]
# Style Loss : 0.000199
# run: [70], model[1]
# Style Loss : 0.000349
# run: [70], model[2]
# Style Loss : 0.000451
# run: [70], model[3]
# Style Loss : 0.000518
# run: [70], model[4]
# Style Loss : 0.000575
# run: [70], model[5]
# Style Loss : 0.000664
# run: [70], model[0]
# Style Loss : 0.000198
# run: [70], model[1]
# Style Loss : 0.000348
# run: [70], model[2]
# Style Loss : 0.000449
# run: [70], model[3]
# Style Loss : 0.000515
# run: [70], model[4]
# Style Loss : 0.000572
# run: [70], model[5]
# Style Loss : 0.000660
# run: [70], model[0]
# Style Loss : 0.000197
# run: [70], model[1]
# Style Loss : 0.000346
# run: [70], model[2]
# Style Loss : 0.000447
# run: [70], model[3]
# Style Loss : 0.000513
# run: [70], model[4]
# Style Loss : 0.000569
# run: [70], model[5]
# Style Loss : 0.000657
# run: [70], model[0]
# Style Loss : 0.000196
# run: [70], model[1]
# Style Loss : 0.000344
# run: [70], model[2]
# Style Loss : 0.000445
# run: [70], model[3]
# Style Loss : 0.000510
# run: [70], model[4]
# Style Loss : 0.000566
# run: [70], model[5]
# Style Loss : 0.000653
# Current Run Number =  71
# numStreams =  6
# Current Run Number =  72
# numStreams =  6
# Current Run Number =  73
# numStreams =  6
# Current Run Number =  74
# numStreams =  6
# Current Run Number =  75
# numStreams =  6
# Current Run Number =  76
# numStreams =  6
# Current Run Number =  77
# numStreams =  6
# Current Run Number =  78
# numStreams =  6
# Current Run Number =  79
# numStreams =  6
# Current Run Number =  80
# numStreams =  6
# run: [80], model[0]
# Style Loss : 0.000105
# run: [80], model[1]
# Style Loss : 0.000181
# run: [80], model[2]
# Style Loss : 0.000230
# run: [80], model[3]
# Style Loss : 0.000259
# run: [80], model[4]
# Style Loss : 0.000282
# run: [80], model[5]
# Style Loss : 0.000318
# run: [80], model[0]
# Style Loss : 0.000104
# run: [80], model[1]
# Style Loss : 0.000180
# run: [80], model[2]
# Style Loss : 0.000229
# run: [80], model[3]
# Style Loss : 0.000259
# run: [80], model[4]
# Style Loss : 0.000281
# run: [80], model[5]
# Style Loss : 0.000317
# run: [80], model[0]
# Style Loss : 0.000104
# run: [80], model[1]
# Style Loss : 0.000180
# run: [80], model[2]
# Style Loss : 0.000228
# run: [80], model[3]
# Style Loss : 0.000258
# run: [80], model[4]
# Style Loss : 0.000281
# run: [80], model[5]
# Style Loss : 0.000316
# run: [80], model[0]
# Style Loss : 0.000104
# run: [80], model[1]
# Style Loss : 0.000180
# run: [80], model[2]
# Style Loss : 0.000228
# run: [80], model[3]
# Style Loss : 0.000257
# run: [80], model[4]
# Style Loss : 0.000280
# run: [80], model[5]
# Style Loss : 0.000315
# run: [80], model[0]
# Style Loss : 0.000104
# run: [80], model[1]
# Style Loss : 0.000179
# run: [80], model[2]
# Style Loss : 0.000227
# run: [80], model[3]
# Style Loss : 0.000257
# run: [80], model[4]
# Style Loss : 0.000279
# run: [80], model[5]
# Style Loss : 0.000314
# run: [80], model[0]
# Style Loss : 0.000103
# run: [80], model[1]
# Style Loss : 0.000179
# run: [80], model[2]
# Style Loss : 0.000227
# run: [80], model[3]
# Style Loss : 0.000256
# run: [80], model[4]
# Style Loss : 0.000278
# run: [80], model[5]
# Style Loss : 0.000313
# run: [80], model[0]
# Style Loss : 0.000103
# run: [80], model[1]
# Style Loss : 0.000178
# run: [80], model[2]
# Style Loss : 0.000226
# run: [80], model[3]
# Style Loss : 0.000255
# run: [80], model[4]
# Style Loss : 0.000278
# run: [80], model[5]
# Style Loss : 0.000312
# run: [80], model[0]
# Style Loss : 0.000103
# run: [80], model[1]
# Style Loss : 0.000178
# run: [80], model[2]
# Style Loss : 0.000226
# run: [80], model[3]
# Style Loss : 0.000255
# run: [80], model[4]
# Style Loss : 0.000277
# run: [80], model[5]
# Style Loss : 0.000312
# run: [80], model[0]
# Style Loss : 0.000103
# run: [80], model[1]
# Style Loss : 0.000177
# run: [80], model[2]
# Style Loss : 0.000225
# run: [80], model[3]
# Style Loss : 0.000254
# run: [80], model[4]
# Style Loss : 0.000276
# run: [80], model[5]
# Style Loss : 0.000311
# run: [80], model[0]
# Style Loss : 0.000102
# run: [80], model[1]
# Style Loss : 0.000177
# run: [80], model[2]
# Style Loss : 0.000224
# run: [80], model[3]
# Style Loss : 0.000254
# run: [80], model[4]
# Style Loss : 0.000276
# run: [80], model[5]
# Style Loss : 0.000310
# run: [80], model[0]
# Style Loss : 0.000102
# run: [80], model[1]
# Style Loss : 0.000176
# run: [80], model[2]
# Style Loss : 0.000224
# run: [80], model[3]
# Style Loss : 0.000253
# run: [80], model[4]
# Style Loss : 0.000275
# run: [80], model[5]
# Style Loss : 0.000309
# run: [80], model[0]
# Style Loss : 0.000102
# run: [80], model[1]
# Style Loss : 0.000176
# run: [80], model[2]
# Style Loss : 0.000223
# run: [80], model[3]
# Style Loss : 0.000252
# run: [80], model[4]
# Style Loss : 0.000274
# run: [80], model[5]
# Style Loss : 0.000308
# run: [80], model[0]
# Style Loss : 0.000102
# run: [80], model[1]
# Style Loss : 0.000176
# run: [80], model[2]
# Style Loss : 0.000223
# run: [80], model[3]
# Style Loss : 0.000252
# run: [80], model[4]
# Style Loss : 0.000273
# run: [80], model[5]
# Style Loss : 0.000307
# run: [80], model[0]
# Style Loss : 0.000101
# run: [80], model[1]
# Style Loss : 0.000175
# run: [80], model[2]
# Style Loss : 0.000222
# run: [80], model[3]
# Style Loss : 0.000251
# run: [80], model[4]
# Style Loss : 0.000273
# run: [80], model[5]
# Style Loss : 0.000306
# run: [80], model[0]
# Style Loss : 0.000101
# run: [80], model[1]
# Style Loss : 0.000175
# run: [80], model[2]
# Style Loss : 0.000222
# run: [80], model[3]
# Style Loss : 0.000250
# run: [80], model[4]
# Style Loss : 0.000272
# run: [80], model[5]
# Style Loss : 0.000306
# run: [80], model[0]
# Style Loss : 0.000101
# run: [80], model[1]
# Style Loss : 0.000174
# run: [80], model[2]
# Style Loss : 0.000221
# run: [80], model[3]
# Style Loss : 0.000250
# run: [80], model[4]
# Style Loss : 0.000271
# run: [80], model[5]
# Style Loss : 0.000305
# run: [80], model[0]
# Style Loss : 0.000101
# run: [80], model[1]
# Style Loss : 0.000174
# run: [80], model[2]
# Style Loss : 0.000221
# run: [80], model[3]
# Style Loss : 0.000249
# run: [80], model[4]
# Style Loss : 0.000271
# run: [80], model[5]
# Style Loss : 0.000304
# run: [80], model[0]
# Style Loss : 0.000101
# run: [80], model[1]
# Style Loss : 0.000173
# run: [80], model[2]
# Style Loss : 0.000220
# run: [80], model[3]
# Style Loss : 0.000248
# run: [80], model[4]
# Style Loss : 0.000270
# run: [80], model[5]
# Style Loss : 0.000303
# run: [80], model[0]
# Style Loss : 0.000100
# run: [80], model[1]
# Style Loss : 0.000173
# run: [80], model[2]
# Style Loss : 0.000219
# run: [80], model[3]
# Style Loss : 0.000248
# run: [80], model[4]
# Style Loss : 0.000269
# run: [80], model[5]
# Style Loss : 0.000302
# run: [80], model[0]
# Style Loss : 0.000100
# run: [80], model[1]
# Style Loss : 0.000173
# run: [80], model[2]
# Style Loss : 0.000219
# run: [80], model[3]
# Style Loss : 0.000247
# run: [80], model[4]
# Style Loss : 0.000268
# run: [80], model[5]
# Style Loss : 0.000302
# Current Run Number =  81
# numStreams =  6
# Current Run Number =  82
# numStreams =  6
# Current Run Number =  83
# numStreams =  6
# Current Run Number =  84
# numStreams =  6
# Current Run Number =  85
# numStreams =  6
# Current Run Number =  86
# numStreams =  6
# Current Run Number =  87
# numStreams =  6
# Current Run Number =  88
# numStreams =  6
# Current Run Number =  89
# numStreams =  6
# Current Run Number =  90
# numStreams =  6
# run: [90], model[0]
# Style Loss : 0.000072
# run: [90], model[1]
# Style Loss : 0.000123
# run: [90], model[2]
# Style Loss : 0.000155
# run: [90], model[3]
# Style Loss : 0.000173
# run: [90], model[4]
# Style Loss : 0.000186
# run: [90], model[5]
# Style Loss : 0.000207
# run: [90], model[0]
# Style Loss : 0.000072
# run: [90], model[1]
# Style Loss : 0.000123
# run: [90], model[2]
# Style Loss : 0.000154
# run: [90], model[3]
# Style Loss : 0.000173
# run: [90], model[4]
# Style Loss : 0.000186
# run: [90], model[5]
# Style Loss : 0.000207
# run: [90], model[0]
# Style Loss : 0.000072
# run: [90], model[1]
# Style Loss : 0.000123
# run: [90], model[2]
# Style Loss : 0.000154
# run: [90], model[3]
# Style Loss : 0.000173
# run: [90], model[4]
# Style Loss : 0.000186
# run: [90], model[5]
# Style Loss : 0.000207
# run: [90], model[0]
# Style Loss : 0.000072
# run: [90], model[1]
# Style Loss : 0.000123
# run: [90], model[2]
# Style Loss : 0.000154
# run: [90], model[3]
# Style Loss : 0.000172
# run: [90], model[4]
# Style Loss : 0.000186
# run: [90], model[5]
# Style Loss : 0.000206
# run: [90], model[0]
# Style Loss : 0.000072
# run: [90], model[1]
# Style Loss : 0.000122
# run: [90], model[2]
# Style Loss : 0.000154
# run: [90], model[3]
# Style Loss : 0.000172
# run: [90], model[4]
# Style Loss : 0.000185
# run: [90], model[5]
# Style Loss : 0.000206
# run: [90], model[0]
# Style Loss : 0.000071
# run: [90], model[1]
# Style Loss : 0.000122
# run: [90], model[2]
# Style Loss : 0.000153
# run: [90], model[3]
# Style Loss : 0.000172
# run: [90], model[4]
# Style Loss : 0.000185
# run: [90], model[5]
# Style Loss : 0.000206
# run: [90], model[0]
# Style Loss : 0.000071
# run: [90], model[1]
# Style Loss : 0.000122
# run: [90], model[2]
# Style Loss : 0.000153
# run: [90], model[3]
# Style Loss : 0.000172
# run: [90], model[4]
# Style Loss : 0.000185
# run: [90], model[5]
# Style Loss : 0.000205
# run: [90], model[0]
# Style Loss : 0.000071
# run: [90], model[1]
# Style Loss : 0.000122
# run: [90], model[2]
# Style Loss : 0.000153
# run: [90], model[3]
# Style Loss : 0.000171
# run: [90], model[4]
# Style Loss : 0.000184
# run: [90], model[5]
# Style Loss : 0.000205
# run: [90], model[0]
# Style Loss : 0.000071
# run: [90], model[1]
# Style Loss : 0.000122
# run: [90], model[2]
# Style Loss : 0.000153
# run: [90], model[3]
# Style Loss : 0.000171
# run: [90], model[4]
# Style Loss : 0.000184
# run: [90], model[5]
# Style Loss : 0.000204
# run: [90], model[0]
# Style Loss : 0.000071
# run: [90], model[1]
# Style Loss : 0.000121
# run: [90], model[2]
# Style Loss : 0.000152
# run: [90], model[3]
# Style Loss : 0.000171
# run: [90], model[4]
# Style Loss : 0.000184
# run: [90], model[5]
# Style Loss : 0.000204
# run: [90], model[0]
# Style Loss : 0.000071
# run: [90], model[1]
# Style Loss : 0.000121
# run: [90], model[2]
# Style Loss : 0.000152
# run: [90], model[3]
# Style Loss : 0.000171
# run: [90], model[4]
# Style Loss : 0.000184
# run: [90], model[5]
# Style Loss : 0.000204
# run: [90], model[0]
# Style Loss : 0.000071
# run: [90], model[1]
# Style Loss : 0.000121
# run: [90], model[2]
# Style Loss : 0.000152
# run: [90], model[3]
# Style Loss : 0.000170
# run: [90], model[4]
# Style Loss : 0.000183
# run: [90], model[5]
# Style Loss : 0.000204
# run: [90], model[0]
# Style Loss : 0.000071
# run: [90], model[1]
# Style Loss : 0.000121
# run: [90], model[2]
# Style Loss : 0.000152
# run: [90], model[3]
# Style Loss : 0.000170
# run: [90], model[4]
# Style Loss : 0.000183
# run: [90], model[5]
# Style Loss : 0.000203
# run: [90], model[0]
# Style Loss : 0.000071
# run: [90], model[1]
# Style Loss : 0.000121
# run: [90], model[2]
# Style Loss : 0.000152
# run: [90], model[3]
# Style Loss : 0.000170
# run: [90], model[4]
# Style Loss : 0.000183
# run: [90], model[5]
# Style Loss : 0.000203
# run: [90], model[0]
# Style Loss : 0.000071
# run: [90], model[1]
# Style Loss : 0.000121
# run: [90], model[2]
# Style Loss : 0.000151
# run: [90], model[3]
# Style Loss : 0.000170
# run: [90], model[4]
# Style Loss : 0.000182
# run: [90], model[5]
# Style Loss : 0.000203
# run: [90], model[0]
# Style Loss : 0.000070
# run: [90], model[1]
# Style Loss : 0.000120
# run: [90], model[2]
# Style Loss : 0.000151
# run: [90], model[3]
# Style Loss : 0.000169
# run: [90], model[4]
# Style Loss : 0.000182
# run: [90], model[5]
# Style Loss : 0.000202
# run: [90], model[0]
# Style Loss : 0.000070
# run: [90], model[1]
# Style Loss : 0.000120
# run: [90], model[2]
# Style Loss : 0.000151
# run: [90], model[3]
# Style Loss : 0.000169
# run: [90], model[4]
# Style Loss : 0.000182
# run: [90], model[5]
# Style Loss : 0.000202
# run: [90], model[0]
# Style Loss : 0.000070
# run: [90], model[1]
# Style Loss : 0.000120
# run: [90], model[2]
# Style Loss : 0.000151
# run: [90], model[3]
# Style Loss : 0.000169
# run: [90], model[4]
# Style Loss : 0.000182
# run: [90], model[5]
# Style Loss : 0.000202
# run: [90], model[0]
# Style Loss : 0.000070
# run: [90], model[1]
# Style Loss : 0.000120
# run: [90], model[2]
# Style Loss : 0.000150
# run: [90], model[3]
# Style Loss : 0.000169
# run: [90], model[4]
# Style Loss : 0.000181
# run: [90], model[5]
# Style Loss : 0.000201
# run: [90], model[0]
# Style Loss : 0.000070
# run: [90], model[1]
# Style Loss : 0.000120
# run: [90], model[2]
# Style Loss : 0.000150
# run: [90], model[3]
# Style Loss : 0.000168
# run: [90], model[4]
# Style Loss : 0.000181
# run: [90], model[5]
# Style Loss : 0.000201
# Current Run Number =  91
# numStreams =  6
# Current Run Number =  92
# numStreams =  6
# Current Run Number =  93
# numStreams =  6
# Current Run Number =  94
# numStreams =  6
# Current Run Number =  95
# numStreams =  6
# Current Run Number =  96
# numStreams =  6
# Current Run Number =  97
# numStreams =  6
# Current Run Number =  98
# numStreams =  6
# Current Run Number =  99
# numStreams =  6
# Current Run Number =  100
# numStreams =  6
# run: [100], model[0]
# Style Loss : 0.000057
# run: [100], model[1]
# Style Loss : 0.000097
# run: [100], model[2]
# Style Loss : 0.000121
# run: [100], model[3]
# Style Loss : 0.000135
# run: [100], model[4]
# Style Loss : 0.000144
# run: [100], model[5]
# Style Loss : 0.000159
# run: [100], model[0]
# Style Loss : 0.000057
# run: [100], model[1]
# Style Loss : 0.000097
# run: [100], model[2]
# Style Loss : 0.000121
# run: [100], model[3]
# Style Loss : 0.000135
# run: [100], model[4]
# Style Loss : 0.000144
# run: [100], model[5]
# Style Loss : 0.000159
# run: [100], model[0]
# Style Loss : 0.000057
# run: [100], model[1]
# Style Loss : 0.000097
# run: [100], model[2]
# Style Loss : 0.000121
# run: [100], model[3]
# Style Loss : 0.000135
# run: [100], model[4]
# Style Loss : 0.000144
# run: [100], model[5]
# Style Loss : 0.000159
# run: [100], model[0]
# Style Loss : 0.000057
# run: [100], model[1]
# Style Loss : 0.000097
# run: [100], model[2]
# Style Loss : 0.000120
# run: [100], model[3]
# Style Loss : 0.000134
# run: [100], model[4]
# Style Loss : 0.000144
# run: [100], model[5]
# Style Loss : 0.000159
# run: [100], model[0]
# Style Loss : 0.000057
# run: [100], model[1]
# Style Loss : 0.000097
# run: [100], model[2]
# Style Loss : 0.000120
# run: [100], model[3]
# Style Loss : 0.000134
# run: [100], model[4]
# Style Loss : 0.000144
# run: [100], model[5]
# Style Loss : 0.000159
# run: [100], model[0]
# Style Loss : 0.000057
# run: [100], model[1]
# Style Loss : 0.000096
# run: [100], model[2]
# Style Loss : 0.000120
# run: [100], model[3]
# Style Loss : 0.000134
# run: [100], model[4]
# Style Loss : 0.000144
# run: [100], model[5]
# Style Loss : 0.000159
# run: [100], model[0]
# Style Loss : 0.000057
# run: [100], model[1]
# Style Loss : 0.000096
# run: [100], model[2]
# Style Loss : 0.000120
# run: [100], model[3]
# Style Loss : 0.000134
# run: [100], model[4]
# Style Loss : 0.000143
# run: [100], model[5]
# Style Loss : 0.000158
# run: [100], model[0]
# Style Loss : 0.000057
# run: [100], model[1]
# Style Loss : 0.000096
# run: [100], model[2]
# Style Loss : 0.000120
# run: [100], model[3]
# Style Loss : 0.000134
# run: [100], model[4]
# Style Loss : 0.000143
# run: [100], model[5]
# Style Loss : 0.000158
# run: [100], model[0]
# Style Loss : 0.000057
# run: [100], model[1]
# Style Loss : 0.000096
# run: [100], model[2]
# Style Loss : 0.000120
# run: [100], model[3]
# Style Loss : 0.000134
# run: [100], model[4]
# Style Loss : 0.000143
# run: [100], model[5]
# Style Loss : 0.000158
# run: [100], model[0]
# Style Loss : 0.000057
# run: [100], model[1]
# Style Loss : 0.000096
# run: [100], model[2]
# Style Loss : 0.000120
# run: [100], model[3]
# Style Loss : 0.000134
# run: [100], model[4]
# Style Loss : 0.000143
# run: [100], model[5]
# Style Loss : 0.000158
# run: [100], model[0]
# Style Loss : 0.000057
# run: [100], model[1]
# Style Loss : 0.000096
# run: [100], model[2]
# Style Loss : 0.000120
# run: [100], model[3]
# Style Loss : 0.000133
# run: [100], model[4]
# Style Loss : 0.000143
# run: [100], model[5]
# Style Loss : 0.000158
# run: [100], model[0]
# Style Loss : 0.000056
# run: [100], model[1]
# Style Loss : 0.000096
# run: [100], model[2]
# Style Loss : 0.000120
# run: [100], model[3]
# Style Loss : 0.000133
# run: [100], model[4]
# Style Loss : 0.000143
# run: [100], model[5]
# Style Loss : 0.000157
# run: [100], model[0]
# Style Loss : 0.000056
# run: [100], model[1]
# Style Loss : 0.000096
# run: [100], model[2]
# Style Loss : 0.000119
# run: [100], model[3]
# Style Loss : 0.000133
# run: [100], model[4]
# Style Loss : 0.000143
# run: [100], model[5]
# Style Loss : 0.000157
# run: [100], model[0]
# Style Loss : 0.000056
# run: [100], model[1]
# Style Loss : 0.000096
# run: [100], model[2]
# Style Loss : 0.000119
# run: [100], model[3]
# Style Loss : 0.000133
# run: [100], model[4]
# Style Loss : 0.000142
# run: [100], model[5]
# Style Loss : 0.000157
# run: [100], model[0]
# Style Loss : 0.000056
# run: [100], model[1]
# Style Loss : 0.000096
# run: [100], model[2]
# Style Loss : 0.000119
# run: [100], model[3]
# Style Loss : 0.000133
# run: [100], model[4]
# Style Loss : 0.000142
# run: [100], model[5]
# Style Loss : 0.000157
# run: [100], model[0]
# Style Loss : 0.000056
# run: [100], model[1]
# Style Loss : 0.000096
# run: [100], model[2]
# Style Loss : 0.000119
# run: [100], model[3]
# Style Loss : 0.000133
# run: [100], model[4]
# Style Loss : 0.000142
# run: [100], model[5]
# Style Loss : 0.000157
# run: [100], model[0]
# Style Loss : 0.000056
# run: [100], model[1]
# Style Loss : 0.000095
# run: [100], model[2]
# Style Loss : 0.000119
# run: [100], model[3]
# Style Loss : 0.000133
# run: [100], model[4]
# Style Loss : 0.000142
# run: [100], model[5]
# Style Loss : 0.000157
# run: [100], model[0]
# Style Loss : 0.000056
# run: [100], model[1]
# Style Loss : 0.000095
# run: [100], model[2]
# Style Loss : 0.000119
# run: [100], model[3]
# Style Loss : 0.000133
# run: [100], model[4]
# Style Loss : 0.000142
# run: [100], model[5]
# Style Loss : 0.000156
# run: [100], model[0]
# Style Loss : 0.000056
# run: [100], model[1]
# Style Loss : 0.000095
# run: [100], model[2]
# Style Loss : 0.000119
# run: [100], model[3]
# Style Loss : 0.000133
# run: [100], model[4]
# Style Loss : 0.000142
# run: [100], model[5]
# Style Loss : 0.000156
# run: [100], model[0]
# Style Loss : 0.000056
# run: [100], model[1]
# Style Loss : 0.000095
# run: [100], model[2]
# Style Loss : 0.000119
# run: [100], model[3]
# Style Loss : 0.000132
# run: [100], model[4]
# Style Loss : 0.000142
# run: [100], model[5]
# Style Loss : 0.000156
# Current Run Number =  101
# numStreams =  6
# (257, 3488)
# Output range: -0.94464105 2.8830783
# mean and sigma: 0.06143539 0.19636838

# %%
#SPECTOFFSET
SPECTOFFSET=0

##out_spec = inv_scale(out,shf)
for j in range(len(outputs)):
    print(f'Min/Max of outputs:  {np.amin(outputs[j])},{np.amax(outputs[j])}') # check values make sense
    fig = plt.figure()
    plt.title('Style spectrogram')
    ax = fig.add_subplot(111)
    n,b,_ = ax.hist(outputs[j].flatten(),bins='auto')
    plt.show()

if tifresi :
    #### Shift log spec to use max range before thresholding for tfresi inversion
    #outputs=[x+1-np.amax(x) for x in outputs]
    print('TIFResi: inv_log_spectrogram')
    if use01scale == True:
        foo = [img_invscale(x,a_min,a_max,0,1) for x in outputs]
        out_spec = [inv_log_spectrogram(x+SPECTOFFSET) for x in foo]
        for j in range(len(outputs)):
            print(f'   RESCALED: Min/Max of outputs:  {np.amin(foo[j])},{np.amax(foo[j])}') # check values make sense

    else:
        out_spec = [inv_log_spectrogram(x+SPECTOFFSET) for x in outputs] 
        #out_spec = [inv_log(x+SPECTOFFSET) for x in outputs]
        for j in range(len(outputs)):
            print(f'   inv_log_spectrogram: Min/Max of outputs:  {np.amin(out_spec[j])},{np.amax(out_spec[j])}') # check values make sense

else : 
    print('HUZ: inv_log')
    if use01scale == True:
        out_spec = [inv_log(img_invscale(x,a_min,a_max,0,1)) for x in outputs]
    else:
        out_spec = [inv_log(x) for x in outputs]

    for j in range(len(out_spec)):
        print(f'Min/Max of out_spec: {np.amin(out_spec[j])}, {np.amax(out_spec[j])}') # check values make sense
# Out:
# Min/Max of outputs:  -0.9446410536766052,2.8830783367156982
# HUZ: inv_log
# Min/Max of out_spec: -0.6111809015274048, 16.869197845458984

# %%
# Griffin & Lim algo for phase reconstruction (not used for tifresi)

print(f'out_spec lene is {len(out_spec)}')
for index,value in enumerate(out_spec):
    print(f'shape of value is {value.shape}')
    
    if tifresi :
        print(f'TIFResi invert mag to audio')
        print("shape of mag = ",np.shape(value))
        S = value
        bar=S#-np.amin(S)+.0001
#         bar = np.abs(bar)
        #bar=bar/np.amax(bar)
        bar = np.clip(bar, 0,None)
        print(f'Min/Max of spectrogram: {np.amin(bar)}, {np.amax(bar)}') # check values make sense
        x = stft_system.invert_spectrogram(bar) 
    else :
        print(f'Huz invert mag to audio')
        p = 2 * np.pi * np.random.random_sample(value.shape) - np.pi #start with some phase
        #Griffin Lim
        for i in range(500):
            S = value * np.exp(1j*p) #use magnitude a given by spectrogram and some random phase
            x = librosa.istft(S,hop_length=K_HOP, win_length=N_FFT, center=False) #do the inverse transform
            p = np.angle(librosa.stft(x, n_fft=N_FFT, hop_length=K_HOP, win_length=N_FFT, center=False)) #use this new phase value

    try:
        os.makedirs("outputs/" + outname)
    except FileExistsError:
        # directory already exists
        pass

    OUTPUT_FILENAME="outputs/" + outname + '/' + outname + '_' + str(index) + '.wav'
    #librosa.output.write_wav("outputs/" + outname + '/' + outname + '_' + str(index) + '.wav', x, fs)
    sf.write(OUTPUT_FILENAME, x, fs)
    print(f'Spectrogram values range over [{np.amin(value)},{np.amax(value)} ]')
    #figure(figsize=(8, 6), dpi=80)
    plt.figure().set_size_inches(20, 20)
    plt.title('Result')
    plt.imshow(value,  origin='lower')
    
    plt.show()

plt.ioff()
# Out:
# out_spec lene is 1
# shape of value is (257, 3488)
# Huz invert mag to audio
# Spectrogram values range over [-0.6111809015274048,16.869197845458984 ]

# %%
print(OUTPUT_FILENAME)
display(Audio(OUTPUT_FILENAME, autoplay=True))
# Out:
# outputs/rftests/rftests_0.wav
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
